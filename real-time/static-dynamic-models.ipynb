# %%
# !pip install mediapipe numpy opencv-python tensorflow[and-cuda] pandas joblib
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.21-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting numpy
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting joblib
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting tensorflow[and-cuda]
#   Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py (from mediapipe)
#   Downloading absl_py-2.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: attrs>=19.1.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from mediapipe) (25.3.0)
# Collecting flatbuffers>=2.0 (from mediapipe)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting jax (from mediapipe)
#   Downloading jax-0.6.1-py3-none-any.whl.metadata (13 kB)
# Collecting jaxlib (from mediapipe)
#   Downloading jaxlib-0.6.1-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting matplotlib (from mediapipe)
#   Downloading matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting sentencepiece (from mediapipe)
#   Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting astunparse>=1.6.0 (from tensorflow[and-cuda])
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow[and-cuda])
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow[and-cuda])
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow[and-cuda])
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow[and-cuda])
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (25.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.32.3)
# Requirement already satisfied: setuptools in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow[and-cuda])
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (4.13.2)
# Collecting wrapt>=1.11.0 (from tensorflow[and-cuda])
#   Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow[and-cuda])
#   Downloading grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow[and-cuda])
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow[and-cuda])
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting h5py>=3.11.0 (from tensorflow[and-cuda])
#   Downloading h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow[and-cuda])
#   Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting nvidia-cublas-cu12==12.5.3.2 (from tensorflow[and-cuda])
#   Downloading nvidia_cublas_cu12-12.5.3.2-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_cuda_cupti_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvcc-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_cuda_nvcc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_cuda_nvrtc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_cuda_runtime_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12==9.3.0.75 (from tensorflow[and-cuda])
#   Downloading nvidia_cudnn_cu12-9.3.0.75-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12==11.2.3.61 (from tensorflow[and-cuda])
#   Downloading nvidia_cufft_cu12-11.2.3.61-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.6.82 (from tensorflow[and-cuda])
#   Downloading nvidia_curand_cu12-10.3.6.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.3.83 (from tensorflow[and-cuda])
#   Downloading nvidia_cusolver_cu12-11.6.3.83-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.1.3 (from tensorflow[and-cuda])
#   Downloading nvidia_cusparse_cu12-12.5.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.23.4 (from tensorflow[and-cuda])
#   Downloading nvidia_nccl_cu12-2.23.4-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2025.4.26)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow[and-cuda])
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow[and-cuda])
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow[and-cuda])
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow[and-cuda])
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.5.0->tensorflow[and-cuda])
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow[and-cuda])
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow[and-cuda])
#   Downloading optree-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: CFFI>=1.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow[and-cuda]) (3.0.2)
# Collecting scipy>=1.11.1 (from jax->mediapipe)
#   Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->mediapipe)
#   Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapipe)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mediapipe)
#   Downloading fonttools-4.58.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapipe)
#   Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting pillow>=8 (from matplotlib->mediapipe)
#   Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->mediapipe)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow[and-cuda])
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow[and-cuda]) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow[and-cuda])
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading mediapipe-0.10.21-cp312-cp312-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 32.0 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 33.3 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 33.3 MB/s eta 0:00:0000:0100:01
# Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (645.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 27.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.5.3.2-py3-none-manylinux2014_x86_64.whl (363.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.3/363.3 MB 30.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 30.5 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cuda_nvcc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (22.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 34.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 32.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (895 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 895.7/895.7 kB 25.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.3.0.75-py3-none-manylinux2014_x86_64.whl (577.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.2/577.2 MB 28.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.2.3.61-py3-none-manylinux2014_x86_64.whl (192.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 MB 34.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.6.82-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.6.3.83-py3-none-manylinux2014_x86_64.whl (130.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 MB 33.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.5.1.3-py3-none-manylinux2014_x86_64.whl (217.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.6/217.6 MB 34.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.23.4-py3-none-manylinux2014_x86_64.whl (199.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.0/199.0 MB 34.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 33.9 MB/s eta 0:00:0000:0100:01
# Downloading grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 32.3 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 30.7 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 31.3 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 31.2 MB/s eta 0:00:0000:01
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 32.9 MB/s eta 0:00:00 0:00:01
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading absl_py-2.3.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 32.6 MB/s eta 0:00:00
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 27.6 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 33.5 MB/s eta 0:00:0000:0100:01
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading sounddevice-0.5.2-py3-none-any.whl (32 kB)
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
# Downloading jax-0.6.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 30.0 MB/s eta 0:00:00
# Downloading jaxlib-0.6.1-cp312-cp312-manylinux2014_x86_64.whl (89.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 MB 34.3 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 33.8 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 32.3 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 32.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 29.1 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 32.1 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading opencv_contrib_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 33.8 MB/s eta 0:00:0000:0100:01
# Downloading optree-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.8 MB/s eta 0:00:00
# Installing collected packages: sentencepiece, pytz, namex, libclang, flatbuffers, wrapt, wheel, werkzeug, tzdata, termcolor, tensorboard-data-server, pyparsing, protobuf, pillow, optree, opt-einsum, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-nvcc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, mdurl, markdown, kiwisolver, joblib, grpcio, google-pasta, gast, fonttools, cycler, absl-py, tensorboard, sounddevice, scipy, pandas, opencv-python, opencv-contrib-python, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, ml-dtypes, markdown-it-py, h5py, contourpy, astunparse, rich, nvidia-cusolver-cu12, matplotlib, jaxlib, keras, jax, tensorflow, mediapipe
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57/57 [mediapipe]ediapipe]ensorflow]lver-cu12]]]2]
# Successfully installed absl-py-2.3.0 astunparse-1.6.3 contourpy-1.3.2 cycler-0.12.1 flatbuffers-25.2.10 fonttools-4.58.1 gast-0.6.0 google-pasta-0.2.0 grpcio-1.71.0 h5py-3.13.0 jax-0.6.1 jaxlib-0.6.1 joblib-1.5.1 keras-3.10.0 kiwisolver-1.4.8 libclang-18.1.1 markdown-3.8 markdown-it-py-3.0.0 matplotlib-3.10.3 mdurl-0.1.2 mediapipe-0.10.21 ml-dtypes-0.5.1 namex-0.1.0 numpy-1.26.4 nvidia-cublas-cu12-12.5.3.2 nvidia-cuda-cupti-cu12-12.5.82 nvidia-cuda-nvcc-cu12-12.5.82 nvidia-cuda-nvrtc-cu12-12.5.82 nvidia-cuda-runtime-cu12-12.5.82 nvidia-cudnn-cu12-9.3.0.75 nvidia-cufft-cu12-11.2.3.61 nvidia-curand-cu12-10.3.6.82 nvidia-cusolver-cu12-11.6.3.83 nvidia-cusparse-cu12-12.5.1.3 nvidia-nccl-cu12-2.23.4 nvidia-nvjitlink-cu12-12.5.82 opencv-contrib-python-4.11.0.86 opencv-python-4.11.0.86 opt-einsum-3.4.0 optree-0.16.0 pandas-2.2.3 pillow-11.2.1 protobuf-4.25.8 pyparsing-3.2.3 pytz-2025.2 rich-14.0.0 scipy-1.15.3 sentencepiece-0.2.0 sounddevice-0.5.2 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 termcolor-3.1.0 tzdata-2025.2 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.2

# %%
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
import joblib

# Załaduj modele
model_static = load_model('../model/StaticBiLSTM/static_gestures_model.keras')
label_encoder_static = joblib.load('../model/StaticBiLSTM/static_gestures_labels.pkl')

model_dynamic = load_model('../model/DynamicBiLSTM/dynamic_gestures_model.keras')
label_encoder_dynamic = joblib.load('../model/DynamicBiLSTM/dynamic_gestures_labels.pkl')

# Parametry
motion_threshold = 1.8  # Próg rozróżnienia statyczny/dynamiczny
motion_history = []
motion_history_len = 5
cooldown_frames = 0
cooldown_threshold = 10
recognized_sign = ''
recognized_type = ''
last_prediction = None
static_buffer = []
dynamic_buffer = []

# MediaPipe
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils
def normalize_landmarks_buffer(buffer):
    data = []
    for frame_idx, row in enumerate(buffer):
        if len(row) != 63:
            print(f"[WARNING] Frame {frame_idx} has invalid length {len(row)}")
            continue
        frame_data = {'frame': frame_idx}
        for i in range(21):
            frame_data[f'landmark_{i}_x'] = row[i * 3]
            frame_data[f'landmark_{i}_y'] = row[i * 3 + 1]
            frame_data[f'landmark_{i}_z'] = row[i * 3 + 2]
        data.append(frame_data)

    if len(data) == 0:
        print("[WARNING] No valid frames in buffer")
        return np.zeros((1, 63))

    df = pd.DataFrame(data)
    df = df.sort_values("frame").copy()

    wrist_ref = {
        axis: df[df["frame"] == 0].iloc[0][f"landmark_1_{axis}"]
        for axis in ['x', 'y', 'z']
    }

    for axis in ['x', 'y', 'z']:
        for i in range(1, 21):
            col = f'landmark_{i}_{axis}'
            df[col] = df[col] - wrist_ref[axis]

    norm_buffer = []
    for _, row in df.iterrows():
        landmarks = []
        for i in range(21):
            landmarks.extend([
                row[f'landmark_{i}_x'],
                row[f'landmark_{i}_y'],
                row[f'landmark_{i}_z']
            ])
        norm_buffer.append(landmarks)

    norm_array = np.array(norm_buffer)
    print(f"[DEBUG] Normalized buffer shape: {norm_array.shape}")
    return norm_array

def extract_right_hand_landmarks(results):
    if results.right_hand_landmarks:
        return [coord for lm in results.right_hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]
    return None

def get_hand_bbox(landmarks, image_width, image_height):
    xs = [lm.x * image_width for lm in landmarks.landmark]
    ys = [lm.y * image_height for lm in landmarks.landmark]
    x_min, x_max = max(int(min(xs)), 0), min(int(max(xs)), image_width)
    y_min, y_max = max(int(min(ys)), 0), min(int(max(ys)), image_height)
    return (x_min, y_min, x_max, y_max)

# Inicjalizacja kamery
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

ret, prev_frame = cap.read()
prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        curr_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame_diff = cv2.absdiff(prev_gray, curr_gray)
        motion_level = np.sum(frame_diff) / (frame.shape[0] * frame.shape[1])
        prev_gray = curr_gray.copy()

        # Wygładzanie ruchu
        motion_history.append(motion_level)
        if len(motion_history) > motion_history_len:
            motion_history.pop(0)
        smooth_motion = np.mean(motion_history)

        print(f"[DEBUG] Motion level: {motion_level:.3f}, Smooth motion: {smooth_motion:.3f}")

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image_rgb)
        image_height, image_width, _ = frame.shape

        landmarks = extract_right_hand_landmarks(results)

        if landmarks:
            mp_drawing.draw_landmarks(
                frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

            bbox = get_hand_bbox(results.right_hand_landmarks, image_width, image_height)
            x1, y1, x2, y2 = bbox
            box_color = (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)

            if smooth_motion < motion_threshold:
                dynamic_buffer.clear()
                static_buffer.append(landmarks)
                # print(f"[DEBUG] Static buffer size: {len(static_buffer)}")
                if len(static_buffer) >= 5:
                    if cooldown_frames == 0:
                        # print("[DEBUG] Running static prediction...")
                        norm_static = normalize_landmarks_buffer(static_buffer)
                        if norm_static.shape[0] == 5:
                            norm_static = np.expand_dims(norm_static, axis=0)
                            prediction = model_static.predict(norm_static)[0]
                            label = label_encoder_static.inverse_transform([np.argmax(prediction)])[0]
                            conf = np.max(prediction)
                            print(f"[STATIC] Predicted: {label} (conf: {conf:.2f})")
                            if conf > 0.5 and label != last_prediction:
                               recognized_sign = label
                               recognized_type = "Statyczny"
                               last_prediction = label
                               cooldown_frames = cooldown_threshold
                               static_buffer.clear()
                               dynamic_buffer.clear()
                               print(f"[INFO] Recognized static gesture: {recognized_sign} with confidence {conf:.2f}")
                        else:
                            print("[WARNING] Normalized static buffer shape unexpected:", norm_static.shape)
                        static_buffer.clear()
                    else:
                        print(f"[DEBUG] Static prediction skipped due to cooldown: {cooldown_frames}")
            else:
                static_buffer.clear()
                dynamic_buffer.append(landmarks)
                # print(f"[DEBUG] Dynamic buffer size: {len(dynamic_buffer)}")
                if len(dynamic_buffer) >= 30:
                    if cooldown_frames == 0:
                        # print("[DEBUG] Running dynamic prediction...")
                        norm_dynamic = normalize_landmarks_buffer(dynamic_buffer)
                        if norm_dynamic.shape[0] == 30:
                            norm_dynamic = np.expand_dims(norm_dynamic, axis=0)
                            prediction = model_dynamic.predict(norm_dynamic)[0]
                            label = label_encoder_dynamic.inverse_transform([np.argmax(prediction)])[0]
                            conf = np.max(prediction)
                            print(f"[DYNAMIC] Predicted: {label} (conf: {conf:.2f})")
                            if conf > 0.5 and label != last_prediction:
                                recognized_sign = label
                                recognized_type = "Dynamiczny"
                                last_prediction = label
                                cooldown_frames = cooldown_threshold
                                static_buffer.clear()
                                dynamic_buffer.clear()
                                print(f"[INFO] Recognized dynamic gesture: {recognized_sign} with confidence {conf:.2f}")
                        else:
                            print("[WARNING] Normalized dynamic buffer shape unexpected:", norm_dynamic.shape)
                        dynamic_buffer.clear()
                    else:
                        print(f"[DEBUG] Dynamic prediction skipped due to cooldown: {cooldown_frames}")

            # Rysowanie labela na górze ekranu, wyśrodkowany
            if recognized_sign and recognized_type:
                label_text = f'{recognized_sign} ({recognized_type})'
                label_pos_x = image_width // 2
                label_pos_y = 30
                print(f"[DEBUG] Drawing label: {label_text} at ({label_pos_x}, {label_pos_y})")
                (text_width, text_height), baseline = cv2.getTextSize(
                    label_text, cv2.FONT_HERSHEY_SIMPLEX, 1.0, 3)
                text_x = label_pos_x - text_width // 2
                text_y = label_pos_y
                cv2.putText(
                    frame,
                    label_text,
                    (text_x, text_y),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1.0,
                    (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0),
                    3,
                    lineType=cv2.LINE_AA
                )
        else:
            static_buffer.clear()
            dynamic_buffer.clear()
            recognized_sign = ''
            recognized_type = ''
            last_prediction = None

        cooldown_frames = max(0, cooldown_frames - 1)

        cv2.imshow('Sign Language Recognition', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-06-01 12:59:38.029608: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748775578.057725   40494 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748775578.065354   40494 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748775578.082410   40494 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748775578.082438   40494 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748775578.082440   40494 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748775578.082442   40494 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-01 12:59:38.087457: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1748775582.146437   40494 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1740 MB memory:  -> device: 0, name: NVIDIA GeForce MX150, pci bus id: 0000:01:00.0, compute capability: 6.1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748775583.750033   40494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1748775583.752628   40633 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1-1ubuntu3.1~22.04.3), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1748775583.832096   40619 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775583.876412   40617 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775583.879889   40618 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775583.881402   40619 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775583.882954   40617 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775583.894108   40619 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775583.902063   40620 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775583.906999   40618 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775583.910745   40621 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# [DEBUG] Motion level: 1.609, Smooth motion: 1.609
# [DEBUG] Motion level: 1.542, Smooth motion: 1.575
# [DEBUG] Motion level: 1.521, Smooth motion: 1.557
# [DEBUG] Motion level: 1.491, Smooth motion: 1.541
# [DEBUG] Motion level: 1.494, Smooth motion: 1.532
# [DEBUG] Motion level: 2.685, Smooth motion: 1.747
# [DEBUG] Motion level: 1.417, Smooth motion: 1.722
# [DEBUG] Motion level: 1.565, Smooth motion: 1.730
# [DEBUG] Motion level: 1.751, Smooth motion: 1.782
# [DEBUG] Motion level: 1.655, Smooth motion: 1.815
# [DEBUG] Motion level: 1.605, Smooth motion: 1.599
# [DEBUG] Motion level: 1.560, Smooth motion: 1.627
# [DEBUG] Motion level: 1.531, Smooth motion: 1.621
# [DEBUG] Motion level: 1.572, Smooth motion: 1.585
# [DEBUG] Motion level: 1.570, Smooth motion: 1.568
# [DEBUG] Motion level: 1.937, Smooth motion: 1.634
# [DEBUG] Motion level: 1.613, Smooth motion: 1.645
# [DEBUG] Motion level: 1.558, Smooth motion: 1.650
# [DEBUG] Motion level: 1.578, Smooth motion: 1.651
# [DEBUG] Motion level: 1.544, Smooth motion: 1.646
# [DEBUG] Motion level: 1.560, Smooth motion: 1.571
# [DEBUG] Motion level: 1.569, Smooth motion: 1.562
# [DEBUG] Motion level: 1.548, Smooth motion: 1.560
# [DEBUG] Motion level: 1.565, Smooth motion: 1.557
# [DEBUG] Motion level: 1.568, Smooth motion: 1.562
# [DEBUG] Motion level: 1.560, Smooth motion: 1.562
# [DEBUG] Motion level: 1.559, Smooth motion: 1.560
# [DEBUG] Motion level: 2.212, Smooth motion: 1.693
# [DEBUG] Motion level: 2.434, Smooth motion: 1.867
# [DEBUG] Motion level: 5.232, Smooth motion: 2.599
# [DEBUG] Motion level: 4.488, Smooth motion: 3.185
# [DEBUG] Motion level: 5.695, Smooth motion: 4.012
# [DEBUG] Motion level: 6.025, Smooth motion: 4.775
# [DEBUG] Motion level: 7.097, Smooth motion: 5.707
# [DEBUG] Motion level: 3.422, Smooth motion: 5.345
# [DEBUG] Motion level: 2.931, Smooth motion: 5.034
# [DEBUG] Motion level: 3.893, Smooth motion: 4.674
# [DEBUG] Motion level: 2.677, Smooth motion: 4.004
# [DEBUG] Motion level: 6.207, Smooth motion: 3.826
# [DEBUG] Motion level: 2.403, Smooth motion: 3.622
# [DEBUG] Motion level: 2.373, Smooth motion: 3.511
# [DEBUG] Motion level: 3.470, Smooth motion: 3.426
# [DEBUG] Motion level: 2.485, Smooth motion: 3.388
# [DEBUG] Motion level: 2.652, Smooth motion: 2.677
# [DEBUG] Motion level: 4.996, Smooth motion: 3.195
# [DEBUG] Motion level: 3.485, Smooth motion: 3.418
# [DEBUG] Motion level: 3.500, Smooth motion: 3.424
# [DEBUG] Motion level: 3.790, Smooth motion: 3.684
# [DEBUG] Motion level: 4.829, Smooth motion: 4.120
# [DEBUG] Motion level: 5.011, Smooth motion: 4.123
# [DEBUG] Motion level: 5.551, Smooth motion: 4.536
# [DEBUG] Motion level: 5.932, Smooth motion: 5.023
# [DEBUG] Motion level: 5.875, Smooth motion: 5.440
# [DEBUG] Motion level: 5.707, Smooth motion: 5.615
# [DEBUG] Motion level: 5.506, Smooth motion: 5.714
# [DEBUG] Motion level: 5.861, Smooth motion: 5.776
# [DEBUG] Motion level: 4.515, Smooth motion: 5.493
# [DEBUG] Motion level: 4.209, Smooth motion: 5.160
# [DEBUG] Motion level: 5.786, Smooth motion: 5.175
# [DEBUG] Motion level: 3.039, Smooth motion: 4.682
# [DEBUG] Motion level: 2.627, Smooth motion: 4.035
# [DEBUG] Motion level: 2.962, Smooth motion: 3.724
# [DEBUG] Motion level: 1.881, Smooth motion: 3.259
# [DEBUG] Motion level: 3.295, Smooth motion: 2.761
# [DEBUG] Motion level: 1.732, Smooth motion: 2.499
# [DEBUG] Motion level: 1.790, Smooth motion: 2.332
# [DEBUG] Motion level: 1.621, Smooth motion: 2.064
# [DEBUG] Motion level: 1.672, Smooth motion: 2.022
# [DEBUG] Motion level: 1.574, Smooth motion: 1.678
# [DEBUG] Motion level: 1.772, Smooth motion: 1.686
# [DEBUG] Motion level: 2.780, Smooth motion: 1.884
# [DEBUG] Motion level: 1.518, Smooth motion: 1.863
# [DEBUG] Motion level: 1.531, Smooth motion: 1.835
# [DEBUG] Motion level: 1.724, Smooth motion: 1.865
# [DEBUG] Motion level: 1.580, Smooth motion: 1.827
# [DEBUG] Motion level: 1.657, Smooth motion: 1.602
# [DEBUG] Motion level: 1.524, Smooth motion: 1.603
# [DEBUG] Motion level: 1.547, Smooth motion: 1.606
# [DEBUG] Motion level: 2.821, Smooth motion: 1.826
# [DEBUG] Motion level: 1.482, Smooth motion: 1.806
# [DEBUG] Motion level: 1.503, Smooth motion: 1.775
# [DEBUG] Motion level: 1.522, Smooth motion: 1.775
# [DEBUG] Motion level: 1.560, Smooth motion: 1.778
# [DEBUG] Motion level: 1.577, Smooth motion: 1.529
# [DEBUG] Motion level: 1.736, Smooth motion: 1.580
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# I0000 00:00:1748775588.071769   40574 cuda_dnn.cc:529] Loaded cuDNN version 90300
# [STATIC] Predicted: B (conf: 0.18)
# [DEBUG] Motion level: 2.766, Smooth motion: 1.832
# [DEBUG] Motion level: 1.543, Smooth motion: 1.837
# [DEBUG] Motion level: 1.451, Smooth motion: 1.815
# [DEBUG] Motion level: 1.452, Smooth motion: 1.790
# [DEBUG] Motion level: 3.086, Smooth motion: 2.060
# [DEBUG] Motion level: 1.405, Smooth motion: 1.787
# [DEBUG] Motion level: 1.495, Smooth motion: 1.778
# [DEBUG] Motion level: 1.443, Smooth motion: 1.776
# [DEBUG] Motion level: 1.434, Smooth motion: 1.772
# [DEBUG] Motion level: 1.470, Smooth motion: 1.449
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [STATIC] Predicted: B (conf: 0.18)
# [DEBUG] Motion level: 1.414, Smooth motion: 1.451
# [DEBUG] Motion level: 1.483, Smooth motion: 1.449
# [DEBUG] Motion level: 1.448, Smooth motion: 1.450
# [DEBUG] Motion level: 1.635, Smooth motion: 1.490
# [DEBUG] Motion level: 1.729, Smooth motion: 1.542
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [STATIC] Predicted: B (conf: 0.18)
# [DEBUG] Motion level: 1.413, Smooth motion: 1.542
# [DEBUG] Motion level: 1.435, Smooth motion: 1.532
# [DEBUG] Motion level: 1.406, Smooth motion: 1.524
# [DEBUG] Motion level: 1.419, Smooth motion: 1.480
# [DEBUG] Motion level: 1.499, Smooth motion: 1.434
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [STATIC] Predicted: B (conf: 0.18)
# [DEBUG] Motion level: 1.679, Smooth motion: 1.488
# [DEBUG] Motion level: 1.584, Smooth motion: 1.518
# [DEBUG] Motion level: 1.406, Smooth motion: 1.518
# [DEBUG] Motion level: 1.449, Smooth motion: 1.524
# [DEBUG] Motion level: 1.546, Smooth motion: 1.533
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: B (conf: 0.19)
# [DEBUG] Motion level: 1.418, Smooth motion: 1.481
# [DEBUG] Motion level: 1.391, Smooth motion: 1.442
# [DEBUG] Motion level: 1.406, Smooth motion: 1.442
# [DEBUG] Motion level: 1.395, Smooth motion: 1.431
# [DEBUG] Motion level: 1.431, Smooth motion: 1.408
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# [STATIC] Predicted: B (conf: 0.19)
# [DEBUG] Motion level: 1.464, Smooth motion: 1.417
# [DEBUG] Motion level: 1.472, Smooth motion: 1.434
# [DEBUG] Motion level: 1.436, Smooth motion: 1.440
# [DEBUG] Motion level: 1.492, Smooth motion: 1.459
# [DEBUG] Motion level: 1.562, Smooth motion: 1.485
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: B (conf: 0.19)
# [DEBUG] Motion level: 1.440, Smooth motion: 1.480
# [DEBUG] Motion level: 1.400, Smooth motion: 1.466
# [DEBUG] Motion level: 1.390, Smooth motion: 1.457
# [DEBUG] Motion level: 1.410, Smooth motion: 1.440
# [DEBUG] Motion level: 1.431, Smooth motion: 1.414
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [STATIC] Predicted: B (conf: 0.19)
# [DEBUG] Motion level: 1.432, Smooth motion: 1.413
# [DEBUG] Motion level: 1.415, Smooth motion: 1.415
# [DEBUG] Motion level: 1.491, Smooth motion: 1.436
# [DEBUG] Motion level: 1.441, Smooth motion: 1.442
# [DEBUG] Motion level: 2.369, Smooth motion: 1.629
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: B (conf: 0.19)
# [DEBUG] Motion level: 1.743, Smooth motion: 1.692
# [DEBUG] Motion level: 2.142, Smooth motion: 1.837
# [DEBUG] Motion level: 1.629, Smooth motion: 1.865
# [DEBUG] Motion level: 2.089, Smooth motion: 1.994
# [DEBUG] Motion level: 2.415, Smooth motion: 2.004
# [DEBUG] Motion level: 1.661, Smooth motion: 1.987
# [DEBUG] Motion level: 2.238, Smooth motion: 2.006
# [DEBUG] Motion level: 1.855, Smooth motion: 2.052
# [DEBUG] Motion level: 2.651, Smooth motion: 2.164
# [DEBUG] Motion level: 2.829, Smooth motion: 2.247
# [DEBUG] Motion level: 2.074, Smooth motion: 2.329
# [DEBUG] Motion level: 2.116, Smooth motion: 2.305
# [DEBUG] Motion level: 3.188, Smooth motion: 2.572
# [DEBUG] Motion level: 2.057, Smooth motion: 2.453
# [DEBUG] Motion level: 1.967, Smooth motion: 2.281
# [DEBUG] Motion level: 2.392, Smooth motion: 2.344
# [DEBUG] Motion level: 1.846, Smooth motion: 2.290
# [DEBUG] Motion level: 1.970, Smooth motion: 2.046
# [DEBUG] Motion level: 1.970, Smooth motion: 2.029
# [DEBUG] Motion level: 2.105, Smooth motion: 2.057
# [DEBUG] Motion level: 1.565, Smooth motion: 1.891
# [DEBUG] Motion level: 1.458, Smooth motion: 1.814
# [DEBUG] Motion level: 1.875, Smooth motion: 1.795
# [DEBUG] Motion level: 1.781, Smooth motion: 1.757
# [DEBUG] Motion level: 2.119, Smooth motion: 1.760
# [DEBUG] Motion level: 2.554, Smooth motion: 1.958
# [DEBUG] Motion level: 3.337, Smooth motion: 2.333
# [DEBUG] Motion level: 2.360, Smooth motion: 2.430
# [DEBUG] Motion level: 2.184, Smooth motion: 2.511
# [DEBUG] Motion level: 2.506, Smooth motion: 2.588
# [DEBUG] Motion level: 1.565, Smooth motion: 2.390
# [DEBUG] Motion level: 1.624, Smooth motion: 2.048
# [DEBUG] Motion level: 1.699, Smooth motion: 1.915
# [DEBUG] Motion level: 1.764, Smooth motion: 1.832
# [DEBUG] Motion level: 1.519, Smooth motion: 1.634
# [DEBUG] Motion level: 1.560, Smooth motion: 1.633
# [DEBUG] Motion level: 1.552, Smooth motion: 1.619
# [DEBUG] Motion level: 1.671, Smooth motion: 1.613
# [DEBUG] Motion level: 1.506, Smooth motion: 1.562
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: B (conf: 0.51)
# [INFO] Recognized static gesture: B with confidence 0.51
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.515, Smooth motion: 1.561
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.605, Smooth motion: 1.570
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.440, Smooth motion: 1.547
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.524, Smooth motion: 1.518
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.589, Smooth motion: 1.535
# [DEBUG] Static prediction skipped due to cooldown: 5
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.499, Smooth motion: 1.531
# [DEBUG] Static prediction skipped due to cooldown: 4
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.442, Smooth motion: 1.499
# [DEBUG] Static prediction skipped due to cooldown: 3
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.489, Smooth motion: 1.509
# [DEBUG] Static prediction skipped due to cooldown: 2
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.434, Smooth motion: 1.491
# [DEBUG] Static prediction skipped due to cooldown: 1
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.470, Smooth motion: 1.467
# [DEBUG] Normalized buffer shape: (10, 63)
# [WARNING] Normalized static buffer shape unexpected: (10, 63)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.457, Smooth motion: 1.458
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.446, Smooth motion: 1.459
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.467, Smooth motion: 1.455
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.450, Smooth motion: 1.458
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.630, Smooth motion: 1.490
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: B (conf: 0.51)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.468, Smooth motion: 1.492
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.691, Smooth motion: 1.541
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.523, Smooth motion: 1.552
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.490, Smooth motion: 1.560
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.655, Smooth motion: 1.565
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: B (conf: 0.50)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.439, Smooth motion: 1.560
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.450, Smooth motion: 1.511
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.453, Smooth motion: 1.497
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.439, Smooth motion: 1.487
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.499, Smooth motion: 1.456
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: B (conf: 0.51)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.641, Smooth motion: 1.496
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.604, Smooth motion: 1.527
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.446, Smooth motion: 1.526
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.449, Smooth motion: 1.528
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.749, Smooth motion: 1.578
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: B (conf: 0.50)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.461, Smooth motion: 1.542
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.588, Smooth motion: 1.539
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.901, Smooth motion: 1.630
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.620, Smooth motion: 2.064
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.735, Smooth motion: 2.661
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.330, Smooth motion: 2.835
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.686, Smooth motion: 3.054
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.717, Smooth motion: 3.018
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.785, Smooth motion: 2.651
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.646, Smooth motion: 2.033
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.582, Smooth motion: 1.883
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.658, Smooth motion: 1.678
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.479, Smooth motion: 1.630
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.646, Smooth motion: 1.602
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.561, Smooth motion: 1.586
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.543, Smooth motion: 1.578
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: R (conf: 0.47)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.592, Smooth motion: 1.564
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.487, Smooth motion: 1.566
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.671, Smooth motion: 1.571
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.493, Smooth motion: 1.557
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.778, Smooth motion: 1.604
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: R (conf: 0.46)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.444, Smooth motion: 1.575
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.533, Smooth motion: 1.584
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.457, Smooth motion: 1.541
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.456, Smooth motion: 1.534
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.186, Smooth motion: 1.615
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: R (conf: 0.42)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.714, Smooth motion: 1.669
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.056, Smooth motion: 1.774
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.596, Smooth motion: 1.801
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.631, Smooth motion: 1.837
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.648, Smooth motion: 1.729
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.544, Smooth motion: 1.695
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.500, Smooth motion: 1.584
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.483, Smooth motion: 1.561
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.420, Smooth motion: 1.519
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: P (conf: 0.42)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.413, Smooth motion: 1.472
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.441, Smooth motion: 1.452
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.471, Smooth motion: 1.446
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.475, Smooth motion: 1.444
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.696, Smooth motion: 1.499
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: P (conf: 0.42)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.433, Smooth motion: 1.503
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.420, Smooth motion: 1.499
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.452, Smooth motion: 1.495
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.419, Smooth motion: 1.484
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.730, Smooth motion: 1.491
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: P (conf: 0.42)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.253, Smooth motion: 1.655
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.917, Smooth motion: 1.754
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.803, Smooth motion: 1.824
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.512, Smooth motion: 2.043
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.718, Smooth motion: 2.241
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.320, Smooth motion: 2.254
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.908, Smooth motion: 2.252
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.908, Smooth motion: 2.273
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.995, Smooth motion: 2.170
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.472, Smooth motion: 2.121
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.526, Smooth motion: 1.962
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.431, Smooth motion: 1.866
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.510, Smooth motion: 1.787
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.523, Smooth motion: 1.692
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.604, Smooth motion: 1.519
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.643, Smooth motion: 1.542
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.809, Smooth motion: 1.618
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: R (conf: 0.62)
# [INFO] Recognized static gesture: R with confidence 0.62
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.515, Smooth motion: 1.619
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.689, Smooth motion: 1.652
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.428, Smooth motion: 1.617
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.404, Smooth motion: 1.569
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.598, Smooth motion: 1.527
# [DEBUG] Static prediction skipped due to cooldown: 5
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.472, Smooth motion: 1.518
# [DEBUG] Static prediction skipped due to cooldown: 4
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.540, Smooth motion: 1.488
# [DEBUG] Static prediction skipped due to cooldown: 3
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.425, Smooth motion: 1.488
# [DEBUG] Static prediction skipped due to cooldown: 2
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.453, Smooth motion: 1.497
# [DEBUG] Static prediction skipped due to cooldown: 1
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.748, Smooth motion: 1.528
# [DEBUG] Normalized buffer shape: (10, 63)
# [WARNING] Normalized static buffer shape unexpected: (10, 63)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.695, Smooth motion: 1.572
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.882, Smooth motion: 1.640
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.866, Smooth motion: 1.929
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.843, Smooth motion: 2.007
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.706, Smooth motion: 1.998
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.560, Smooth motion: 1.971
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.725, Smooth motion: 1.940
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.509, Smooth motion: 1.669
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.913, Smooth motion: 1.683
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.686, Smooth motion: 1.679
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.712, Smooth motion: 1.709
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.968, Smooth motion: 1.758
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: R (conf: 0.64)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.642, Smooth motion: 1.784
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.652, Smooth motion: 1.732
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.931, Smooth motion: 1.781
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.513, Smooth motion: 1.741
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.843, Smooth motion: 1.716
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: R (conf: 0.65)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.421, Smooth motion: 1.672
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.484, Smooth motion: 1.638
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.728, Smooth motion: 1.598
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.479, Smooth motion: 1.591
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.155, Smooth motion: 1.654
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: R (conf: 0.63)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.814, Smooth motion: 1.732
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.887, Smooth motion: 1.813
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.259, Smooth motion: 2.119
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.914, Smooth motion: 2.606
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.365, Smooth motion: 2.848
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.747, Smooth motion: 3.034
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.177, Smooth motion: 3.092
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.308, Smooth motion: 2.902
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.189, Smooth motion: 2.557
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.006, Smooth motion: 2.286
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.588, Smooth motion: 2.054
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.730, Smooth motion: 1.964
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.991, Smooth motion: 1.901
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.428, Smooth motion: 1.749
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.491, Smooth motion: 1.646
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.812, Smooth motion: 1.690
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.440, Smooth motion: 1.632
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.389, Smooth motion: 1.512
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [STATIC] Predicted: R (conf: 0.64)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.382, Smooth motion: 1.503
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.427, Smooth motion: 1.490
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.392, Smooth motion: 1.406
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.416, Smooth motion: 1.401
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.790, Smooth motion: 1.482
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: R (conf: 0.65)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.453, Smooth motion: 1.496
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.445, Smooth motion: 1.499
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.470, Smooth motion: 1.515
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.645, Smooth motion: 1.561
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.590, Smooth motion: 1.520
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: R (conf: 0.67)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.401, Smooth motion: 1.510
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.396, Smooth motion: 1.500
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.417, Smooth motion: 1.490
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.377, Smooth motion: 1.436
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.497, Smooth motion: 1.418
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: R (conf: 0.67)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.444, Smooth motion: 1.426
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.387, Smooth motion: 1.424
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.373, Smooth motion: 1.415
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.393, Smooth motion: 1.419
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.449, Smooth motion: 1.409
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: R (conf: 0.67)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.391, Smooth motion: 1.399
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.369, Smooth motion: 1.395
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.374, Smooth motion: 1.395
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.385, Smooth motion: 1.393
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.444, Smooth motion: 1.392
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: R (conf: 0.67)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.380, Smooth motion: 1.390
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.384, Smooth motion: 1.394
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.401, Smooth motion: 1.399
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.386, Smooth motion: 1.399
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.500, Smooth motion: 1.410
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [STATIC] Predicted: R (conf: 0.67)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.417, Smooth motion: 1.418
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.368, Smooth motion: 1.415
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.366, Smooth motion: 1.407
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.383, Smooth motion: 1.407
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.457, Smooth motion: 1.398
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: R (conf: 0.67)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.394, Smooth motion: 1.394
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.525, Smooth motion: 1.425
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.715, Smooth motion: 1.495
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.228, Smooth motion: 1.864
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 6.350, Smooth motion: 2.842
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 6.720, Smooth motion: 3.907
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.359, Smooth motion: 4.474
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.066, Smooth motion: 4.944
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.710, Smooth motion: 5.041
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 5.337, Smooth motion: 4.838
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.131, Smooth motion: 4.120
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.996, Smooth motion: 3.848
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.654, Smooth motion: 3.965
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.783, Smooth motion: 3.780
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.485, Smooth motion: 3.210
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.944, Smooth motion: 3.172
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.985, Smooth motion: 2.970
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.465, Smooth motion: 2.532
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.653, Smooth motion: 2.906
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.747, Smooth motion: 3.159
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.020, Smooth motion: 3.374
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 6.573, Smooth motion: 4.291
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.326, Smooth motion: 4.664
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.343, Smooth motion: 4.602
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 5.689, Smooth motion: 4.990
# [DEBUG] Motion level: 3.949, Smooth motion: 4.976
# [DEBUG] Motion level: 4.040, Smooth motion: 4.470
# [DEBUG] Motion level: 5.847, Smooth motion: 4.774
# [DEBUG] Motion level: 3.874, Smooth motion: 4.680
# [DEBUG] Motion level: 3.570, Smooth motion: 4.256
# [DEBUG] Motion level: 5.056, Smooth motion: 4.477
# [DEBUG] Motion level: 2.825, Smooth motion: 4.234
# [DEBUG] Motion level: 2.543, Smooth motion: 3.574
# [DEBUG] Motion level: 3.175, Smooth motion: 3.434
# [DEBUG] Motion level: 1.865, Smooth motion: 3.093
# [DEBUG] Motion level: 2.110, Smooth motion: 2.504
# [DEBUG] Motion level: 1.569, Smooth motion: 2.252
# [DEBUG] Motion level: 1.961, Smooth motion: 2.136
# [DEBUG] Motion level: 1.773, Smooth motion: 1.856
# [DEBUG] Motion level: 2.020, Smooth motion: 1.887
# [DEBUG] Motion level: 4.077, Smooth motion: 2.280
# [DEBUG] Motion level: 3.507, Smooth motion: 2.668
# [DEBUG] Motion level: 3.845, Smooth motion: 3.045
# [DEBUG] Motion level: 5.417, Smooth motion: 3.773
# [DEBUG] Motion level: 3.880, Smooth motion: 4.145
# [DEBUG] Motion level: 5.444, Smooth motion: 4.418
# [DEBUG] Motion level: 4.571, Smooth motion: 4.631
# [DEBUG] Motion level: 5.910, Smooth motion: 5.044
# [DEBUG] Motion level: 4.057, Smooth motion: 4.772
# [DEBUG] Motion level: 5.997, Smooth motion: 5.196
# [DEBUG] Motion level: 3.914, Smooth motion: 4.890
# [DEBUG] Motion level: 5.718, Smooth motion: 5.119
# [DEBUG] Motion level: 3.619, Smooth motion: 4.661
# [DEBUG] Motion level: 3.476, Smooth motion: 4.545
# [DEBUG] Motion level: 4.549, Smooth motion: 4.255
# [DEBUG] Motion level: 2.629, Smooth motion: 3.998
# [DEBUG] Motion level: 2.934, Smooth motion: 3.441
# [DEBUG] Motion level: 2.084, Smooth motion: 3.134
# [DEBUG] Normalized buffer shape: (30, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# [DYNAMIC] Predicted: F (conf: 0.78)
# [INFO] Recognized dynamic gesture: F with confidence 0.78
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.166, Smooth motion: 2.872
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.096, Smooth motion: 2.582
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.384, Smooth motion: 2.733
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.586, Smooth motion: 2.663
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 7.033, Smooth motion: 3.653
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 4.357, Smooth motion: 4.091
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.967, Smooth motion: 4.065
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.895, Smooth motion: 4.168
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.736, Smooth motion: 4.398
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.657, Smooth motion: 3.522
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.521, Smooth motion: 3.155
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.154, Smooth motion: 3.193
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.223, Smooth motion: 2.858
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.248, Smooth motion: 2.561
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.102, Smooth motion: 2.650
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.397, Smooth motion: 2.625
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.193, Smooth motion: 2.633
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.349, Smooth motion: 2.658
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.399, Smooth motion: 2.688
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.943, Smooth motion: 2.656
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.082, Smooth motion: 2.593
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.051, Smooth motion: 2.365
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.536, Smooth motion: 2.402
# [DEBUG] Motion level: 1.793, Smooth motion: 2.281
# [DEBUG] Motion level: 1.701, Smooth motion: 2.033
# [DEBUG] Motion level: 1.619, Smooth motion: 1.940
# [DEBUG] Motion level: 1.854, Smooth motion: 1.901
# [DEBUG] Motion level: 1.511, Smooth motion: 1.696
# [DEBUG] Motion level: 1.490, Smooth motion: 1.635
# [DEBUG] Motion level: 1.603, Smooth motion: 1.615
# [DEBUG] Motion level: 1.417, Smooth motion: 1.575
# [DEBUG] Motion level: 1.396, Smooth motion: 1.483
# [DEBUG] Motion level: 1.366, Smooth motion: 1.454
# [DEBUG] Motion level: 1.891, Smooth motion: 1.534
# [DEBUG] Motion level: 1.953, Smooth motion: 1.604
# [DEBUG] Motion level: 2.156, Smooth motion: 1.752
# [DEBUG] Motion level: 3.411, Smooth motion: 2.156
# [DEBUG] Motion level: 2.928, Smooth motion: 2.468
# [DEBUG] Motion level: 3.166, Smooth motion: 2.723
# [DEBUG] Motion level: 3.430, Smooth motion: 3.018
# [DEBUG] Motion level: 5.258, Smooth motion: 3.639
# [DEBUG] Motion level: 4.453, Smooth motion: 3.847
# [DEBUG] Motion level: 4.243, Smooth motion: 4.110
# [DEBUG] Motion level: 5.525, Smooth motion: 4.582
# [DEBUG] Motion level: 4.252, Smooth motion: 4.746
# [DEBUG] Motion level: 4.221, Smooth motion: 4.539
# [DEBUG] Motion level: 6.879, Smooth motion: 5.024
# [DEBUG] Motion level: 4.682, Smooth motion: 5.112
# [DEBUG] Motion level: 5.008, Smooth motion: 5.009
# [DEBUG] Motion level: 8.730, Smooth motion: 5.904
# [DEBUG] Motion level: 5.759, Smooth motion: 6.212
# [DEBUG] Motion level: 9.619, Smooth motion: 6.760
# [DEBUG] Motion level: 5.828, Smooth motion: 6.989
# [DEBUG] Motion level: 5.631, Smooth motion: 7.113
# [DEBUG] Motion level: 8.683, Smooth motion: 7.104
# [DEBUG] Motion level: 4.659, Smooth motion: 6.884
# [DEBUG] Motion level: 6.604, Smooth motion: 6.281
# [DEBUG] Motion level: 3.606, Smooth motion: 5.837
# [DEBUG] Motion level: 5.764, Smooth motion: 5.863
# [DEBUG] Motion level: 3.585, Smooth motion: 4.844
# [DEBUG] Motion level: 5.424, Smooth motion: 4.997
# [DEBUG] Motion level: 3.383, Smooth motion: 4.352
# [DEBUG] Motion level: 3.247, Smooth motion: 4.281
# [DEBUG] Motion level: 3.109, Smooth motion: 3.750
# [DEBUG] Motion level: 4.202, Smooth motion: 3.873
# [DEBUG] Motion level: 2.966, Smooth motion: 3.381
# [DEBUG] Motion level: 4.353, Smooth motion: 3.575
# [DEBUG] Motion level: 4.269, Smooth motion: 3.780
# [DEBUG] Motion level: 2.939, Smooth motion: 3.746
# [DEBUG] Motion level: 4.352, Smooth motion: 3.776
# [DEBUG] Motion level: 2.865, Smooth motion: 3.756
# [DEBUG] Normalized buffer shape: (30, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [DYNAMIC] Predicted: F (conf: 0.93)
# [INFO] Recognized dynamic gesture: F with confidence 0.93
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.763, Smooth motion: 3.438
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 4.035, Smooth motion: 3.391
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.631, Smooth motion: 3.329
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.482, Smooth motion: 2.955
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 5.130, Smooth motion: 3.408
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.111, Smooth motion: 3.278
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.655, Smooth motion: 3.002
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.860, Smooth motion: 2.848
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.811, Smooth motion: 2.713
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.183, Smooth motion: 2.124
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.611, Smooth motion: 2.024
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.820, Smooth motion: 1.857
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.515, Smooth motion: 1.788
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.503, Smooth motion: 1.726
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.471, Smooth motion: 1.584
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.627, Smooth motion: 1.587
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.936, Smooth motion: 1.810
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.473, Smooth motion: 1.802
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.514, Smooth motion: 1.804
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.431, Smooth motion: 1.796
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.524, Smooth motion: 1.776
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.192, Smooth motion: 1.627
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.943, Smooth motion: 1.721
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.044, Smooth motion: 1.827
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.153, Smooth motion: 1.971
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.162, Smooth motion: 2.299
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.352, Smooth motion: 2.331
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.426, Smooth motion: 2.427
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.561, Smooth motion: 2.531
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.799, Smooth motion: 2.860
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.102, Smooth motion: 2.848
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.463, Smooth motion: 3.070
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 4.510, Smooth motion: 3.487
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.360, Smooth motion: 3.647
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.936, Smooth motion: 3.674
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.892, Smooth motion: 3.832
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.879, Smooth motion: 3.715
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.752, Smooth motion: 3.564
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.772, Smooth motion: 3.646
# ...
# [DEBUG] Motion level: 1.354, Smooth motion: 1.410
# [DEBUG] Motion level: 1.355, Smooth motion: 1.414
# [DEBUG] Motion level: 1.405, Smooth motion: 1.378
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.339, Smooth motion: 1.376
# [DEBUG] Motion level: 1.332, Smooth motion: 1.357
# [DEBUG] Motion level: 1.344, Smooth motion: 1.355
# [DEBUG] Motion level: 1.328, Smooth motion: 1.350
# [DEBUG] Motion level: 1.356, Smooth motion: 1.340
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.333, Smooth motion: 1.339
# [DEBUG] Motion level: 1.333, Smooth motion: 1.339
# [DEBUG] Motion level: 1.323, Smooth motion: 1.335
# [DEBUG] Motion level: 1.349, Smooth motion: 1.339
# [DEBUG] Motion level: 1.382, Smooth motion: 1.344
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: E (conf: 0.24)
# [DEBUG] Motion level: 1.344, Smooth motion: 1.346
# [DEBUG] Motion level: 1.367, Smooth motion: 1.353
# [DEBUG] Motion level: 1.332, Smooth motion: 1.355
# [DEBUG] Motion level: 1.372, Smooth motion: 1.360
# [DEBUG] Motion level: 1.428, Smooth motion: 1.369
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: E (conf: 0.24)
# [DEBUG] Motion level: 1.333, Smooth motion: 1.366
# [DEBUG] Motion level: 1.347, Smooth motion: 1.362
# [DEBUG] Motion level: 1.326, Smooth motion: 1.361
# [DEBUG] Motion level: 1.339, Smooth motion: 1.354
# [DEBUG] Motion level: 1.337, Smooth motion: 1.336
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.319, Smooth motion: 1.333
# [DEBUG] Motion level: 1.331, Smooth motion: 1.330
# [DEBUG] Motion level: 1.339, Smooth motion: 1.333
# [DEBUG] Motion level: 1.325, Smooth motion: 1.330
# [DEBUG] Motion level: 1.365, Smooth motion: 1.336
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: E (conf: 0.22)
# [DEBUG] Motion level: 1.333, Smooth motion: 1.339
# [DEBUG] Motion level: 1.318, Smooth motion: 1.336
# [DEBUG] Motion level: 1.326, Smooth motion: 1.334
# [DEBUG] Motion level: 1.319, Smooth motion: 1.332
# [DEBUG] Motion level: 1.380, Smooth motion: 1.335
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: E (conf: 0.20)
# [DEBUG] Motion level: 1.352, Smooth motion: 1.339
# [DEBUG] Motion level: 1.341, Smooth motion: 1.344
# [DEBUG] Motion level: 1.332, Smooth motion: 1.345
# [DEBUG] Motion level: 1.322, Smooth motion: 1.345
# [DEBUG] Motion level: 1.370, Smooth motion: 1.343
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.338, Smooth motion: 1.341
# [DEBUG] Motion level: 1.330, Smooth motion: 1.339
# [DEBUG] Motion level: 1.370, Smooth motion: 1.346
# [DEBUG] Motion level: 1.326, Smooth motion: 1.347
# [DEBUG] Motion level: 1.365, Smooth motion: 1.346
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [STATIC] Predicted: E (conf: 0.22)
# [DEBUG] Motion level: 1.337, Smooth motion: 1.346
# [DEBUG] Motion level: 1.342, Smooth motion: 1.348
# [DEBUG] Motion level: 1.324, Smooth motion: 1.339
# [DEBUG] Motion level: 1.337, Smooth motion: 1.341
# [DEBUG] Motion level: 1.348, Smooth motion: 1.338
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.323, Smooth motion: 1.335
# [DEBUG] Motion level: 1.329, Smooth motion: 1.332
# [DEBUG] Motion level: 1.324, Smooth motion: 1.332
# [DEBUG] Motion level: 1.340, Smooth motion: 1.333
# [DEBUG] Motion level: 1.347, Smooth motion: 1.333
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.341, Smooth motion: 1.336
# [DEBUG] Motion level: 1.325, Smooth motion: 1.336
# [DEBUG] Motion level: 1.333, Smooth motion: 1.338
# [DEBUG] Motion level: 1.322, Smooth motion: 1.334
# [DEBUG] Motion level: 1.344, Smooth motion: 1.333
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.332, Smooth motion: 1.331
# [DEBUG] Motion level: 1.321, Smooth motion: 1.331
# [DEBUG] Motion level: 1.327, Smooth motion: 1.329
# [DEBUG] Motion level: 1.372, Smooth motion: 1.339
# [DEBUG] Motion level: 1.518, Smooth motion: 1.374
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: E (conf: 0.22)
# [DEBUG] Motion level: 1.373, Smooth motion: 1.382
# [DEBUG] Motion level: 1.416, Smooth motion: 1.401
# [DEBUG] Motion level: 1.350, Smooth motion: 1.406
# [DEBUG] Motion level: 1.339, Smooth motion: 1.399
# [DEBUG] Motion level: 1.462, Smooth motion: 1.388
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: E (conf: 0.24)
# [DEBUG] Motion level: 1.339, Smooth motion: 1.381
# [DEBUG] Motion level: 1.334, Smooth motion: 1.365
# [DEBUG] Motion level: 1.358, Smooth motion: 1.366
# [DEBUG] Motion level: 1.401, Smooth motion: 1.379
# [DEBUG] Motion level: 1.516, Smooth motion: 1.390
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.400, Smooth motion: 1.402
# [DEBUG] Motion level: 1.341, Smooth motion: 1.403
# [DEBUG] Motion level: 1.377, Smooth motion: 1.407
# [DEBUG] Motion level: 1.338, Smooth motion: 1.394
# [DEBUG] Motion level: 1.381, Smooth motion: 1.367
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.327, Smooth motion: 1.353
# [DEBUG] Motion level: 1.333, Smooth motion: 1.351
# [DEBUG] Motion level: 1.338, Smooth motion: 1.343
# [DEBUG] Motion level: 1.323, Smooth motion: 1.340
# [DEBUG] Motion level: 1.433, Smooth motion: 1.351
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: E (conf: 0.22)
# [DEBUG] Motion level: 1.332, Smooth motion: 1.352
# [DEBUG] Motion level: 1.329, Smooth motion: 1.351
# [DEBUG] Motion level: 1.344, Smooth motion: 1.352
# [DEBUG] Motion level: 1.344, Smooth motion: 1.356
# [DEBUG] Motion level: 1.506, Smooth motion: 1.371
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.333, Smooth motion: 1.371
# [DEBUG] Motion level: 1.329, Smooth motion: 1.371
# [DEBUG] Motion level: 1.344, Smooth motion: 1.371
# [DEBUG] Motion level: 1.325, Smooth motion: 1.367
# [DEBUG] Motion level: 1.394, Smooth motion: 1.345
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [STATIC] Predicted: E (conf: 0.22)
# [DEBUG] Motion level: 1.322, Smooth motion: 1.343
# [DEBUG] Motion level: 1.327, Smooth motion: 1.343
# [DEBUG] Motion level: 1.323, Smooth motion: 1.338
# [DEBUG] Motion level: 1.333, Smooth motion: 1.340
# [DEBUG] Motion level: 1.406, Smooth motion: 1.342
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: E (conf: 0.22)
# [DEBUG] Motion level: 1.328, Smooth motion: 1.344
# [DEBUG] Motion level: 1.339, Smooth motion: 1.346
# [DEBUG] Motion level: 1.330, Smooth motion: 1.347
# [DEBUG] Motion level: 1.343, Smooth motion: 1.349
# [DEBUG] Motion level: 1.351, Smooth motion: 1.338
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: E (conf: 0.23)
# [DEBUG] Motion level: 1.336, Smooth motion: 1.340
# [DEBUG] Motion level: 1.327, Smooth motion: 1.337
# [DEBUG] Motion level: 1.324, Smooth motion: 1.336
# [DEBUG] Motion level: 1.338, Smooth motion: 1.335
# [DEBUG] Motion level: 1.492, Smooth motion: 1.364
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: E (conf: 0.22)
# [DEBUG] Motion level: 2.369, Smooth motion: 1.570
# [DEBUG] Motion level: 2.172, Smooth motion: 1.739
# [DEBUG] Motion level: 2.135, Smooth motion: 1.901
# [DEBUG] Motion level: 2.243, Smooth motion: 2.082
# [DEBUG] Motion level: 2.231, Smooth motion: 2.230
# [DEBUG] Motion level: 1.512, Smooth motion: 2.059
# [DEBUG] Motion level: 1.950, Smooth motion: 2.014
# [DEBUG] Motion level: 1.703, Smooth motion: 1.928
# [DEBUG] Motion level: 2.329, Smooth motion: 1.945
# [DEBUG] Motion level: 1.587, Smooth motion: 1.816
# [DEBUG] Motion level: 1.599, Smooth motion: 1.833
# [DEBUG] Motion level: 1.375, Smooth motion: 1.718
# [DEBUG] Motion level: 1.381, Smooth motion: 1.654
# [DEBUG] Motion level: 1.487, Smooth motion: 1.486
# [DEBUG] Motion level: 1.499, Smooth motion: 1.468
# [DEBUG] Motion level: 1.476, Smooth motion: 1.444
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: E (conf: 0.22)
# [DEBUG] Motion level: 1.846, Smooth motion: 1.538
# [DEBUG] Motion level: 1.703, Smooth motion: 1.602
# [DEBUG] Motion level: 2.685, Smooth motion: 1.842
# [DEBUG] Motion level: 2.128, Smooth motion: 1.968
# [DEBUG] Motion level: 5.843, Smooth motion: 2.841
# [DEBUG] Motion level: 2.967, Smooth motion: 3.065
# [DEBUG] Motion level: 5.039, Smooth motion: 3.732
# [DEBUG] Motion level: 3.292, Smooth motion: 3.854
# [DEBUG] Motion level: 5.498, Smooth motion: 4.528
# [DEBUG] Motion level: 3.486, Smooth motion: 4.056
# [DEBUG] Motion level: 5.853, Smooth motion: 4.633
# [DEBUG] Motion level: 3.604, Smooth motion: 4.347
# [DEBUG] Motion level: 3.564, Smooth motion: 4.401
# [DEBUG] Motion level: 5.693, Smooth motion: 4.440
# [DEBUG] Motion level: 3.414, Smooth motion: 4.426
# [DEBUG] Motion level: 5.315, Smooth motion: 4.318
# [DEBUG] Motion level: 3.074, Smooth motion: 4.212
# [DEBUG] Motion level: 2.938, Smooth motion: 4.087
# [DEBUG] Motion level: 4.321, Smooth motion: 3.812
# [DEBUG] Motion level: 2.519, Smooth motion: 3.633
# [DEBUG] Motion level: 3.774, Smooth motion: 3.325
# [DEBUG] Motion level: 3.162, Smooth motion: 3.343
# [DEBUG] Motion level: 1.959, Smooth motion: 3.147
# [DEBUG] Motion level: 1.890, Smooth motion: 2.661
# [DEBUG] Motion level: 2.434, Smooth motion: 2.644
# [DEBUG] Motion level: 1.685, Smooth motion: 2.226
# [DEBUG] Motion level: 1.587, Smooth motion: 1.911
# [DEBUG] Motion level: 1.499, Smooth motion: 1.819
# [DEBUG] Motion level: 1.525, Smooth motion: 1.746
# [DEBUG] Motion level: 1.392, Smooth motion: 1.538
# [DEBUG] Motion level: 1.528, Smooth motion: 1.506
# [DEBUG] Motion level: 1.407, Smooth motion: 1.470
# [DEBUG] Motion level: 1.413, Smooth motion: 1.453
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: E (conf: 0.27)
# [DEBUG] Motion level: 1.382, Smooth motion: 1.424
# [DEBUG] Motion level: 1.467, Smooth motion: 1.439
# [DEBUG] Motion level: 1.395, Smooth motion: 1.413
# [DEBUG] Motion level: 1.467, Smooth motion: 1.425
# [DEBUG] Motion level: 1.818, Smooth motion: 1.506
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: E (conf: 0.26)
# [DEBUG] Motion level: 1.386, Smooth motion: 1.507
# [DEBUG] Motion level: 1.494, Smooth motion: 1.512
# [DEBUG] Motion level: 1.425, Smooth motion: 1.518
# [DEBUG] Motion level: 1.454, Smooth motion: 1.515
# [DEBUG] Motion level: 3.384, Smooth motion: 1.829
# [DEBUG] Motion level: 2.008, Smooth motion: 1.953
# [DEBUG] Motion level: 2.688, Smooth motion: 2.192
# [DEBUG] Motion level: 1.892, Smooth motion: 2.285
# [DEBUG] Motion level: 1.917, Smooth motion: 2.378
# [DEBUG] Motion level: 1.936, Smooth motion: 2.088
# [DEBUG] Motion level: 2.748, Smooth motion: 2.236
# [DEBUG] Motion level: 2.016, Smooth motion: 2.102
# [DEBUG] Motion level: 1.976, Smooth motion: 2.119
# [DEBUG] Motion level: 1.946, Smooth motion: 2.124
# [DEBUG] Motion level: 2.819, Smooth motion: 2.301
# [DEBUG] Motion level: 1.816, Smooth motion: 2.115
# [DEBUG] Motion level: 1.620, Smooth motion: 2.035
# [DEBUG] Motion level: 1.508, Smooth motion: 1.942
# [DEBUG] Motion level: 1.790, Smooth motion: 1.911
# [DEBUG] Motion level: 1.609, Smooth motion: 1.669
# [DEBUG] Motion level: 1.612, Smooth motion: 1.628
# [DEBUG] Motion level: 1.705, Smooth motion: 1.645
# [DEBUG] Motion level: 2.170, Smooth motion: 1.777
# [DEBUG] Motion level: 1.542, Smooth motion: 1.727
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: E (conf: 0.24)
# [DEBUG] Motion level: 1.502, Smooth motion: 1.706
# [DEBUG] Motion level: 2.004, Smooth motion: 1.785
# [DEBUG] Motion level: 1.668, Smooth motion: 1.777
# [DEBUG] Motion level: 1.981, Smooth motion: 1.739
# [DEBUG] Motion level: 1.871, Smooth motion: 1.805
# [DEBUG] Motion level: 1.496, Smooth motion: 1.804
# [DEBUG] Motion level: 1.386, Smooth motion: 1.680
# [DEBUG] Motion level: 1.482, Smooth motion: 1.643
# [DEBUG] Motion level: 1.390, Smooth motion: 1.525
# [DEBUG] Motion level: 1.389, Smooth motion: 1.428
# [DEBUG] Motion level: 1.583, Smooth motion: 1.446
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: E (conf: 0.27)
# [DEBUG] Motion level: 1.371, Smooth motion: 1.443
# [DEBUG] Motion level: 1.377, Smooth motion: 1.422
# [DEBUG] Motion level: 1.463, Smooth motion: 1.436
# [DEBUG] Motion level: 1.397, Smooth motion: 1.438
# [DEBUG] Motion level: 2.015, Smooth motion: 1.525
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: E (conf: 0.26)
# [DEBUG] Motion level: 1.489, Smooth motion: 1.548
# [DEBUG] Motion level: 1.801, Smooth motion: 1.633
# [DEBUG] Motion level: 1.534, Smooth motion: 1.647
# [DEBUG] Motion level: 1.544, Smooth motion: 1.677
# [DEBUG] Motion level: 3.221, Smooth motion: 1.918
# [DEBUG] Motion level: 2.428, Smooth motion: 2.106
# [DEBUG] Motion level: 4.946, Smooth motion: 2.735
# [DEBUG] Motion level: 4.675, Smooth motion: 3.363
# [DEBUG] Motion level: 4.945, Smooth motion: 4.043
# [DEBUG] Motion level: 6.336, Smooth motion: 4.666
# [DEBUG] Motion level: 3.836, Smooth motion: 4.948
# [DEBUG] Motion level: 3.374, Smooth motion: 4.633
# [DEBUG] Motion level: 3.567, Smooth motion: 4.412
# [DEBUG] Motion level: 2.337, Smooth motion: 3.890
# [DEBUG] Motion level: 3.348, Smooth motion: 3.293
# [DEBUG] Motion level: 3.698, Smooth motion: 3.265
# [DEBUG] Motion level: 3.242, Smooth motion: 3.238
# [DEBUG] Motion level: 2.286, Smooth motion: 2.982
# [DEBUG] Motion level: 2.379, Smooth motion: 2.990
# [DEBUG] Motion level: 3.949, Smooth motion: 3.111
# [DEBUG] Motion level: 2.495, Smooth motion: 2.870
# [DEBUG] Motion level: 2.453, Smooth motion: 2.712
# [DEBUG] Motion level: 3.757, Smooth motion: 3.007
# [DEBUG] Motion level: 2.600, Smooth motion: 3.051
# [DEBUG] Motion level: 4.148, Smooth motion: 3.091
# [DEBUG] Motion level: 2.771, Smooth motion: 3.146
# [DEBUG] Motion level: 3.872, Smooth motion: 3.430
# [DEBUG] Motion level: 2.665, Smooth motion: 3.211
# [DEBUG] Motion level: 2.953, Smooth motion: 3.282
# [DEBUG] Motion level: 3.918, Smooth motion: 3.236
# [DEBUG] Motion level: 2.766, Smooth motion: 3.235
# [DEBUG] Motion level: 4.084, Smooth motion: 3.277
# [DEBUG] Motion level: 2.254, Smooth motion: 3.195
# [DEBUG] Motion level: 5.143, Smooth motion: 3.633
# [DEBUG] Motion level: 2.673, Smooth motion: 3.384
# [DEBUG] Motion level: 2.760, Smooth motion: 3.383
# [DEBUG] Motion level: 5.395, Smooth motion: 3.645
# [DEBUG] Motion level: 3.386, Smooth motion: 3.871
# [DEBUG] Motion level: 3.371, Smooth motion: 3.517
# [DEBUG] Motion level: 3.528, Smooth motion: 3.688
# [DEBUG] Motion level: 5.129, Smooth motion: 4.162
# [DEBUG] Motion level: 2.809, Smooth motion: 3.645
# [DEBUG] Motion level: 2.592, Smooth motion: 3.486
# [DEBUG] Motion level: 2.266, Smooth motion: 3.265
# [DEBUG] Motion level: 3.402, Smooth motion: 3.240
# [DEBUG] Motion level: 1.895, Smooth motion: 2.593
# [DEBUG] Motion level: 1.847, Smooth motion: 2.400
# [DEBUG] Motion level: 1.911, Smooth motion: 2.264
# [DEBUG] Motion level: 1.854, Smooth motion: 2.182
# [DEBUG] Motion level: 1.668, Smooth motion: 1.835
# [DEBUG] Motion level: 1.626, Smooth motion: 1.781
# [DEBUG] Motion level: 1.620, Smooth motion: 1.736
# [DEBUG] Motion level: 1.578, Smooth motion: 1.669
# [DEBUG] Motion level: 1.611, Smooth motion: 1.620

# %%
import cv2
import mediapipe as mp
import numpy as np
from tensorflow.keras.models import load_model
import joblib

# Załaduj modele
model_static = load_model('../model/StaticBiLSTM/static_gestures_model.keras')
label_encoder_static = joblib.load('../model/StaticBiLSTM/static_gestures_labels.pkl')

model_dynamic = load_model('../model/DynamicBiLSTM/dynamic_gestures_model.keras')
label_encoder_dynamic = joblib.load('../model/DynamicBiLSTM/dynamic_gestures_labels.pkl')

# Parametry
motion_threshold = 1.8
motion_history = []
motion_history_len = 5
cooldown_frames = 0
cooldown_threshold = 10
recognized_sign = ''
recognized_type = ''
last_prediction = None
static_buffer = []
dynamic_buffer = []

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

def normalize_landmarks_buffer(buffer):
    buffer = np.array(buffer)
    if buffer.shape[0] == 0:
        return np.zeros((1, 63))
    wrist_ref = buffer[0, 3:6]  # landmark_1 x,y,z
    norm_buffer = buffer.copy()
    for i in range(1, 21):
        norm_buffer[:, i*3:(i+1)*3] -= wrist_ref
    return norm_buffer

def extract_right_hand_landmarks(results):
    if results.right_hand_landmarks:
        return [coord for lm in results.right_hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]
    return None

def get_hand_bbox(landmarks, image_width, image_height):
    xs = [lm.x * image_width for lm in landmarks.landmark]
    ys = [lm.y * image_height for lm in landmarks.landmark]
    x_min, x_max = max(int(min(xs)), 0), min(int(max(xs)), image_width)
    y_min, y_max = max(int(min(ys)), 0), min(int(max(ys)), image_height)
    return (x_min, y_min, x_max, y_max)

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

ret, prev_frame = cap.read()
prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        curr_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame_diff = cv2.absdiff(prev_gray, curr_gray)
        motion_level = np.sum(frame_diff) / (frame.shape[0] * frame.shape[1])
        prev_gray = curr_gray.copy()

        motion_history.append(motion_level)
        if len(motion_history) > motion_history_len:
            motion_history.pop(0)
        smooth_motion = np.mean(motion_history)

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image_rgb)
        image_height, image_width, _ = frame.shape

        landmarks = extract_right_hand_landmarks(results)

        if landmarks:
            mp_drawing.draw_landmarks(frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
            bbox = get_hand_bbox(results.right_hand_landmarks, image_width, image_height)
            x1, y1, x2, y2 = bbox
            box_color = (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)

            if smooth_motion < motion_threshold:
                dynamic_buffer.clear()
                static_buffer.append(landmarks)
                if len(static_buffer) >= 5 and cooldown_frames == 0:
                    norm_static = normalize_landmarks_buffer(static_buffer)
                    if norm_static.shape[0] == 5:
                        norm_static = np.expand_dims(norm_static, axis=0)
                        prediction = model_static.predict(norm_static, verbose=0)[0]
                        label = label_encoder_static.inverse_transform([np.argmax(prediction)])[0]
                        conf = np.max(prediction)
                        if conf > 0.8 and label != last_prediction:
                            recognized_sign = label
                            recognized_type = "Statyczny"
                            last_prediction = label
                            cooldown_frames = cooldown_threshold
                            static_buffer.clear()
                            dynamic_buffer.clear()
            else:
                static_buffer.clear()
                dynamic_buffer.append(landmarks)
                if len(dynamic_buffer) >= 30 and cooldown_frames == 0:
                    norm_dynamic = normalize_landmarks_buffer(dynamic_buffer)
                    if norm_dynamic.shape[0] == 30:
                        norm_dynamic = np.expand_dims(norm_dynamic, axis=0)
                        prediction = model_dynamic.predict(norm_dynamic, verbose=0)[0]
                        label = label_encoder_dynamic.inverse_transform([np.argmax(prediction)])[0]
                        conf = np.max(prediction)
                        if conf > 0.8 and label != last_prediction:
                            recognized_sign = label
                            recognized_type = "Dynamiczny"
                            last_prediction = label
                            cooldown_frames = cooldown_threshold
                            static_buffer.clear()
                            dynamic_buffer.clear()

            if recognized_sign and recognized_type:
                label_text = f'{recognized_sign} ({recognized_type})'
                label_pos_x = image_width // 2
                label_pos_y = 30
                (text_width, _), _ = cv2.getTextSize(label_text, cv2.FONT_HERSHEY_SIMPLEX, 1.0, 3)
                text_x = label_pos_x - text_width // 2
                cv2.putText(frame, label_text, (text_x, label_pos_y), cv2.FONT_HERSHEY_SIMPLEX,
                            1.0, (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0), 3, cv2.LINE_AA)
        else:
            static_buffer.clear()
            dynamic_buffer.clear()
            recognized_sign = ''
            recognized_type = ''
            last_prediction = None

        cooldown_frames = max(0, cooldown_frames - 1)

        cv2.imshow('Sign Language Recognition', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1748775680.951385   40494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1748775680.952764   42313 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1-1ubuntu3.1~22.04.3), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1748775681.097379   42305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775681.161450   42303 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775681.168611   42308 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775681.170577   42305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775681.172904   42309 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775681.180297   42304 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775681.185393   42306 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748775681.193146   42307 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
