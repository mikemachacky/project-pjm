# %%
# !pip install mediapipe numpy opencv-python tensorflow[and-cuda] pandas joblib
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.21-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting numpy
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting joblib
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting tensorflow[and-cuda]
#   Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py (from mediapipe)
#   Downloading absl_py-2.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: attrs>=19.1.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from mediapipe) (25.3.0)
# Collecting flatbuffers>=2.0 (from mediapipe)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting jax (from mediapipe)
#   Downloading jax-0.6.1-py3-none-any.whl.metadata (13 kB)
# Collecting jaxlib (from mediapipe)
#   Downloading jaxlib-0.6.1-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting matplotlib (from mediapipe)
#   Downloading matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting sentencepiece (from mediapipe)
#   Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting astunparse>=1.6.0 (from tensorflow[and-cuda])
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow[and-cuda])
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow[and-cuda])
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow[and-cuda])
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow[and-cuda])
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (25.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.32.3)
# Requirement already satisfied: setuptools in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow[and-cuda])
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from tensorflow[and-cuda]) (4.13.2)
# Collecting wrapt>=1.11.0 (from tensorflow[and-cuda])
#   Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow[and-cuda])
#   Downloading grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow[and-cuda])
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow[and-cuda])
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting h5py>=3.11.0 (from tensorflow[and-cuda])
#   Downloading h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow[and-cuda])
#   Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting nvidia-cublas-cu12==12.5.3.2 (from tensorflow[and-cuda])
#   Downloading nvidia_cublas_cu12-12.5.3.2-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_cuda_cupti_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvcc-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_cuda_nvcc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_cuda_nvrtc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_cuda_runtime_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12==9.3.0.75 (from tensorflow[and-cuda])
#   Downloading nvidia_cudnn_cu12-9.3.0.75-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12==11.2.3.61 (from tensorflow[and-cuda])
#   Downloading nvidia_cufft_cu12-11.2.3.61-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.6.82 (from tensorflow[and-cuda])
#   Downloading nvidia_curand_cu12-10.3.6.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.3.83 (from tensorflow[and-cuda])
#   Downloading nvidia_cusolver_cu12-11.6.3.83-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.1.3 (from tensorflow[and-cuda])
#   Downloading nvidia_cusparse_cu12-12.5.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.23.4 (from tensorflow[and-cuda])
#   Downloading nvidia_nccl_cu12-2.23.4-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.5.82 (from tensorflow[and-cuda])
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2025.4.26)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow[and-cuda])
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow[and-cuda])
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow[and-cuda])
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow[and-cuda])
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.5.0->tensorflow[and-cuda])
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow[and-cuda])
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow[and-cuda])
#   Downloading optree-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: CFFI>=1.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow[and-cuda]) (3.0.2)
# Collecting scipy>=1.11.1 (from jax->mediapipe)
#   Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->mediapipe)
#   Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapipe)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mediapipe)
#   Downloading fonttools-4.58.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapipe)
#   Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting pillow>=8 (from matplotlib->mediapipe)
#   Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->mediapipe)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow[and-cuda])
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/magda/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow[and-cuda]) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow[and-cuda])
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading mediapipe-0.10.21-cp312-cp312-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 32.0 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 33.3 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 33.3 MB/s eta 0:00:0000:0100:01
# Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (645.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 27.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.5.3.2-py3-none-manylinux2014_x86_64.whl (363.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.3/363.3 MB 30.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 30.5 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cuda_nvcc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (22.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 34.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 32.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (895 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 895.7/895.7 kB 25.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.3.0.75-py3-none-manylinux2014_x86_64.whl (577.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.2/577.2 MB 28.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.2.3.61-py3-none-manylinux2014_x86_64.whl (192.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 MB 34.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.6.82-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.6.3.83-py3-none-manylinux2014_x86_64.whl (130.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 MB 33.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.5.1.3-py3-none-manylinux2014_x86_64.whl (217.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.6/217.6 MB 34.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.23.4-py3-none-manylinux2014_x86_64.whl (199.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.0/199.0 MB 34.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 33.9 MB/s eta 0:00:0000:0100:01
# Downloading grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 32.3 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 30.7 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 31.3 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 31.2 MB/s eta 0:00:0000:01
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 32.9 MB/s eta 0:00:00 0:00:01
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading absl_py-2.3.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 32.6 MB/s eta 0:00:00
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 27.6 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 33.5 MB/s eta 0:00:0000:0100:01
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading sounddevice-0.5.2-py3-none-any.whl (32 kB)
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
# Downloading jax-0.6.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 30.0 MB/s eta 0:00:00
# Downloading jaxlib-0.6.1-cp312-cp312-manylinux2014_x86_64.whl (89.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 MB 34.3 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 33.8 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 32.3 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 32.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 29.1 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 32.1 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading opencv_contrib_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 33.8 MB/s eta 0:00:0000:0100:01
# Downloading optree-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.8 MB/s eta 0:00:00
# Installing collected packages: sentencepiece, pytz, namex, libclang, flatbuffers, wrapt, wheel, werkzeug, tzdata, termcolor, tensorboard-data-server, pyparsing, protobuf, pillow, optree, opt-einsum, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-nvcc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, mdurl, markdown, kiwisolver, joblib, grpcio, google-pasta, gast, fonttools, cycler, absl-py, tensorboard, sounddevice, scipy, pandas, opencv-python, opencv-contrib-python, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, ml-dtypes, markdown-it-py, h5py, contourpy, astunparse, rich, nvidia-cusolver-cu12, matplotlib, jaxlib, keras, jax, tensorflow, mediapipe
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57/57 [mediapipe]ediapipe]ensorflow]lver-cu12]]]2]
# Successfully installed absl-py-2.3.0 astunparse-1.6.3 contourpy-1.3.2 cycler-0.12.1 flatbuffers-25.2.10 fonttools-4.58.1 gast-0.6.0 google-pasta-0.2.0 grpcio-1.71.0 h5py-3.13.0 jax-0.6.1 jaxlib-0.6.1 joblib-1.5.1 keras-3.10.0 kiwisolver-1.4.8 libclang-18.1.1 markdown-3.8 markdown-it-py-3.0.0 matplotlib-3.10.3 mdurl-0.1.2 mediapipe-0.10.21 ml-dtypes-0.5.1 namex-0.1.0 numpy-1.26.4 nvidia-cublas-cu12-12.5.3.2 nvidia-cuda-cupti-cu12-12.5.82 nvidia-cuda-nvcc-cu12-12.5.82 nvidia-cuda-nvrtc-cu12-12.5.82 nvidia-cuda-runtime-cu12-12.5.82 nvidia-cudnn-cu12-9.3.0.75 nvidia-cufft-cu12-11.2.3.61 nvidia-curand-cu12-10.3.6.82 nvidia-cusolver-cu12-11.6.3.83 nvidia-cusparse-cu12-12.5.1.3 nvidia-nccl-cu12-2.23.4 nvidia-nvjitlink-cu12-12.5.82 opencv-contrib-python-4.11.0.86 opencv-python-4.11.0.86 opt-einsum-3.4.0 optree-0.16.0 pandas-2.2.3 pillow-11.2.1 protobuf-4.25.8 pyparsing-3.2.3 pytz-2025.2 rich-14.0.0 scipy-1.15.3 sentencepiece-0.2.0 sounddevice-0.5.2 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 termcolor-3.1.0 tzdata-2025.2 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.2

# %%
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
import joblib

# Załaduj modele
model_static = load_model('../model/StaticBiLSTM/static_gestures_model.keras')
label_encoder_static = joblib.load('../model/StaticBiLSTM/static_gestures_labels.pkl')

model_dynamic = load_model('../model/DynamicBiLSTM/dynamic_gestures_model.keras')
label_encoder_dynamic = joblib.load('../model/DynamicBiLSTM/dynamic_gestures_labels.pkl')

# Parametry
motion_threshold = 1.8  # Próg rozróżnienia statyczny/dynamiczny
motion_history = []
motion_history_len = 5
cooldown_frames = 0
cooldown_threshold = 10
recognized_sign = ''
recognized_type = ''
last_prediction = None
static_buffer = []
dynamic_buffer = []

# MediaPipe
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils
def normalize_landmarks_buffer(buffer):
    data = []
    for frame_idx, row in enumerate(buffer):
        if len(row) != 63:
            print(f"[WARNING] Frame {frame_idx} has invalid length {len(row)}")
            continue
        frame_data = {'frame': frame_idx}
        for i in range(21):
            frame_data[f'landmark_{i}_x'] = row[i * 3]
            frame_data[f'landmark_{i}_y'] = row[i * 3 + 1]
            frame_data[f'landmark_{i}_z'] = row[i * 3 + 2]
        data.append(frame_data)

    if len(data) == 0:
        print("[WARNING] No valid frames in buffer")
        return np.zeros((1, 63))

    df = pd.DataFrame(data)
    df = df.sort_values("frame").copy()

    wrist_ref = {
        axis: df[df["frame"] == 0].iloc[0][f"landmark_1_{axis}"]
        for axis in ['x', 'y', 'z']
    }

    for axis in ['x', 'y', 'z']:
        for i in range(1, 21):
            col = f'landmark_{i}_{axis}'
            df[col] = df[col] - wrist_ref[axis]

    norm_buffer = []
    for _, row in df.iterrows():
        landmarks = []
        for i in range(21):
            landmarks.extend([
                row[f'landmark_{i}_x'],
                row[f'landmark_{i}_y'],
                row[f'landmark_{i}_z']
            ])
        norm_buffer.append(landmarks)

    norm_array = np.array(norm_buffer)
    print(f"[DEBUG] Normalized buffer shape: {norm_array.shape}")
    return norm_array

def extract_right_hand_landmarks(results):
    if results.right_hand_landmarks:
        return [coord for lm in results.right_hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]
    return None

def get_hand_bbox(landmarks, image_width, image_height):
    xs = [lm.x * image_width for lm in landmarks.landmark]
    ys = [lm.y * image_height for lm in landmarks.landmark]
    x_min, x_max = max(int(min(xs)), 0), min(int(max(xs)), image_width)
    y_min, y_max = max(int(min(ys)), 0), min(int(max(ys)), image_height)
    return (x_min, y_min, x_max, y_max)

# Inicjalizacja kamery
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

ret, prev_frame = cap.read()
prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        curr_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame_diff = cv2.absdiff(prev_gray, curr_gray)
        motion_level = np.sum(frame_diff) / (frame.shape[0] * frame.shape[1])
        prev_gray = curr_gray.copy()

        # Wygładzanie ruchu
        motion_history.append(motion_level)
        if len(motion_history) > motion_history_len:
            motion_history.pop(0)
        smooth_motion = np.mean(motion_history)

        print(f"[DEBUG] Motion level: {motion_level:.3f}, Smooth motion: {smooth_motion:.3f}")

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image_rgb)
        image_height, image_width, _ = frame.shape

        landmarks = extract_right_hand_landmarks(results)

        if landmarks:
            mp_drawing.draw_landmarks(
                frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

            bbox = get_hand_bbox(results.right_hand_landmarks, image_width, image_height)
            x1, y1, x2, y2 = bbox
            box_color = (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)

            if smooth_motion < motion_threshold:
                dynamic_buffer.clear()
                static_buffer.append(landmarks)
                # print(f"[DEBUG] Static buffer size: {len(static_buffer)}")
                if len(static_buffer) >= 5:
                    if cooldown_frames == 0:
                        # print("[DEBUG] Running static prediction...")
                        norm_static = normalize_landmarks_buffer(static_buffer)
                        if norm_static.shape[0] == 5:
                            norm_static = np.expand_dims(norm_static, axis=0)
                            prediction = model_static.predict(norm_static)[0]
                            label = label_encoder_static.inverse_transform([np.argmax(prediction)])[0]
                            conf = np.max(prediction)
                            print(f"[STATIC] Predicted: {label} (conf: {conf:.2f})")
                            if conf > 0.5 and label != last_prediction:
                               recognized_sign = label
                               recognized_type = "Statyczny"
                               last_prediction = label
                               cooldown_frames = cooldown_threshold
                               static_buffer.clear()
                               dynamic_buffer.clear()
                               print(f"[INFO] Recognized static gesture: {recognized_sign} with confidence {conf:.2f}")
                        else:
                            print("[WARNING] Normalized static buffer shape unexpected:", norm_static.shape)
                        static_buffer.clear()
                    else:
                        print(f"[DEBUG] Static prediction skipped due to cooldown: {cooldown_frames}")
            else:
                static_buffer.clear()
                dynamic_buffer.append(landmarks)
                # print(f"[DEBUG] Dynamic buffer size: {len(dynamic_buffer)}")
                if len(dynamic_buffer) >= 30:
                    if cooldown_frames == 0:
                        # print("[DEBUG] Running dynamic prediction...")
                        norm_dynamic = normalize_landmarks_buffer(dynamic_buffer)
                        if norm_dynamic.shape[0] == 30:
                            norm_dynamic = np.expand_dims(norm_dynamic, axis=0)
                            prediction = model_dynamic.predict(norm_dynamic)[0]
                            label = label_encoder_dynamic.inverse_transform([np.argmax(prediction)])[0]
                            conf = np.max(prediction)
                            print(f"[DYNAMIC] Predicted: {label} (conf: {conf:.2f})")
                            if conf > 0.5 and label != last_prediction:
                                recognized_sign = label
                                recognized_type = "Dynamiczny"
                                last_prediction = label
                                cooldown_frames = cooldown_threshold
                                static_buffer.clear()
                                dynamic_buffer.clear()
                                print(f"[INFO] Recognized dynamic gesture: {recognized_sign} with confidence {conf:.2f}")
                        else:
                            print("[WARNING] Normalized dynamic buffer shape unexpected:", norm_dynamic.shape)
                        dynamic_buffer.clear()
                    else:
                        print(f"[DEBUG] Dynamic prediction skipped due to cooldown: {cooldown_frames}")

            # Rysowanie labela na górze ekranu, wyśrodkowany
            if recognized_sign and recognized_type:
                label_text = f'{recognized_sign} ({recognized_type})'
                label_pos_x = image_width // 2
                label_pos_y = 30
                print(f"[DEBUG] Drawing label: {label_text} at ({label_pos_x}, {label_pos_y})")
                (text_width, text_height), baseline = cv2.getTextSize(
                    label_text, cv2.FONT_HERSHEY_SIMPLEX, 1.0, 3)
                text_x = label_pos_x - text_width // 2
                text_y = label_pos_y
                cv2.putText(
                    frame,
                    label_text,
                    (text_x, text_y),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1.0,
                    (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0),
                    3,
                    lineType=cv2.LINE_AA
                )
        else:
            static_buffer.clear()
            dynamic_buffer.clear()
            recognized_sign = ''
            recognized_type = ''
            last_prediction = None

        cooldown_frames = max(0, cooldown_frames - 1)

        cv2.imshow('Sign Language Recognition', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1748774948.380845   28916 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1748774948.381728   38706 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1-1ubuntu3.1~22.04.3), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1748774948.446154   38697 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774948.461765   38701 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774948.464360   38697 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774948.465118   38699 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774948.465330   38703 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774948.471536   38703 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774948.472632   38702 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774948.486098   38698 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# [DEBUG] Motion level: 1.513, Smooth motion: 1.513
# [DEBUG] Motion level: 1.431, Smooth motion: 1.472
# [DEBUG] Motion level: 1.482, Smooth motion: 1.475
# [DEBUG] Motion level: 1.617, Smooth motion: 1.511
# [DEBUG] Motion level: 1.423, Smooth motion: 1.493
# [DEBUG] Motion level: 1.555, Smooth motion: 1.502
# [DEBUG] Motion level: 1.460, Smooth motion: 1.508
# [DEBUG] Motion level: 2.632, Smooth motion: 1.737
# [DEBUG] Motion level: 1.518, Smooth motion: 1.718
# [DEBUG] Motion level: 1.450, Smooth motion: 1.723
# [DEBUG] Motion level: 1.399, Smooth motion: 1.692
# [DEBUG] Motion level: 1.360, Smooth motion: 1.672
# [DEBUG] Motion level: 1.394, Smooth motion: 1.424
# [DEBUG] Motion level: 1.385, Smooth motion: 1.398
# [DEBUG] Motion level: 1.481, Smooth motion: 1.404
# [DEBUG] Motion level: 1.376, Smooth motion: 1.399
# [DEBUG] Motion level: 1.390, Smooth motion: 1.405
# [DEBUG] Motion level: 1.428, Smooth motion: 1.412
# [DEBUG] Motion level: 1.505, Smooth motion: 1.436
# [DEBUG] Motion level: 1.422, Smooth motion: 1.424
# [DEBUG] Motion level: 1.446, Smooth motion: 1.438
# [DEBUG] Motion level: 1.449, Smooth motion: 1.450
# [DEBUG] Motion level: 1.637, Smooth motion: 1.492
# [DEBUG] Motion level: 3.364, Smooth motion: 1.864
# [DEBUG] Motion level: 1.610, Smooth motion: 1.901
# [DEBUG] Motion level: 1.653, Smooth motion: 1.943
# [DEBUG] Motion level: 1.530, Smooth motion: 1.959
# [DEBUG] Motion level: 1.550, Smooth motion: 1.941
# [DEBUG] Motion level: 1.561, Smooth motion: 1.581
# [DEBUG] Motion level: 1.580, Smooth motion: 1.574
# [DEBUG] Motion level: 1.625, Smooth motion: 1.569
# [DEBUG] Motion level: 1.570, Smooth motion: 1.577
# [DEBUG] Motion level: 1.598, Smooth motion: 1.587
# [DEBUG] Motion level: 1.573, Smooth motion: 1.589
# [DEBUG] Motion level: 1.687, Smooth motion: 1.611
# [DEBUG] Motion level: 1.715, Smooth motion: 1.629
# [DEBUG] Motion level: 1.620, Smooth motion: 1.639
# [DEBUG] Motion level: 1.580, Smooth motion: 1.635
# [DEBUG] Motion level: 3.788, Smooth motion: 2.078
# [DEBUG] Motion level: 1.608, Smooth motion: 2.062
# [DEBUG] Motion level: 1.616, Smooth motion: 2.042
# [DEBUG] Motion level: 1.626, Smooth motion: 2.043
# [DEBUG] Motion level: 1.631, Smooth motion: 2.054
# [DEBUG] Motion level: 1.646, Smooth motion: 1.625
# [DEBUG] Motion level: 1.690, Smooth motion: 1.642
# [DEBUG] Motion level: 1.620, Smooth motion: 1.643
# [DEBUG] Motion level: 1.610, Smooth motion: 1.639
# [DEBUG] Motion level: 1.615, Smooth motion: 1.636
# [DEBUG] Motion level: 1.608, Smooth motion: 1.629
# [DEBUG] Motion level: 1.609, Smooth motion: 1.612
# [DEBUG] Motion level: 1.602, Smooth motion: 1.609
# [DEBUG] Motion level: 1.613, Smooth motion: 1.609
# [DEBUG] Motion level: 1.611, Smooth motion: 1.608
# [DEBUG] Motion level: 1.634, Smooth motion: 1.614
# [DEBUG] Motion level: 1.630, Smooth motion: 1.618
# [DEBUG] Motion level: 1.642, Smooth motion: 1.626
# [DEBUG] Motion level: 1.628, Smooth motion: 1.629
# [DEBUG] Motion level: 1.624, Smooth motion: 1.632
# [DEBUG] Motion level: 1.619, Smooth motion: 1.629
# [DEBUG] Motion level: 1.625, Smooth motion: 1.628
# [DEBUG] Motion level: 1.619, Smooth motion: 1.623
# [DEBUG] Motion level: 1.698, Smooth motion: 1.637
# [DEBUG] Motion level: 1.627, Smooth motion: 1.638
# [DEBUG] Motion level: 1.657, Smooth motion: 1.645
# [DEBUG] Motion level: 1.624, Smooth motion: 1.645
# [DEBUG] Motion level: 1.620, Smooth motion: 1.645
# [DEBUG] Motion level: 1.612, Smooth motion: 1.628
# [DEBUG] Motion level: 1.615, Smooth motion: 1.626
# [DEBUG] Motion level: 1.631, Smooth motion: 1.620
# [DEBUG] Motion level: 1.634, Smooth motion: 1.622
# [DEBUG] Motion level: 1.669, Smooth motion: 1.632
# [DEBUG] Motion level: 1.655, Smooth motion: 1.641
# [DEBUG] Motion level: 1.738, Smooth motion: 1.665
# [DEBUG] Motion level: 1.661, Smooth motion: 1.671
# [DEBUG] Motion level: 1.683, Smooth motion: 1.681
# [DEBUG] Motion level: 1.659, Smooth motion: 1.679
# [DEBUG] Motion level: 1.709, Smooth motion: 1.690
# [DEBUG] Motion level: 1.653, Smooth motion: 1.673
# [DEBUG] Motion level: 1.673, Smooth motion: 1.675
# [DEBUG] Motion level: 1.648, Smooth motion: 1.668
# [DEBUG] Motion level: 1.648, Smooth motion: 1.666
# [DEBUG] Motion level: 1.659, Smooth motion: 1.656
# [DEBUG] Motion level: 1.631, Smooth motion: 1.652
# [DEBUG] Motion level: 1.638, Smooth motion: 1.645
# [DEBUG] Motion level: 1.627, Smooth motion: 1.641
# [DEBUG] Motion level: 1.679, Smooth motion: 1.647
# [DEBUG] Motion level: 1.703, Smooth motion: 1.656
# [DEBUG] Motion level: 1.735, Smooth motion: 1.677
# [DEBUG] Motion level: 1.834, Smooth motion: 1.716
# [DEBUG] Motion level: 1.709, Smooth motion: 1.732
# [DEBUG] Motion level: 1.766, Smooth motion: 1.750
# [DEBUG] Motion level: 1.710, Smooth motion: 1.751
# [DEBUG] Motion level: 1.699, Smooth motion: 1.744
# [DEBUG] Motion level: 1.711, Smooth motion: 1.719
# [DEBUG] Motion level: 1.643, Smooth motion: 1.706
# [DEBUG] Motion level: 1.718, Smooth motion: 1.696
# [DEBUG] Motion level: 1.631, Smooth motion: 1.680
# [DEBUG] Motion level: 1.672, Smooth motion: 1.675
# [DEBUG] Motion level: 1.632, Smooth motion: 1.659
# [DEBUG] Motion level: 1.629, Smooth motion: 1.656
# [DEBUG] Motion level: 1.640, Smooth motion: 1.641
# [DEBUG] Motion level: 1.679, Smooth motion: 1.650
# [DEBUG] Motion level: 1.615, Smooth motion: 1.639
# [DEBUG] Motion level: 1.673, Smooth motion: 1.647
# [DEBUG] Motion level: 1.647, Smooth motion: 1.651
# [DEBUG] Motion level: 1.732, Smooth motion: 1.669
# [DEBUG] Motion level: 1.643, Smooth motion: 1.662
# [DEBUG] Motion level: 1.668, Smooth motion: 1.673
# [DEBUG] Motion level: 1.667, Smooth motion: 1.672
# [DEBUG] Motion level: 1.690, Smooth motion: 1.680
# [DEBUG] Motion level: 1.756, Smooth motion: 1.685
# [DEBUG] Motion level: 1.766, Smooth motion: 1.710
# [DEBUG] Motion level: 1.816, Smooth motion: 1.739
# [DEBUG] Motion level: 1.661, Smooth motion: 1.738
# [DEBUG] Motion level: 1.795, Smooth motion: 1.759
# [DEBUG] Motion level: 1.642, Smooth motion: 1.736
# [DEBUG] Motion level: 1.702, Smooth motion: 1.723
# [DEBUG] Motion level: 1.676, Smooth motion: 1.695
# [DEBUG] Motion level: 1.757, Smooth motion: 1.715
# [DEBUG] Motion level: 1.667, Smooth motion: 1.689
# [DEBUG] Motion level: 1.689, Smooth motion: 1.698
# [DEBUG] Motion level: 1.685, Smooth motion: 1.695
# [DEBUG] Motion level: 1.671, Smooth motion: 1.694
# [DEBUG] Motion level: 1.647, Smooth motion: 1.672
# [DEBUG] Motion level: 1.662, Smooth motion: 1.671
# [DEBUG] Motion level: 1.612, Smooth motion: 1.656
# [DEBUG] Motion level: 1.625, Smooth motion: 1.644
# [DEBUG] Motion level: 1.629, Smooth motion: 1.635
# [DEBUG] Motion level: 1.615, Smooth motion: 1.629
# [DEBUG] Motion level: 1.616, Smooth motion: 1.620
# [DEBUG] Motion level: 1.662, Smooth motion: 1.630
# [DEBUG] Motion level: 1.642, Smooth motion: 1.633
# [DEBUG] Motion level: 1.633, Smooth motion: 1.634
# [DEBUG] Motion level: 1.665, Smooth motion: 1.644
# [DEBUG] Motion level: 1.784, Smooth motion: 1.677
# [DEBUG] Motion level: 1.651, Smooth motion: 1.675
# [DEBUG] Motion level: 1.675, Smooth motion: 1.682
# [DEBUG] Motion level: 1.643, Smooth motion: 1.684
# [DEBUG] Motion level: 1.668, Smooth motion: 1.684
# [DEBUG] Motion level: 1.644, Smooth motion: 1.656
# [DEBUG] Motion level: 1.675, Smooth motion: 1.661
# [DEBUG] Motion level: 1.629, Smooth motion: 1.652
# [DEBUG] Motion level: 1.654, Smooth motion: 1.654
# [DEBUG] Motion level: 1.647, Smooth motion: 1.650
# [DEBUG] Motion level: 1.670, Smooth motion: 1.655
# [DEBUG] Motion level: 1.729, Smooth motion: 1.666
# [DEBUG] Motion level: 1.615, Smooth motion: 1.663
# [DEBUG] Motion level: 1.634, Smooth motion: 1.659
# [DEBUG] Motion level: 1.633, Smooth motion: 1.656
# [DEBUG] Motion level: 1.633, Smooth motion: 1.649
# [DEBUG] Motion level: 1.667, Smooth motion: 1.636
# [DEBUG] Motion level: 1.636, Smooth motion: 1.641
# [DEBUG] Motion level: 1.611, Smooth motion: 1.636
# [DEBUG] Motion level: 1.639, Smooth motion: 1.637
# [DEBUG] Motion level: 1.612, Smooth motion: 1.633
# [DEBUG] Motion level: 1.625, Smooth motion: 1.625
# [DEBUG] Motion level: 1.604, Smooth motion: 1.618
# [DEBUG] Motion level: 1.617, Smooth motion: 1.619
# [DEBUG] Motion level: 1.635, Smooth motion: 1.618
# [DEBUG] Motion level: 1.677, Smooth motion: 1.631
# [DEBUG] Motion level: 1.746, Smooth motion: 1.656
# [DEBUG] Motion level: 1.923, Smooth motion: 1.720
# [DEBUG] Motion level: 2.232, Smooth motion: 1.843
# [DEBUG] Motion level: 2.534, Smooth motion: 2.022
# [DEBUG] Motion level: 2.684, Smooth motion: 2.224
# [DEBUG] Motion level: 2.832, Smooth motion: 2.441
# [DEBUG] Motion level: 2.968, Smooth motion: 2.650
# [DEBUG] Motion level: 2.871, Smooth motion: 2.778
# [DEBUG] Motion level: 2.756, Smooth motion: 2.822
# [DEBUG] Motion level: 2.683, Smooth motion: 2.822
# [DEBUG] Motion level: 2.761, Smooth motion: 2.808
# [DEBUG] Motion level: 2.761, Smooth motion: 2.766
# [DEBUG] Motion level: 2.785, Smooth motion: 2.749
# [DEBUG] Motion level: 2.897, Smooth motion: 2.777
# [DEBUG] Motion level: 3.037, Smooth motion: 2.848
# [DEBUG] Motion level: 3.444, Smooth motion: 2.985
# [DEBUG] Motion level: 3.250, Smooth motion: 3.083
# [DEBUG] Motion level: 3.342, Smooth motion: 3.194
# [DEBUG] Motion level: 3.523, Smooth motion: 3.319
# [DEBUG] Motion level: 3.357, Smooth motion: 3.383
# [DEBUG] Motion level: 3.098, Smooth motion: 3.314
# [DEBUG] Motion level: 2.997, Smooth motion: 3.264
# [DEBUG] Motion level: 3.049, Smooth motion: 3.205
# [DEBUG] Motion level: 2.699, Smooth motion: 3.040
# [DEBUG] Motion level: 2.504, Smooth motion: 2.869
# [DEBUG] Motion level: 2.278, Smooth motion: 2.705
# [DEBUG] Motion level: 2.133, Smooth motion: 2.532
# [DEBUG] Motion level: 1.941, Smooth motion: 2.311
# [DEBUG] Motion level: 1.796, Smooth motion: 2.130
# [DEBUG] Motion level: 1.712, Smooth motion: 1.972
# [DEBUG] Motion level: 1.704, Smooth motion: 1.857
# [DEBUG] Motion level: 1.707, Smooth motion: 1.772
# [DEBUG] Motion level: 1.690, Smooth motion: 1.722
# [DEBUG] Motion level: 1.739, Smooth motion: 1.711
# [DEBUG] Motion level: 1.687, Smooth motion: 1.705
# [DEBUG] Motion level: 1.708, Smooth motion: 1.706
# [DEBUG] Motion level: 1.779, Smooth motion: 1.721
# [DEBUG] Motion level: 1.741, Smooth motion: 1.731
# [DEBUG] Motion level: 1.702, Smooth motion: 1.723
# [DEBUG] Motion level: 1.668, Smooth motion: 1.720
# [DEBUG] Motion level: 1.760, Smooth motion: 1.730
# [DEBUG] Motion level: 1.709, Smooth motion: 1.716
# [DEBUG] Motion level: 1.678, Smooth motion: 1.703
# [DEBUG] Motion level: 1.745, Smooth motion: 1.712
# [DEBUG] Motion level: 1.787, Smooth motion: 1.736
# [DEBUG] Motion level: 1.721, Smooth motion: 1.728
# [DEBUG] Motion level: 1.740, Smooth motion: 1.734
# [DEBUG] Motion level: 1.707, Smooth motion: 1.740
# [DEBUG] Motion level: 1.730, Smooth motion: 1.737
# [DEBUG] Motion level: 1.679, Smooth motion: 1.715
# [DEBUG] Motion level: 1.705, Smooth motion: 1.712
# [DEBUG] Motion level: 1.653, Smooth motion: 1.695
# [DEBUG] Motion level: 1.689, Smooth motion: 1.691
# [DEBUG] Motion level: 1.664, Smooth motion: 1.678
# [DEBUG] Motion level: 1.685, Smooth motion: 1.679
# [DEBUG] Motion level: 1.652, Smooth motion: 1.669
# [DEBUG] Motion level: 1.727, Smooth motion: 1.684
# [DEBUG] Motion level: 1.676, Smooth motion: 1.681
# [DEBUG] Motion level: 1.670, Smooth motion: 1.682
# [DEBUG] Motion level: 1.672, Smooth motion: 1.680
# [DEBUG] Motion level: 1.724, Smooth motion: 1.694
# [DEBUG] Motion level: 1.675, Smooth motion: 1.683
# [DEBUG] Motion level: 1.705, Smooth motion: 1.689
# [DEBUG] Motion level: 1.693, Smooth motion: 1.694
# [DEBUG] Motion level: 1.738, Smooth motion: 1.707
# [DEBUG] Motion level: 1.691, Smooth motion: 1.700
# [DEBUG] Motion level: 1.713, Smooth motion: 1.708
# [DEBUG] Motion level: 1.686, Smooth motion: 1.704
# [DEBUG] Motion level: 1.727, Smooth motion: 1.711
# [DEBUG] Motion level: 1.662, Smooth motion: 1.696
# [DEBUG] Motion level: 1.650, Smooth motion: 1.687
# [DEBUG] Motion level: 1.652, Smooth motion: 1.675
# [DEBUG] Motion level: 1.673, Smooth motion: 1.673
# [DEBUG] Motion level: 1.661, Smooth motion: 1.660
# [DEBUG] Motion level: 1.666, Smooth motion: 1.661
# [DEBUG] Motion level: 1.644, Smooth motion: 1.659
# [DEBUG] Motion level: 1.645, Smooth motion: 1.658
# [DEBUG] Motion level: 1.641, Smooth motion: 1.652
# [DEBUG] Motion level: 1.642, Smooth motion: 1.648
# [DEBUG] Motion level: 1.651, Smooth motion: 1.645
# [DEBUG] Motion level: 1.656, Smooth motion: 1.647
# [DEBUG] Motion level: 1.659, Smooth motion: 1.650
# [DEBUG] Motion level: 1.662, Smooth motion: 1.654
# [DEBUG] Motion level: 1.685, Smooth motion: 1.663
# [DEBUG] Motion level: 1.687, Smooth motion: 1.670
# [DEBUG] Motion level: 1.706, Smooth motion: 1.680
# [DEBUG] Motion level: 1.797, Smooth motion: 1.708
# [DEBUG] Motion level: 1.764, Smooth motion: 1.728
# [DEBUG] Motion level: 1.707, Smooth motion: 1.732
# [DEBUG] Motion level: 1.717, Smooth motion: 1.738
# [DEBUG] Motion level: 1.671, Smooth motion: 1.731
# [DEBUG] Motion level: 1.667, Smooth motion: 1.705
# [DEBUG] Motion level: 1.649, Smooth motion: 1.682
# [DEBUG] Motion level: 1.662, Smooth motion: 1.673
# [DEBUG] Motion level: 1.662, Smooth motion: 1.662
# [DEBUG] Motion level: 1.706, Smooth motion: 1.669
# [DEBUG] Motion level: 1.722, Smooth motion: 1.680
# [DEBUG] Motion level: 1.714, Smooth motion: 1.693
# [DEBUG] Motion level: 1.671, Smooth motion: 1.695
# [DEBUG] Motion level: 1.661, Smooth motion: 1.695
# [DEBUG] Motion level: 1.648, Smooth motion: 1.683
# [DEBUG] Motion level: 1.656, Smooth motion: 1.670
# [DEBUG] Motion level: 1.656, Smooth motion: 1.658
# [DEBUG] Motion level: 1.659, Smooth motion: 1.656
# [DEBUG] Motion level: 1.652, Smooth motion: 1.654
# [DEBUG] Motion level: 1.669, Smooth motion: 1.658
# [DEBUG] Motion level: 1.749, Smooth motion: 1.677
# [DEBUG] Motion level: 1.763, Smooth motion: 1.699
# [DEBUG] Motion level: 1.765, Smooth motion: 1.720
# [DEBUG] Motion level: 1.741, Smooth motion: 1.738
# [DEBUG] Motion level: 1.782, Smooth motion: 1.760
# [DEBUG] Motion level: 1.846, Smooth motion: 1.780
# [DEBUG] Motion level: 1.892, Smooth motion: 1.805
# [DEBUG] Motion level: 1.863, Smooth motion: 1.825
# [DEBUG] Motion level: 1.786, Smooth motion: 1.834
# [DEBUG] Motion level: 1.762, Smooth motion: 1.830
# [DEBUG] Motion level: 1.704, Smooth motion: 1.801
# [DEBUG] Motion level: 1.670, Smooth motion: 1.757
# [DEBUG] Motion level: 1.802, Smooth motion: 1.745
# [DEBUG] Motion level: 2.051, Smooth motion: 1.798
# [DEBUG] Motion level: 1.878, Smooth motion: 1.821
# [DEBUG] Motion level: 1.954, Smooth motion: 1.871
# [DEBUG] Motion level: 1.913, Smooth motion: 1.920
# [DEBUG] Motion level: 1.888, Smooth motion: 1.937
# [DEBUG] Motion level: 1.984, Smooth motion: 1.923
# [DEBUG] Motion level: 1.819, Smooth motion: 1.912
# [DEBUG] Motion level: 2.046, Smooth motion: 1.930
# [DEBUG] Motion level: 1.731, Smooth motion: 1.893
# [DEBUG] Motion level: 2.084, Smooth motion: 1.933
# [DEBUG] Motion level: 1.743, Smooth motion: 1.884
# [DEBUG] Motion level: 1.880, Smooth motion: 1.896
# [DEBUG] Motion level: 1.693, Smooth motion: 1.826
# [DEBUG] Motion level: 1.735, Smooth motion: 1.827
# [DEBUG] Motion level: 1.713, Smooth motion: 1.753
# [DEBUG] Motion level: 1.716, Smooth motion: 1.747
# [DEBUG] Motion level: 1.725, Smooth motion: 1.716
# [DEBUG] Motion level: 1.718, Smooth motion: 1.721
# [DEBUG] Motion level: 1.683, Smooth motion: 1.711
# [DEBUG] Motion level: 1.694, Smooth motion: 1.707
# [DEBUG] Motion level: 1.688, Smooth motion: 1.702
# [DEBUG] Motion level: 1.682, Smooth motion: 1.693
# [DEBUG] Motion level: 1.744, Smooth motion: 1.698
# [DEBUG] Motion level: 1.701, Smooth motion: 1.702
# [DEBUG] Motion level: 1.738, Smooth motion: 1.711
# [DEBUG] Motion level: 1.728, Smooth motion: 1.719
# [DEBUG] Motion level: 1.717, Smooth motion: 1.726
# [DEBUG] Motion level: 1.812, Smooth motion: 1.739
# [DEBUG] Motion level: 1.771, Smooth motion: 1.753
# [DEBUG] Motion level: 1.814, Smooth motion: 1.768
# [DEBUG] Motion level: 1.725, Smooth motion: 1.768
# [DEBUG] Motion level: 1.818, Smooth motion: 1.788
# [DEBUG] Motion level: 1.682, Smooth motion: 1.762
# [DEBUG] Motion level: 1.742, Smooth motion: 1.756
# [DEBUG] Motion level: 1.684, Smooth motion: 1.730
# [DEBUG] Motion level: 1.659, Smooth motion: 1.717
# [DEBUG] Motion level: 1.679, Smooth motion: 1.689
# [DEBUG] Motion level: 1.685, Smooth motion: 1.690
# [DEBUG] Motion level: 1.663, Smooth motion: 1.674
# [DEBUG] Motion level: 1.680, Smooth motion: 1.673
# [DEBUG] Motion level: 1.779, Smooth motion: 1.697
# [DEBUG] Motion level: 1.731, Smooth motion: 1.708
# [DEBUG] Motion level: 1.780, Smooth motion: 1.727
# [DEBUG] Motion level: 1.973, Smooth motion: 1.789
# [DEBUG] Motion level: 2.349, Smooth motion: 1.922
# [DEBUG] Motion level: 2.549, Smooth motion: 2.077
# [DEBUG] Motion level: 2.721, Smooth motion: 2.275
# [DEBUG] Motion level: 3.216, Smooth motion: 2.562
# [DEBUG] Motion level: 3.481, Smooth motion: 2.863
# [DEBUG] Motion level: 3.598, Smooth motion: 3.113
# [DEBUG] Motion level: 3.761, Smooth motion: 3.355
# [DEBUG] Motion level: 3.865, Smooth motion: 3.584
# [DEBUG] Motion level: 3.964, Smooth motion: 3.734
# [DEBUG] Motion level: 6.024, Smooth motion: 4.242
# [DEBUG] Motion level: 3.813, Smooth motion: 4.285
# [DEBUG] Motion level: 3.730, Smooth motion: 4.279
# [DEBUG] Motion level: 3.596, Smooth motion: 4.225
# [DEBUG] Motion level: 3.329, Smooth motion: 4.098
# [DEBUG] Motion level: 3.204, Smooth motion: 3.534
# [DEBUG] Motion level: 3.125, Smooth motion: 3.397
# [DEBUG] Motion level: 3.039, Smooth motion: 3.258
# [DEBUG] Motion level: 3.059, Smooth motion: 3.151
# [DEBUG] Motion level: 3.096, Smooth motion: 3.105
# [DEBUG] Motion level: 3.075, Smooth motion: 3.079
# [DEBUG] Motion level: 3.110, Smooth motion: 3.076
# [DEBUG] Motion level: 3.134, Smooth motion: 3.095
# [DEBUG] Motion level: 3.062, Smooth motion: 3.095
# [DEBUG] Motion level: 2.832, Smooth motion: 3.042
# [DEBUG] Motion level: 2.775, Smooth motion: 2.982
# [DEBUG] Motion level: 2.825, Smooth motion: 2.925
# [DEBUG] Motion level: 4.821, Smooth motion: 3.263
# [DEBUG] Motion level: 2.632, Smooth motion: 3.177
# [DEBUG] Motion level: 2.519, Smooth motion: 3.114
# [DEBUG] Motion level: 2.396, Smooth motion: 3.039
# [DEBUG] Motion level: 2.581, Smooth motion: 2.990
# [DEBUG] Motion level: 2.614, Smooth motion: 2.548
# [DEBUG] Motion level: 2.511, Smooth motion: 2.524
# [DEBUG] Motion level: 2.557, Smooth motion: 2.532
# [DEBUG] Motion level: 2.673, Smooth motion: 2.587
# [DEBUG] Motion level: 2.631, Smooth motion: 2.597
# [DEBUG] Motion level: 2.595, Smooth motion: 2.593
# [DEBUG] Motion level: 2.584, Smooth motion: 2.608
# [DEBUG] Motion level: 2.709, Smooth motion: 2.638
# [DEBUG] Motion level: 2.556, Smooth motion: 2.615
# [DEBUG] Motion level: 2.590, Smooth motion: 2.607
# [DEBUG] Motion level: 2.556, Smooth motion: 2.599
# [DEBUG] Motion level: 2.457, Smooth motion: 2.574
# [DEBUG] Motion level: 2.308, Smooth motion: 2.494
# [DEBUG] Motion level: 5.051, Smooth motion: 2.993
# [DEBUG] Motion level: 2.475, Smooth motion: 2.969
# [DEBUG] Motion level: 2.501, Smooth motion: 2.958
# [DEBUG] Motion level: 2.489, Smooth motion: 2.965
# [DEBUG] Motion level: 2.399, Smooth motion: 2.983
# [DEBUG] Motion level: 2.209, Smooth motion: 2.414
# [DEBUG] Motion level: 2.092, Smooth motion: 2.338
# [DEBUG] Motion level: 1.958, Smooth motion: 2.229
# [DEBUG] Motion level: 1.783, Smooth motion: 2.088
# [DEBUG] Motion level: 1.722, Smooth motion: 1.953
# [DEBUG] Motion level: 1.759, Smooth motion: 1.863
# [DEBUG] Motion level: 1.703, Smooth motion: 1.785
# [DEBUG] Motion level: 1.715, Smooth motion: 1.737
# [DEBUG] Motion level: 1.695, Smooth motion: 1.719
# [DEBUG] Motion level: 1.682, Smooth motion: 1.711
# [DEBUG] Motion level: 1.698, Smooth motion: 1.699
# [DEBUG] Motion level: 1.743, Smooth motion: 1.707
# [DEBUG] Motion level: 1.768, Smooth motion: 1.717
# [DEBUG] Motion level: 1.826, Smooth motion: 1.743
# [DEBUG] Motion level: 1.849, Smooth motion: 1.777
# [DEBUG] Motion level: 1.881, Smooth motion: 1.813
# [DEBUG] Motion level: 1.922, Smooth motion: 1.849
# [DEBUG] Motion level: 1.868, Smooth motion: 1.869
# [DEBUG] Motion level: 1.812, Smooth motion: 1.866
# [DEBUG] Motion level: 1.779, Smooth motion: 1.852
# [DEBUG] Motion level: 1.680, Smooth motion: 1.812
# [DEBUG] Motion level: 1.725, Smooth motion: 1.773
# [DEBUG] Motion level: 1.827, Smooth motion: 1.765
# [DEBUG] Motion level: 2.827, Smooth motion: 1.968
# [DEBUG] Motion level: 2.863, Smooth motion: 2.185
# [DEBUG] Motion level: 2.854, Smooth motion: 2.419
# [DEBUG] Motion level: 3.152, Smooth motion: 2.705
# [DEBUG] Motion level: 3.421, Smooth motion: 3.023
# [DEBUG] Motion level: 3.484, Smooth motion: 3.155
# [DEBUG] Motion level: 3.301, Smooth motion: 3.242
# [DEBUG] Motion level: 2.881, Smooth motion: 3.248
# [DEBUG] Motion level: 2.519, Smooth motion: 3.121
# [DEBUG] Motion level: 2.279, Smooth motion: 2.893
# [DEBUG] Motion level: 2.771, Smooth motion: 2.750
# [DEBUG] Motion level: 2.170, Smooth motion: 2.524
# [DEBUG] Motion level: 3.104, Smooth motion: 2.569
# [DEBUG] Motion level: 2.293, Smooth motion: 2.523
# [DEBUG] Motion level: 2.088, Smooth motion: 2.485
# [DEBUG] Motion level: 1.728, Smooth motion: 2.276
# [DEBUG] Motion level: 3.050, Smooth motion: 2.452
# [DEBUG] Motion level: 2.082, Smooth motion: 2.248
# [DEBUG] Motion level: 1.656, Smooth motion: 2.121
# [DEBUG] Motion level: 1.791, Smooth motion: 2.062
# [DEBUG] Motion level: 1.683, Smooth motion: 2.052
# [DEBUG] Motion level: 2.661, Smooth motion: 1.975
# [DEBUG] Motion level: 1.656, Smooth motion: 1.890
# [DEBUG] Motion level: 1.539, Smooth motion: 1.866
# [DEBUG] Motion level: 1.587, Smooth motion: 1.825
# [DEBUG] Motion level: 1.534, Smooth motion: 1.795
# [DEBUG] Motion level: 1.576, Smooth motion: 1.578
# [DEBUG] Motion level: 1.559, Smooth motion: 1.559
# [DEBUG] Motion level: 1.625, Smooth motion: 1.576
# [DEBUG] Motion level: 1.517, Smooth motion: 1.562
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.559, Smooth motion: 1.567
# [DEBUG] Motion level: 1.536, Smooth motion: 1.559
# [DEBUG] Motion level: 1.529, Smooth motion: 1.553
# [DEBUG] Motion level: 1.612, Smooth motion: 1.551
# [DEBUG] Motion level: 1.887, Smooth motion: 1.625
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.537, Smooth motion: 1.620
# [DEBUG] Motion level: 1.543, Smooth motion: 1.622
# [DEBUG] Motion level: 1.531, Smooth motion: 1.622
# [DEBUG] Motion level: 1.524, Smooth motion: 1.604
# [DEBUG] Motion level: 1.566, Smooth motion: 1.540
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.558, Smooth motion: 1.544
# [DEBUG] Motion level: 1.541, Smooth motion: 1.544
# [DEBUG] Motion level: 1.534, Smooth motion: 1.545
# [DEBUG] Motion level: 1.550, Smooth motion: 1.550
# [DEBUG] Motion level: 1.626, Smooth motion: 1.562
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.534, Smooth motion: 1.557
# [DEBUG] Motion level: 1.559, Smooth motion: 1.561
# [DEBUG] Motion level: 1.542, Smooth motion: 1.562
# [DEBUG] Motion level: 1.523, Smooth motion: 1.557
# [DEBUG] Motion level: 1.538, Smooth motion: 1.539
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.531, Smooth motion: 1.538
# [DEBUG] Motion level: 1.532, Smooth motion: 1.533
# [DEBUG] Motion level: 1.526, Smooth motion: 1.530
# [DEBUG] Motion level: 1.590, Smooth motion: 1.544
# [DEBUG] Motion level: 1.636, Smooth motion: 1.563
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.573, Smooth motion: 1.572
# [DEBUG] Motion level: 1.577, Smooth motion: 1.580
# [DEBUG] Motion level: 1.532, Smooth motion: 1.581
# [DEBUG] Motion level: 1.564, Smooth motion: 1.576
# [DEBUG] Motion level: 1.553, Smooth motion: 1.560
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.519, Smooth motion: 1.549
# [DEBUG] Motion level: 1.539, Smooth motion: 1.541
# [DEBUG] Motion level: 1.545, Smooth motion: 1.544
# [DEBUG] Motion level: 1.528, Smooth motion: 1.537
# [DEBUG] Motion level: 1.668, Smooth motion: 1.560
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.536, Smooth motion: 1.563
# [DEBUG] Motion level: 1.564, Smooth motion: 1.568
# [DEBUG] Motion level: 1.536, Smooth motion: 1.566
# [DEBUG] Motion level: 1.576, Smooth motion: 1.576
# [DEBUG] Motion level: 1.700, Smooth motion: 1.582
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.559, Smooth motion: 1.587
# [DEBUG] Motion level: 1.527, Smooth motion: 1.579
# [DEBUG] Motion level: 1.543, Smooth motion: 1.581
# [DEBUG] Motion level: 1.551, Smooth motion: 1.576
# [DEBUG] Motion level: 1.639, Smooth motion: 1.564
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.520, Smooth motion: 1.556
# [DEBUG] Motion level: 1.541, Smooth motion: 1.559
# [DEBUG] Motion level: 1.537, Smooth motion: 1.558
# [DEBUG] Motion level: 1.551, Smooth motion: 1.558
# [DEBUG] Motion level: 1.607, Smooth motion: 1.551
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.573, Smooth motion: 1.562
# [DEBUG] Motion level: 1.584, Smooth motion: 1.570
# [DEBUG] Motion level: 1.542, Smooth motion: 1.571
# [DEBUG] Motion level: 1.572, Smooth motion: 1.576
# [DEBUG] Motion level: 1.678, Smooth motion: 1.590
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.587, Smooth motion: 1.593
# [DEBUG] Motion level: 1.542, Smooth motion: 1.584
# [DEBUG] Motion level: 1.611, Smooth motion: 1.598
# [DEBUG] Motion level: 1.555, Smooth motion: 1.595
# [DEBUG] Motion level: 1.744, Smooth motion: 1.608
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.557, Smooth motion: 1.602
# [DEBUG] Motion level: 1.520, Smooth motion: 1.597
# [DEBUG] Motion level: 1.530, Smooth motion: 1.581
# [DEBUG] Motion level: 1.531, Smooth motion: 1.576
# [DEBUG] Motion level: 1.606, Smooth motion: 1.549
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: L (conf: 0.34)
# [DEBUG] Motion level: 1.524, Smooth motion: 1.542
# [DEBUG] Motion level: 1.537, Smooth motion: 1.546
# [DEBUG] Motion level: 1.523, Smooth motion: 1.544
# [DEBUG] Motion level: 1.526, Smooth motion: 1.543
# [DEBUG] Motion level: 1.556, Smooth motion: 1.533
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.538, Smooth motion: 1.536
# [DEBUG] Motion level: 1.566, Smooth motion: 1.542
# [DEBUG] Motion level: 1.529, Smooth motion: 1.543
# [DEBUG] Motion level: 1.544, Smooth motion: 1.547
# [DEBUG] Motion level: 1.649, Smooth motion: 1.565
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.524, Smooth motion: 1.562
# [DEBUG] Motion level: 1.556, Smooth motion: 1.560
# [DEBUG] Motion level: 1.525, Smooth motion: 1.560
# [DEBUG] Motion level: 1.558, Smooth motion: 1.562
# [DEBUG] Motion level: 1.618, Smooth motion: 1.556
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.540, Smooth motion: 1.559
# [DEBUG] Motion level: 1.558, Smooth motion: 1.560
# [DEBUG] Motion level: 1.546, Smooth motion: 1.564
# [DEBUG] Motion level: 1.531, Smooth motion: 1.558
# [DEBUG] Motion level: 1.577, Smooth motion: 1.550
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.534, Smooth motion: 1.549
# [DEBUG] Motion level: 1.518, Smooth motion: 1.541
# [DEBUG] Motion level: 1.531, Smooth motion: 1.538
# [DEBUG] Motion level: 1.524, Smooth motion: 1.537
# [DEBUG] Motion level: 1.585, Smooth motion: 1.539
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.530, Smooth motion: 1.538
# [DEBUG] Motion level: 1.539, Smooth motion: 1.542
# [DEBUG] Motion level: 1.530, Smooth motion: 1.542
# [DEBUG] Motion level: 1.542, Smooth motion: 1.545
# [DEBUG] Motion level: 1.562, Smooth motion: 1.541
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.526, Smooth motion: 1.540
# [DEBUG] Motion level: 1.532, Smooth motion: 1.538
# [DEBUG] Motion level: 1.529, Smooth motion: 1.538
# [DEBUG] Motion level: 1.521, Smooth motion: 1.534
# [DEBUG] Motion level: 1.531, Smooth motion: 1.528
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.520, Smooth motion: 1.527
# [DEBUG] Motion level: 1.525, Smooth motion: 1.525
# [DEBUG] Motion level: 1.541, Smooth motion: 1.528
# [DEBUG] Motion level: 1.530, Smooth motion: 1.530
# [DEBUG] Motion level: 1.625, Smooth motion: 1.548
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.557, Smooth motion: 1.556
# [DEBUG] Motion level: 1.532, Smooth motion: 1.557
# [DEBUG] Motion level: 1.534, Smooth motion: 1.556
# [DEBUG] Motion level: 1.511, Smooth motion: 1.552
# [DEBUG] Motion level: 1.536, Smooth motion: 1.534
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.530, Smooth motion: 1.529
# [DEBUG] Motion level: 1.525, Smooth motion: 1.527
# [DEBUG] Motion level: 1.538, Smooth motion: 1.528
# [DEBUG] Motion level: 1.531, Smooth motion: 1.532
# [DEBUG] Motion level: 1.554, Smooth motion: 1.536
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.530, Smooth motion: 1.536
# [DEBUG] Motion level: 1.523, Smooth motion: 1.535
# [DEBUG] Motion level: 1.532, Smooth motion: 1.534
# [DEBUG] Motion level: 1.530, Smooth motion: 1.534
# [DEBUG] Motion level: 1.559, Smooth motion: 1.535
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: L (conf: 0.36)
# [DEBUG] Motion level: 1.543, Smooth motion: 1.537
# [DEBUG] Motion level: 1.531, Smooth motion: 1.539
# [DEBUG] Motion level: 1.539, Smooth motion: 1.540
# [DEBUG] Motion level: 1.523, Smooth motion: 1.539
# [DEBUG] Motion level: 1.566, Smooth motion: 1.540
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: L (conf: 0.35)
# [DEBUG] Motion level: 1.531, Smooth motion: 1.538
# [DEBUG] Motion level: 1.523, Smooth motion: 1.536
# [DEBUG] Motion level: 1.543, Smooth motion: 1.537
# [DEBUG] Motion level: 1.731, Smooth motion: 1.579
# [DEBUG] Motion level: 3.202, Smooth motion: 1.906
# [DEBUG] Motion level: 2.197, Smooth motion: 2.039
# [DEBUG] Motion level: 1.737, Smooth motion: 2.082
# [DEBUG] Motion level: 1.918, Smooth motion: 2.157
# [DEBUG] Motion level: 1.765, Smooth motion: 2.164
# [DEBUG] Motion level: 1.705, Smooth motion: 1.864
# [DEBUG] Motion level: 1.577, Smooth motion: 1.740
# [DEBUG] Motion level: 1.630, Smooth motion: 1.719
# [DEBUG] Motion level: 1.674, Smooth motion: 1.670
# [DEBUG] Motion level: 1.551, Smooth motion: 1.628
# [DEBUG] Motion level: 1.580, Smooth motion: 1.603
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: B (conf: 0.84)
# [INFO] Recognized static gesture: B with confidence 0.84
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.583, Smooth motion: 1.604
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.544, Smooth motion: 1.586
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.615, Smooth motion: 1.575
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.697, Smooth motion: 1.604
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.194, Smooth motion: 1.727
# [DEBUG] Static prediction skipped due to cooldown: 5
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.631, Smooth motion: 1.736
# [DEBUG] Static prediction skipped due to cooldown: 4
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.784, Smooth motion: 1.784
# [DEBUG] Static prediction skipped due to cooldown: 3
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.821, Smooth motion: 1.825
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.693, Smooth motion: 1.824
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.784, Smooth motion: 1.743
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.607, Smooth motion: 1.738
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.660, Smooth motion: 1.713
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.544, Smooth motion: 1.658
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.554, Smooth motion: 1.630
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: B (conf: 0.83)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.538, Smooth motion: 1.581
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.546, Smooth motion: 1.569
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.545, Smooth motion: 1.546
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.586, Smooth motion: 1.554
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.817, Smooth motion: 1.606
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [STATIC] Predicted: B (conf: 0.84)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.558, Smooth motion: 1.610
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.668, Smooth motion: 1.635
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.604, Smooth motion: 1.647
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.645, Smooth motion: 1.658
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.606, Smooth motion: 1.616
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: B (conf: 0.84)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.570, Smooth motion: 1.619
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.532, Smooth motion: 1.591
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.587, Smooth motion: 1.588
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.546, Smooth motion: 1.568
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.760, Smooth motion: 1.599
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: B (conf: 0.85)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.812, Smooth motion: 1.647
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.032, Smooth motion: 1.947
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.422, Smooth motion: 2.114
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.413, Smooth motion: 2.288
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.363, Smooth motion: 2.608
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.295, Smooth motion: 2.705
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.644, Smooth motion: 2.428
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.618, Smooth motion: 2.267
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.725, Smooth motion: 2.129
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.605, Smooth motion: 1.777
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.695, Smooth motion: 1.657
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.044, Smooth motion: 1.737
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.687, Smooth motion: 1.751
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.768, Smooth motion: 1.760
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: R (conf: 0.74)
# [INFO] Recognized static gesture: R with confidence 0.74
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.563, Smooth motion: 1.751
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.573, Smooth motion: 1.727
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.696, Smooth motion: 1.657
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.579, Smooth motion: 1.636
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.080, Smooth motion: 1.698
# [DEBUG] Static prediction skipped due to cooldown: 5
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.643, Smooth motion: 1.714
# [DEBUG] Static prediction skipped due to cooldown: 4
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.806, Smooth motion: 1.761
# [DEBUG] Static prediction skipped due to cooldown: 3
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.665, Smooth motion: 1.755
# [DEBUG] Static prediction skipped due to cooldown: 2
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.810, Smooth motion: 1.801
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.803, Smooth motion: 1.745
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.605, Smooth motion: 1.738
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.696, Smooth motion: 1.716
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.647, Smooth motion: 1.712
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.559, Smooth motion: 1.662
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: R (conf: 0.73)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.570, Smooth motion: 1.615
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.573, Smooth motion: 1.609
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.537, Smooth motion: 1.577
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.558, Smooth motion: 1.559
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.676, Smooth motion: 1.583
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [STATIC] Predicted: R (conf: 0.73)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.544, Smooth motion: 1.578
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.597, Smooth motion: 1.582
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.549, Smooth motion: 1.585
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.558, Smooth motion: 1.585
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.566, Smooth motion: 1.563
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: R (conf: 0.71)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.536, Smooth motion: 1.561
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.522, Smooth motion: 1.546
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.543, Smooth motion: 1.545
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.526, Smooth motion: 1.539
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.585, Smooth motion: 1.542
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: R (conf: 0.72)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.548, Smooth motion: 1.545
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.529, Smooth motion: 1.546
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.582, Smooth motion: 1.554
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.819, Smooth motion: 1.613
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.241, Smooth motion: 1.944
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.301, Smooth motion: 2.295
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.469, Smooth motion: 2.482
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.011, Smooth motion: 2.768
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.076, Smooth motion: 3.020
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.531, Smooth motion: 2.878
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.286, Smooth motion: 2.875
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.073, Smooth motion: 2.995
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.101, Smooth motion: 2.813
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.348, Smooth motion: 2.668
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.009, Smooth motion: 2.563
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.780, Smooth motion: 2.462
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.188, Smooth motion: 2.485
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.653, Smooth motion: 2.795
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.946, Smooth motion: 3.115
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.105, Smooth motion: 3.534
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.022, Smooth motion: 3.783
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.737, Smooth motion: 3.893
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.511, Smooth motion: 3.864
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.606, Smooth motion: 3.596
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.268, Smooth motion: 3.629
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.816, Smooth motion: 3.587
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.730, Smooth motion: 3.586
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.042, Smooth motion: 3.692
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.041, Smooth motion: 3.779
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.948, Smooth motion: 3.515
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.777, Smooth motion: 3.308
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.916, Smooth motion: 2.945
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.234, Smooth motion: 2.583
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.794, Smooth motion: 2.334
# [DEBUG] Normalized buffer shape: (30, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# [DYNAMIC] Predicted: E_E (conf: 0.53)
# [INFO] Recognized dynamic gesture: E_E with confidence 0.53
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.084, Smooth motion: 2.161
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.573, Smooth motion: 2.120
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.719, Smooth motion: 2.081
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.546, Smooth motion: 1.943
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.901, Smooth motion: 2.164
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.615, Smooth motion: 2.071
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.556, Smooth motion: 1.867
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.694, Smooth motion: 1.862
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.634, Smooth motion: 1.880
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.662, Smooth motion: 1.632
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.644, Smooth motion: 1.638
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.049, Smooth motion: 1.737
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.284, Smooth motion: 1.855
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.010, Smooth motion: 1.930
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.936, Smooth motion: 2.185
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.863, Smooth motion: 2.428
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.190, Smooth motion: 2.456
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.798, Smooth motion: 2.559
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.665, Smooth motion: 2.690
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.964, Smooth motion: 2.496
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.703, Smooth motion: 2.464
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.643, Smooth motion: 2.755
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.351, Smooth motion: 2.865
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 5.021, Smooth motion: 3.336
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 5.189, Smooth motion: 3.981
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# ...
# [DEBUG] Motion level: 2.129, Smooth motion: 2.316
# [DEBUG] Motion level: 3.891, Smooth motion: 2.517
# [DEBUG] Motion level: 4.534, Smooth motion: 3.032
# [DEBUG] Motion level: 3.044, Smooth motion: 3.253
# [DEBUG] Motion level: 4.045, Smooth motion: 3.529
# [DEBUG] Motion level: 3.930, Smooth motion: 3.889
# [DEBUG] Motion level: 2.743, Smooth motion: 3.659
# [DEBUG] Motion level: 3.529, Smooth motion: 3.458
# [DEBUG] Motion level: 3.642, Smooth motion: 3.578
# [DEBUG] Motion level: 2.962, Smooth motion: 3.361
# [DEBUG] Motion level: 1.901, Smooth motion: 2.955
# [DEBUG] Motion level: 1.922, Smooth motion: 2.791
# [DEBUG] Motion level: 2.703, Smooth motion: 2.626
# [DEBUG] Motion level: 3.045, Smooth motion: 2.507
# [DEBUG] Motion level: 3.218, Smooth motion: 2.558
# [DEBUG] Motion level: 3.445, Smooth motion: 2.866
# [DEBUG] Motion level: 2.422, Smooth motion: 2.967
# [DEBUG] Motion level: 3.528, Smooth motion: 3.132
# [DEBUG] Motion level: 2.430, Smooth motion: 3.009
# [DEBUG] Motion level: 2.473, Smooth motion: 2.860
# [DEBUG] Motion level: 3.454, Smooth motion: 2.861
# [DEBUG] Motion level: 2.486, Smooth motion: 2.874
# [DEBUG] Motion level: 3.548, Smooth motion: 2.878
# [DEBUG] Motion level: 2.592, Smooth motion: 2.911
# [DEBUG] Motion level: 4.330, Smooth motion: 3.282
# [DEBUG] Motion level: 3.587, Smooth motion: 3.309
# [DEBUG] Motion level: 4.819, Smooth motion: 3.775
# [DEBUG] Motion level: 4.068, Smooth motion: 3.879
# [DEBUG] Motion level: 7.139, Smooth motion: 4.788
# [DEBUG] Motion level: 6.088, Smooth motion: 5.140
# [DEBUG] Motion level: 5.359, Smooth motion: 5.495
# [DEBUG] Motion level: 4.765, Smooth motion: 5.484
# [DEBUG] Motion level: 4.316, Smooth motion: 5.534
# [DEBUG] Motion level: 2.507, Smooth motion: 4.607
# [DEBUG] Motion level: 3.036, Smooth motion: 3.997
# [DEBUG] Motion level: 2.621, Smooth motion: 3.449
# [DEBUG] Motion level: 1.895, Smooth motion: 2.875
# [DEBUG] Motion level: 2.396, Smooth motion: 2.491
# [DEBUG] Motion level: 2.907, Smooth motion: 2.571
# [DEBUG] Motion level: 2.334, Smooth motion: 2.430
# [DEBUG] Motion level: 1.781, Smooth motion: 2.262
# [DEBUG] Motion level: 2.202, Smooth motion: 2.324
# [DEBUG] Motion level: 2.640, Smooth motion: 2.373
# [DEBUG] Motion level: 2.214, Smooth motion: 2.234
# [DEBUG] Motion level: 3.409, Smooth motion: 2.449
# [DEBUG] Motion level: 2.658, Smooth motion: 2.625
# [DEBUG] Motion level: 3.866, Smooth motion: 2.957
# [DEBUG] Motion level: 3.968, Smooth motion: 3.223
# [DEBUG] Motion level: 2.838, Smooth motion: 3.348
# [DEBUG] Motion level: 3.883, Smooth motion: 3.443
# [DEBUG] Motion level: 3.681, Smooth motion: 3.647
# [DEBUG] Motion level: 2.658, Smooth motion: 3.406
# [DEBUG] Motion level: 3.822, Smooth motion: 3.376
# [DEBUG] Motion level: 4.031, Smooth motion: 3.615
# [DEBUG] Motion level: 2.888, Smooth motion: 3.416
# [DEBUG] Motion level: 4.253, Smooth motion: 3.530
# [DEBUG] Normalized buffer shape: (30, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [DYNAMIC] Predicted: SZ (conf: 0.87)
# [INFO] Recognized dynamic gesture: SZ with confidence 0.87
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.985, Smooth motion: 3.596
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 4.312, Smooth motion: 3.694
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 4.245, Smooth motion: 3.737
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.781, Smooth motion: 3.715
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 5.438, Smooth motion: 3.952
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.399, Smooth motion: 3.835
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.079, Smooth motion: 3.589
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.905, Smooth motion: 3.321
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.211, Smooth motion: 3.206
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.988, Smooth motion: 2.916
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.207, Smooth motion: 2.878
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.112, Smooth motion: 2.885
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.224, Smooth motion: 2.949
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.118, Smooth motion: 3.130
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.047, Smooth motion: 2.942
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.329, Smooth motion: 2.966
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.980, Smooth motion: 2.940
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.886, Smooth motion: 2.872
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.262, Smooth motion: 2.701
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.878, Smooth motion: 2.667
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.203, Smooth motion: 2.642
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.846, Smooth motion: 2.615
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.912, Smooth motion: 2.620
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.848, Smooth motion: 2.737
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.212, Smooth motion: 2.604
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.852, Smooth motion: 2.734
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.840, Smooth motion: 2.733
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.811, Smooth motion: 2.713
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.735, Smooth motion: 2.690
# [DEBUG] Drawing label: SZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.637, Smooth motion: 2.775
# [DEBUG] Normalized buffer shape: (30, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [DYNAMIC] Predicted: E_E (conf: 0.78)
# [INFO] Recognized dynamic gesture: E_E with confidence 0.78
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.872, Smooth motion: 2.579
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.093, Smooth motion: 2.429
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.828, Smooth motion: 2.233
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.577, Smooth motion: 2.002
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.035, Smooth motion: 1.881
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.672, Smooth motion: 1.841
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.572, Smooth motion: 1.737
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.584, Smooth motion: 1.688
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.593, Smooth motion: 1.691
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.536, Smooth motion: 1.591
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.667, Smooth motion: 1.590
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: R (conf: 0.33)
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.518, Smooth motion: 1.580
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.999, Smooth motion: 1.663
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.566, Smooth motion: 1.857
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.870, Smooth motion: 2.124
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.904, Smooth motion: 2.572
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.146, Smooth motion: 2.697
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.920, Smooth motion: 2.881
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.230, Smooth motion: 2.814
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.201, Smooth motion: 2.880
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.460, Smooth motion: 2.592
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.554, Smooth motion: 2.873
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.566, Smooth motion: 2.802
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.614, Smooth motion: 3.079
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.528, Smooth motion: 2.945
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.534, Smooth motion: 3.159
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.601, Smooth motion: 2.969
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.649, Smooth motion: 2.985
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.635, Smooth motion: 2.989
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.742, Smooth motion: 3.032
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.762, Smooth motion: 2.878
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.751, Smooth motion: 3.108
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.775, Smooth motion: 3.133
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.560, Smooth motion: 3.118
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.515, Smooth motion: 3.073
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.458, Smooth motion: 3.012
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.102, Smooth motion: 2.882
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.251, Smooth motion: 2.777
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.795, Smooth motion: 2.624
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.710, Smooth motion: 2.663
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.102, Smooth motion: 2.592
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.800, Smooth motion: 2.532
# [DEBUG] Drawing label: E_E (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.854, Smooth motion: 2.652
# [DEBUG] Normalized buffer shape: (30, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [DYNAMIC] Predicted: F (conf: 0.99)
# [INFO] Recognized dynamic gesture: F with confidence 0.99
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.220, Smooth motion: 2.537
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.850, Smooth motion: 2.565
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.220, Smooth motion: 2.589
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.992, Smooth motion: 2.627
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 4.152, Smooth motion: 2.887
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.415, Smooth motion: 2.926
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.109, Smooth motion: 2.978
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.362, Smooth motion: 3.006
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.048, Smooth motion: 3.017
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.939, Smooth motion: 2.775
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.806, Smooth motion: 2.853
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.055, Smooth motion: 2.642
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.566, Smooth motion: 2.683
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.880, Smooth motion: 2.449
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.137, Smooth motion: 2.289
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.597, Smooth motion: 2.047
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.921, Smooth motion: 2.020
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.731, Smooth motion: 1.853
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.400, Smooth motion: 1.957
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.954, Smooth motion: 2.121
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.535, Smooth motion: 2.308
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.784, Smooth motion: 2.681
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.032, Smooth motion: 2.941
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.633, Smooth motion: 3.188
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.870, Smooth motion: 3.171
# [DEBUG] Drawing label: F (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.353, Smooth motion: 3.334
# [DEBUG] Motion level: 2.401, Smooth motion: 3.058
# [DEBUG] Motion level: 3.390, Smooth motion: 3.129
# [DEBUG] Motion level: 3.503, Smooth motion: 3.103
# [DEBUG] Motion level: 2.440, Smooth motion: 3.017
# [DEBUG] Motion level: 4.196, Smooth motion: 3.186
# [DEBUG] Motion level: 3.087, Smooth motion: 3.323
# [DEBUG] Motion level: 4.599, Smooth motion: 3.565
# [DEBUG] Motion level: 2.990, Smooth motion: 3.462
# [DEBUG] Motion level: 3.245, Smooth motion: 3.623
# [DEBUG] Motion level: 5.211, Smooth motion: 3.826
# [DEBUG] Motion level: 3.197, Smooth motion: 3.848
# [DEBUG] Motion level: 3.217, Smooth motion: 3.572
# [DEBUG] Motion level: 5.927, Smooth motion: 4.160
# [DEBUG] Motion level: 5.216, Smooth motion: 4.554
# [DEBUG] Motion level: 5.215, Smooth motion: 4.555
# [DEBUG] Motion level: 3.295, Smooth motion: 4.574
# [DEBUG] Motion level: 5.126, Smooth motion: 4.956
# [DEBUG] Motion level: 6.002, Smooth motion: 4.971
# [DEBUG] Motion level: 4.965, Smooth motion: 4.921
# [DEBUG] Motion level: 3.224, Smooth motion: 4.522
# [DEBUG] Motion level: 4.985, Smooth motion: 4.860
# [DEBUG] Motion level: 5.020, Smooth motion: 4.839
# [DEBUG] Motion level: 3.381, Smooth motion: 4.315
# [DEBUG] Motion level: 5.279, Smooth motion: 4.378
# [DEBUG] Motion level: 4.803, Smooth motion: 4.694
# [DEBUG] Motion level: 3.119, Smooth motion: 4.321
# [DEBUG] Motion level: 4.745, Smooth motion: 4.266
# [DEBUG] Motion level: 4.461, Smooth motion: 4.482
# [DEBUG] Motion level: 4.491, Smooth motion: 4.324
# [DEBUG] Motion level: 5.183, Smooth motion: 4.400
# [DEBUG] Motion level: 4.803, Smooth motion: 4.736
# [DEBUG] Motion level: 3.834, Smooth motion: 4.554
# [DEBUG] Motion level: 2.553, Smooth motion: 4.173
# [DEBUG] Motion level: 3.768, Smooth motion: 4.028
# [DEBUG] Motion level: 3.992, Smooth motion: 3.790
# [DEBUG] Motion level: 2.733, Smooth motion: 3.376
# [DEBUG] Motion level: 3.594, Smooth motion: 3.328
# [DEBUG] Motion level: 2.870, Smooth motion: 3.392
# [DEBUG] Motion level: 1.979, Smooth motion: 3.034
# [DEBUG] Motion level: 2.788, Smooth motion: 2.793
# [DEBUG] Motion level: 2.291, Smooth motion: 2.704
# [DEBUG] Motion level: 3.668, Smooth motion: 2.719
# [DEBUG] Motion level: 4.043, Smooth motion: 2.954
# [DEBUG] Motion level: 4.029, Smooth motion: 3.364
# [DEBUG] Motion level: 2.429, Smooth motion: 3.292
# [DEBUG] Motion level: 2.232, Smooth motion: 3.280
# [DEBUG] Motion level: 2.790, Smooth motion: 3.105
# [DEBUG] Motion level: 2.191, Smooth motion: 2.734

# %%
import cv2
import mediapipe as mp
import numpy as np
from tensorflow.keras.models import load_model
import joblib

# Załaduj modele
model_static = load_model('../model/StaticBiLSTM/static_gestures_model.keras')
label_encoder_static = joblib.load('../model/StaticBiLSTM/static_gestures_labels.pkl')

model_dynamic = load_model('../model/DynamicBiLSTM/dynamic_gestures_model.keras')
label_encoder_dynamic = joblib.load('../model/DynamicBiLSTM/dynamic_gestures_labels.pkl')

# Parametry
motion_threshold = 1.9
motion_history = []
motion_history_len = 5
cooldown_frames = 0
cooldown_threshold = 10
recognized_sign = ''
recognized_type = ''
last_prediction = None
static_buffer = []
dynamic_buffer = []

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

def normalize_landmarks_buffer(buffer):
    buffer = np.array(buffer)
    if buffer.shape[0] == 0:
        return np.zeros((1, 63))
    wrist_ref = buffer[0, 3:6]  # landmark_1 x,y,z
    norm_buffer = buffer.copy()
    for i in range(1, 21):
        norm_buffer[:, i*3:(i+1)*3] -= wrist_ref
    return norm_buffer

def extract_right_hand_landmarks(results):
    if results.right_hand_landmarks:
        return [coord for lm in results.right_hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]
    return None

def get_hand_bbox(landmarks, image_width, image_height):
    xs = [lm.x * image_width for lm in landmarks.landmark]
    ys = [lm.y * image_height for lm in landmarks.landmark]
    x_min, x_max = max(int(min(xs)), 0), min(int(max(xs)), image_width)
    y_min, y_max = max(int(min(ys)), 0), min(int(max(ys)), image_height)
    return (x_min, y_min, x_max, y_max)

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

ret, prev_frame = cap.read()
prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        curr_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame_diff = cv2.absdiff(prev_gray, curr_gray)
        motion_level = np.sum(frame_diff) / (frame.shape[0] * frame.shape[1])
        prev_gray = curr_gray.copy()

        motion_history.append(motion_level)
        if len(motion_history) > motion_history_len:
            motion_history.pop(0)
        smooth_motion = np.mean(motion_history)

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image_rgb)
        image_height, image_width, _ = frame.shape

        landmarks = extract_right_hand_landmarks(results)

        if landmarks:
            mp_drawing.draw_landmarks(frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
            bbox = get_hand_bbox(results.right_hand_landmarks, image_width, image_height)
            x1, y1, x2, y2 = bbox
            box_color = (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)

            if smooth_motion < motion_threshold:
                dynamic_buffer.clear()
                static_buffer.append(landmarks)
                if len(static_buffer) >= 5 and cooldown_frames == 0:
                    norm_static = normalize_landmarks_buffer(static_buffer)
                    if norm_static.shape[0] == 5:
                        norm_static = np.expand_dims(norm_static, axis=0)
                        prediction = model_static.predict(norm_static, verbose=0)[0]
                        label = label_encoder_static.inverse_transform([np.argmax(prediction)])[0]
                        conf = np.max(prediction)
                        if conf > 0.8 and label != last_prediction:
                            recognized_sign = label
                            recognized_type = "Statyczny"
                            last_prediction = label
                            cooldown_frames = cooldown_threshold
                            static_buffer.clear()
                            dynamic_buffer.clear()
            else:
                static_buffer.clear()
                dynamic_buffer.append(landmarks)
                if len(dynamic_buffer) >= 30 and cooldown_frames == 0:
                    norm_dynamic = normalize_landmarks_buffer(dynamic_buffer)
                    if norm_dynamic.shape[0] == 30:
                        norm_dynamic = np.expand_dims(norm_dynamic, axis=0)
                        prediction = model_dynamic.predict(norm_dynamic, verbose=0)[0]
                        label = label_encoder_dynamic.inverse_transform([np.argmax(prediction)])[0]
                        conf = np.max(prediction)
                        if conf > 0.8 and label != last_prediction:
                            recognized_sign = label
                            recognized_type = "Dynamiczny"
                            last_prediction = label
                            cooldown_frames = cooldown_threshold
                            static_buffer.clear()
                            dynamic_buffer.clear()

            if recognized_sign and recognized_type:
                label_text = f'{recognized_sign} ({recognized_type})'
                label_pos_x = image_width // 2
                label_pos_y = 30
                (text_width, _), _ = cv2.getTextSize(label_text, cv2.FONT_HERSHEY_SIMPLEX, 1.0, 3)
                text_x = label_pos_x - text_width // 2
                cv2.putText(frame, label_text, (text_x, label_pos_y), cv2.FONT_HERSHEY_SIMPLEX,
                            1.0, (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0), 3, cv2.LINE_AA)
        else:
            static_buffer.clear()
            dynamic_buffer.clear()
            recognized_sign = ''
            recognized_type = ''
            last_prediction = None

        cooldown_frames = max(0, cooldown_frames - 1)

        cv2.imshow('Sign Language Recognition', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1748774800.628461   28916 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1748774800.629271   37621 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1-1ubuntu3.1~22.04.3), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1748774800.708091   37613 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774800.733232   37615 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774800.735013   37617 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774800.735096   37611 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774800.736363   37614 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774800.744485   37616 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774800.749581   37612 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748774800.757077   37618 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
