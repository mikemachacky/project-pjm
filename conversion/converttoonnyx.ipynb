# %%
import numpy as np
import pandas as pd

DATASET_PATH = '../dataset/full_dataset.csv'
df = pd.read_csv(DATASET_PATH)
df.head()
# Out:
#    sample_id  frame label  landmark_1_x  landmark_1_y  landmark_1_z  \
# 0          1      0     A      0.345417      0.648431 -1.125724e-07
# 1          1      1     A      0.366266      0.597102 -9.622672e-08
# 2          1      2     A      0.400966      0.572690 -1.089629e-07
# 3          1      3     A      0.418257      0.573744 -1.190043e-07
# 4          1      4     A      0.431913      0.582072 -1.241054e-07
#
#    landmark_2_x  landmark_2_y  landmark_2_z  landmark_3_x  ...  landmark_18_z  \
# 0      0.363545      0.620765     -0.010274      0.367171  ...      -0.003865
# 1      0.391580      0.578109     -0.012907      0.406190  ...       0.000685
# 2      0.424555      0.552354     -0.004017      0.439723  ...      -0.004296
# 3      0.441344      0.563031     -0.007786      0.460869  ...      -0.002903
# 4      0.453692      0.577044     -0.009167      0.474907  ...      -0.004793
#
#    landmark_19_x  landmark_19_y  landmark_19_z  landmark_20_x  landmark_20_y  \
# 0       0.321722       0.551512      -0.008457       0.326903       0.565844
# 1       0.356418       0.497935      -0.004451       0.361665       0.515749
# 2       0.383425       0.481909      -0.009304       0.389207       0.502081
# 3       0.402536       0.489501      -0.009669       0.406139       0.510639
# 4       0.417201       0.501486      -0.012369       0.419653       0.524298
#
#    landmark_20_z  landmark_21_x  landmark_21_y  landmark_21_z
# 0      -0.005724       0.329682       0.577548      -0.001789
# 1      -0.001988       0.363353       0.523833       0.002337
# 2      -0.005430       0.391897       0.513775      -0.000924
# 3      -0.006567       0.409394       0.523706      -0.001918
# 4      -0.008715       0.422120       0.535854      -0.003439
#
# [5 rows x 66 columns]

# %%
from utils.dataset_tools import DatasetTools
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf

# podział na sekwencje
sequences, labels = DatasetTools.divide_into_sequences(df)

# normalizacja punktów względem nadgarstka
sequences = np.array([DatasetTools.normalize_wrist(seq) for seq in sequences])

# Label encoding
encoder = LabelEncoder()
y = encoder.fit_transform(labels)  # 'A'...'Z' itd. -> 0...35

# One-hot encoding (36 klas)
y_cat = tf.keras.utils.to_categorical(y, num_classes=len(encoder.classes_))

# Konwersja typów
X = sequences.astype(np.float32)
print(X.shape, y_cat.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import tf2onnx
#       2 import onnx
#       4 import subprocess
#
# File ~/miniconda3/envs/tf2onnx-env/lib/python3.12/site-packages/tf2onnx/__init__.py:8
#       3 """tf2onnx package."""
#       5 __all__ = ["utils", "graph_matcher", "graph", "graph_builder",
#       6            "tfonnx", "shape_inference", "schemas", "tf_utils", "tf_loader", "convert"]
# ----> 8 import onnx
#       9 from .version import git_version, version as __version__
#      10 from . import verbose_logging as logging
#
# File ~/miniconda3/envs/tf2onnx-env/lib/python3.12/site-packages/onnx/__init__.py:78
#      76 from onnx import serialization
#      77 from onnx.onnx_cpp2py_export import ONNX_ML
# ---> 78 from onnx.external_data_helper import (
#      79     load_external_data_for_model,
#      80     write_external_data_tensors,
#      81     convert_model_to_external_data,
#      82 )
#      83 from onnx.onnx_pb import (
#      84     AttributeProto,
#      85     EXPERIMENTAL,
#    (...)    111     Version,
#     112 )
#     113 from onnx.onnx_operators_pb import OperatorProto, OperatorSetProto
#
# File ~/miniconda3/envs/tf2onnx-env/lib/python3.12/site-packages/onnx/external_data_helper.py:14
#      11 from typing import Callable, Iterable
#      13 import onnx.onnx_cpp2py_export.checker as c_checker
# ---> 14 from onnx.onnx_pb import (
#      15     AttributeProto,
#      16     FunctionProto,
#      17     GraphProto,
#      18     ModelProto,
#      19     TensorProto,
#      20 )
#      23 class ExternalDataInfo:
#      24     def __init__(self, tensor: TensorProto) -> None:
#
# File ~/miniconda3/envs/tf2onnx-env/lib/python3.12/site-packages/onnx/onnx_pb.py:4
#       1 # This file is generated by setup.py. DO NOT EDIT!
# ----> 4 from .onnx_ml_pb2 import *  # noqa
#
# File ~/miniconda3/envs/tf2onnx-env/lib/python3.12/site-packages/onnx/onnx_ml_pb2.py:9
#       7 from google.protobuf import descriptor as _descriptor
#       8 from google.protobuf import descriptor_pool as _descriptor_pool
# ----> 9 from google.protobuf import runtime_version as _runtime_version
#      10 from google.protobuf import symbol_database as _symbol_database
#      11 from google.protobuf.internal import builder as _builder
#
# ImportError: cannot import name 'runtime_version' from 'google.protobuf' (/home/magda/miniconda3/envs/tf2onnx-env/lib/python3.12/site-packages/google/protobuf/__init__.py)

# %%
from sklearn.model_selection import train_test_split

# najpierw train+val vs test (np. 70% : 30%)
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y_cat, test_size=0.3, random_state=42, stratify=y
)

# następnie train vs val (np. 80% : 20% z trainval)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=0.2, random_state=42, stratify=np.argmax(y_trainval, axis=1)
)

print("Train:", X_train.shape, y_train.shape)
print("Val:",   X_val.shape, y_val.shape)
print("Test:",  X_test.shape, y_test.shape)
# Out:
# Train: (12528, 30, 63) (12528, 36)
# Val: (3132, 30, 63) (3132, 36)
# Test: (6712, 30, 63) (6712, 36)

# %%
# !python -m tf2onnx.convert --keras bilstm_model.keras --output bilstm.onnx --opset 18
# Out:
# /usr/bin/python: Error while finding module specification for 'tf2onnx.convert' (ModuleNotFoundError: No module named 'tf2onnx')
