# %%
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
import joblib

# Załaduj modele
model_static = load_model('StaticBiLSTM/static_gestures_model.keras')
label_encoder_static = joblib.load('StaticBiLSTM/static_gestures_labels.pkl')

model_dynamic = load_model('DynamicBiLSTM/dynamic_gestures_model.keras')
label_encoder_dynamic = joblib.load('DynamicBiLSTM/dynamic_gestures_labels.pkl')

# Parametry
motion_threshold = 1.8  # Próg rozróżnienia statyczny/dynamiczny
motion_history = []
motion_history_len = 5
cooldown_frames = 0
cooldown_threshold = 10
recognized_sign = ''
recognized_type = ''
last_prediction = None
static_buffer = []
dynamic_buffer = []

# MediaPipe
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils
def normalize_landmarks_buffer(buffer):
    data = []
    for frame_idx, row in enumerate(buffer):
        if len(row) != 63:
            print(f"[WARNING] Frame {frame_idx} has invalid length {len(row)}")
            continue
        frame_data = {'frame': frame_idx}
        for i in range(21):
            frame_data[f'landmark_{i}_x'] = row[i * 3]
            frame_data[f'landmark_{i}_y'] = row[i * 3 + 1]
            frame_data[f'landmark_{i}_z'] = row[i * 3 + 2]
        data.append(frame_data)

    if len(data) == 0:
        print("[WARNING] No valid frames in buffer")
        return np.zeros((1, 63))

    df = pd.DataFrame(data)
    df = df.sort_values("frame").copy()

    wrist_ref = {
        axis: df[df["frame"] == 0].iloc[0][f"landmark_1_{axis}"]
        for axis in ['x', 'y', 'z']
    }

    for axis in ['x', 'y', 'z']:
        for i in range(1, 21):
            col = f'landmark_{i}_{axis}'
            df[col] = df[col] - wrist_ref[axis]

    norm_buffer = []
    for _, row in df.iterrows():
        landmarks = []
        for i in range(21):
            landmarks.extend([
                row[f'landmark_{i}_x'],
                row[f'landmark_{i}_y'],
                row[f'landmark_{i}_z']
            ])
        norm_buffer.append(landmarks)

    norm_array = np.array(norm_buffer)
    print(f"[DEBUG] Normalized buffer shape: {norm_array.shape}")
    return norm_array

def extract_right_hand_landmarks(results):
    if results.right_hand_landmarks:
        return [coord for lm in results.right_hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]
    return None

def get_hand_bbox(landmarks, image_width, image_height):
    xs = [lm.x * image_width for lm in landmarks.landmark]
    ys = [lm.y * image_height for lm in landmarks.landmark]
    x_min, x_max = max(int(min(xs)), 0), min(int(max(xs)), image_width)
    y_min, y_max = max(int(min(ys)), 0), min(int(max(ys)), image_height)
    return (x_min, y_min, x_max, y_max)

# Inicjalizacja kamery
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

ret, prev_frame = cap.read()
prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        curr_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame_diff = cv2.absdiff(prev_gray, curr_gray)
        motion_level = np.sum(frame_diff) / (frame.shape[0] * frame.shape[1])
        prev_gray = curr_gray.copy()

        # Wygładzanie ruchu
        motion_history.append(motion_level)
        if len(motion_history) > motion_history_len:
            motion_history.pop(0)
        smooth_motion = np.mean(motion_history)

        print(f"[DEBUG] Motion level: {motion_level:.3f}, Smooth motion: {smooth_motion:.3f}")

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image_rgb)
        image_height, image_width, _ = frame.shape

        landmarks = extract_right_hand_landmarks(results)

        if landmarks:
            mp_drawing.draw_landmarks(
                frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

            bbox = get_hand_bbox(results.right_hand_landmarks, image_width, image_height)
            x1, y1, x2, y2 = bbox
            box_color = (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)

            if smooth_motion < motion_threshold:
                dynamic_buffer.clear()
                static_buffer.append(landmarks)
                # print(f"[DEBUG] Static buffer size: {len(static_buffer)}")
                if len(static_buffer) >= 5:
                    if cooldown_frames == 0:
                        # print("[DEBUG] Running static prediction...")
                        norm_static = normalize_landmarks_buffer(static_buffer)
                        if norm_static.shape[0] == 5:
                            norm_static = np.expand_dims(norm_static, axis=0)
                            prediction = model_static.predict(norm_static)[0]
                            label = label_encoder_static.inverse_transform([np.argmax(prediction)])[0]
                            conf = np.max(prediction)
                            print(f"[STATIC] Predicted: {label} (conf: {conf:.2f})")
                            if conf > 0.5 and label != last_prediction:
                               recognized_sign = label
                               recognized_type = "Statyczny"
                               last_prediction = label
                               cooldown_frames = cooldown_threshold
                               static_buffer.clear()
                               dynamic_buffer.clear()
                               print(f"[INFO] Recognized static gesture: {recognized_sign} with confidence {conf:.2f}")
                        else:
                            print("[WARNING] Normalized static buffer shape unexpected:", norm_static.shape)
                        static_buffer.clear()
                    else:
                        print(f"[DEBUG] Static prediction skipped due to cooldown: {cooldown_frames}")
            else:
                static_buffer.clear()
                dynamic_buffer.append(landmarks)
                # print(f"[DEBUG] Dynamic buffer size: {len(dynamic_buffer)}")
                if len(dynamic_buffer) >= 30:
                    if cooldown_frames == 0:
                        # print("[DEBUG] Running dynamic prediction...")
                        norm_dynamic = normalize_landmarks_buffer(dynamic_buffer)
                        if norm_dynamic.shape[0] == 30:
                            norm_dynamic = np.expand_dims(norm_dynamic, axis=0)
                            prediction = model_dynamic.predict(norm_dynamic)[0]
                            label = label_encoder_dynamic.inverse_transform([np.argmax(prediction)])[0]
                            conf = np.max(prediction)
                            print(f"[DYNAMIC] Predicted: {label} (conf: {conf:.2f})")
                            if conf > 0.5 and label != last_prediction:
                                recognized_sign = label
                                recognized_type = "Dynamiczny"
                                last_prediction = label
                                cooldown_frames = cooldown_threshold
                                static_buffer.clear()
                                dynamic_buffer.clear()
                                print(f"[INFO] Recognized dynamic gesture: {recognized_sign} with confidence {conf:.2f}")
                        else:
                            print("[WARNING] Normalized dynamic buffer shape unexpected:", norm_dynamic.shape)
                        dynamic_buffer.clear()
                    else:
                        print(f"[DEBUG] Dynamic prediction skipped due to cooldown: {cooldown_frames}")

            # Rysowanie labela na górze ekranu, wyśrodkowany
            if recognized_sign and recognized_type:
                label_text = f'{recognized_sign} ({recognized_type})'
                label_pos_x = image_width // 2
                label_pos_y = 30
                print(f"[DEBUG] Drawing label: {label_text} at ({label_pos_x}, {label_pos_y})")
                (text_width, text_height), baseline = cv2.getTextSize(
                    label_text, cv2.FONT_HERSHEY_SIMPLEX, 1.0, 3)
                text_x = label_pos_x - text_width // 2
                text_y = label_pos_y
                cv2.putText(
                    frame,
                    label_text,
                    (text_x, text_y),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1.0,
                    (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0),
                    3,
                    lineType=cv2.LINE_AA
                )
        else:
            static_buffer.clear()
            dynamic_buffer.clear()
            recognized_sign = ''
            recognized_type = ''
            last_prediction = None

        cooldown_frames = max(0, cooldown_frames - 1)

        cv2.imshow('Sign Language Recognition', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748950068.564607   35366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1748950068.567573   35525 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1-1ubuntu3.1~22.04.3), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1748950068.642917   35511 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950068.682258   35509 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950068.683969   35510 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950068.685555   35512 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950068.687719   35511 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950068.695947   35509 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950068.703918   35508 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950068.713417   35512 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950068.717908   35511 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# [DEBUG] Motion level: 1.221, Smooth motion: 1.221
# [DEBUG] Motion level: 1.200, Smooth motion: 1.210
# [DEBUG] Motion level: 1.038, Smooth motion: 1.153
# [DEBUG] Motion level: 0.975, Smooth motion: 1.109
# [DEBUG] Motion level: 1.006, Smooth motion: 1.088
# [DEBUG] Motion level: 2.458, Smooth motion: 1.335
# [DEBUG] Motion level: 1.323, Smooth motion: 1.360
# [DEBUG] Motion level: 1.340, Smooth motion: 1.421
# [DEBUG] Motion level: 1.043, Smooth motion: 1.434
# [DEBUG] Motion level: 1.181, Smooth motion: 1.469
# [DEBUG] Motion level: 0.885, Smooth motion: 1.154
# [DEBUG] Motion level: 1.048, Smooth motion: 1.099
# [DEBUG] Motion level: 0.974, Smooth motion: 1.026
# [DEBUG] Motion level: 1.228, Smooth motion: 1.063
# [DEBUG] Motion level: 1.233, Smooth motion: 1.074
# [DEBUG] Motion level: 3.189, Smooth motion: 1.534
# [DEBUG] Motion level: 1.448, Smooth motion: 1.615
# [DEBUG] Motion level: 1.774, Smooth motion: 1.775
# [DEBUG] Motion level: 3.503, Smooth motion: 2.230
# [DEBUG] Motion level: 2.635, Smooth motion: 2.510
# [DEBUG] Motion level: 2.586, Smooth motion: 2.389
# [DEBUG] Motion level: 3.326, Smooth motion: 2.765
# [DEBUG] Motion level: 1.788, Smooth motion: 2.768
# [DEBUG] Motion level: 2.428, Smooth motion: 2.553
# [DEBUG] Motion level: 1.696, Smooth motion: 2.365
# [DEBUG] Motion level: 1.580, Smooth motion: 2.164
# [DEBUG] Motion level: 1.646, Smooth motion: 1.828
# [DEBUG] Motion level: 3.731, Smooth motion: 2.216
# [DEBUG] Motion level: 1.522, Smooth motion: 2.035
# [DEBUG] Motion level: 2.562, Smooth motion: 2.208
# [DEBUG] Motion level: 2.204, Smooth motion: 2.333
# [DEBUG] Motion level: 2.176, Smooth motion: 2.439
# [DEBUG] Motion level: 7.866, Smooth motion: 3.266
# [DEBUG] Motion level: 6.491, Smooth motion: 4.260
# [DEBUG] Motion level: 5.687, Smooth motion: 4.885
# [DEBUG] Motion level: 3.817, Smooth motion: 5.207
# [DEBUG] Motion level: 6.526, Smooth motion: 6.077
# [DEBUG] Motion level: 3.766, Smooth motion: 5.257
# [DEBUG] Motion level: 3.498, Smooth motion: 4.659
# [DEBUG] Motion level: 4.442, Smooth motion: 4.410
# [DEBUG] Motion level: 2.169, Smooth motion: 4.080
# [DEBUG] Motion level: 1.860, Smooth motion: 3.147
# [DEBUG] Motion level: 2.107, Smooth motion: 2.815
# [DEBUG] Motion level: 1.739, Smooth motion: 2.463
# [DEBUG] Motion level: 1.730, Smooth motion: 1.921
# [DEBUG] Motion level: 3.242, Smooth motion: 2.136
# [DEBUG] Motion level: 1.520, Smooth motion: 2.068
# [DEBUG] Motion level: 1.732, Smooth motion: 1.993
# [DEBUG] Motion level: 1.459, Smooth motion: 1.937
# [DEBUG] Motion level: 1.525, Smooth motion: 1.896
# [DEBUG] Motion level: 1.810, Smooth motion: 1.609
# [DEBUG] Motion level: 1.643, Smooth motion: 1.634
# [DEBUG] Motion level: 2.703, Smooth motion: 1.828
# [DEBUG] Motion level: 3.502, Smooth motion: 2.237
# [DEBUG] Motion level: 2.618, Smooth motion: 2.455
# [DEBUG] Motion level: 3.829, Smooth motion: 2.859
# [DEBUG] Motion level: 2.242, Smooth motion: 2.979
# [DEBUG] Motion level: 2.099, Smooth motion: 2.858
# [DEBUG] Motion level: 2.880, Smooth motion: 2.733
# [DEBUG] Motion level: 2.009, Smooth motion: 2.612
# [DEBUG] Motion level: 2.054, Smooth motion: 2.257
# [DEBUG] Motion level: 1.799, Smooth motion: 2.168
# [DEBUG] Motion level: 1.653, Smooth motion: 2.079
# [DEBUG] Motion level: 1.727, Smooth motion: 1.848
# [DEBUG] Motion level: 1.884, Smooth motion: 1.823
# [DEBUG] Motion level: 1.428, Smooth motion: 1.698
# [DEBUG] Motion level: 1.480, Smooth motion: 1.634
# [DEBUG] Motion level: 1.536, Smooth motion: 1.611
# [DEBUG] Motion level: 1.503, Smooth motion: 1.566
# [DEBUG] Motion level: 1.674, Smooth motion: 1.524
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# I0000 00:00:1748950072.245314   35432 cuda_dnn.cc:529] Loaded cuDNN version 90300
# [STATIC] Predicted: B (conf: 0.17)
# [DEBUG] Motion level: 3.022, Smooth motion: 1.843
# [DEBUG] Motion level: 3.101, Smooth motion: 2.167
# [DEBUG] Motion level: 3.632, Smooth motion: 2.586
# [DEBUG] Motion level: 3.409, Smooth motion: 2.968
# [DEBUG] Motion level: 3.290, Smooth motion: 3.291
# [DEBUG] Motion level: 1.345, Smooth motion: 2.955
# [DEBUG] Motion level: 1.401, Smooth motion: 2.615
# [DEBUG] Motion level: 1.335, Smooth motion: 2.156
# [DEBUG] Motion level: 1.324, Smooth motion: 1.739
# [DEBUG] Motion level: 1.378, Smooth motion: 1.356
# [DEBUG] Motion level: 1.353, Smooth motion: 1.358
# [DEBUG] Motion level: 1.362, Smooth motion: 1.350
# [DEBUG] Motion level: 1.316, Smooth motion: 1.346
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: B (conf: 0.50)
# [DEBUG] Motion level: 1.410, Smooth motion: 1.364
# [DEBUG] Motion level: 1.331, Smooth motion: 1.354
# [DEBUG] Motion level: 1.324, Smooth motion: 1.349
# [DEBUG] Motion level: 1.370, Smooth motion: 1.350
# [DEBUG] Motion level: 1.389, Smooth motion: 1.365
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: B (conf: 0.50)
# [DEBUG] Motion level: 1.376, Smooth motion: 1.358
# [DEBUG] Motion level: 1.356, Smooth motion: 1.363
# [DEBUG] Motion level: 1.402, Smooth motion: 1.379
# [DEBUG] Motion level: 1.322, Smooth motion: 1.369
# [DEBUG] Motion level: 1.405, Smooth motion: 1.372
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [STATIC] Predicted: B (conf: 0.50)
# [DEBUG] Motion level: 1.327, Smooth motion: 1.362
# [DEBUG] Motion level: 1.361, Smooth motion: 1.363
# [DEBUG] Motion level: 1.364, Smooth motion: 1.356
# [DEBUG] Motion level: 1.349, Smooth motion: 1.361
# [DEBUG] Motion level: 1.387, Smooth motion: 1.358
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [STATIC] Predicted: B (conf: 0.50)
# [DEBUG] Motion level: 1.373, Smooth motion: 1.367
# [DEBUG] Motion level: 1.327, Smooth motion: 1.360
# [DEBUG] Motion level: 1.319, Smooth motion: 1.351
# [DEBUG] Motion level: 1.333, Smooth motion: 1.348
# [DEBUG] Motion level: 1.477, Smooth motion: 1.366
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [STATIC] Predicted: B (conf: 0.49)
# [DEBUG] Motion level: 1.340, Smooth motion: 1.359
# [DEBUG] Motion level: 1.344, Smooth motion: 1.362
# [DEBUG] Motion level: 1.328, Smooth motion: 1.364
# [DEBUG] Motion level: 1.354, Smooth motion: 1.368
# [DEBUG] Motion level: 1.364, Smooth motion: 1.346
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [STATIC] Predicted: B (conf: 0.49)
# [DEBUG] Motion level: 1.341, Smooth motion: 1.346
# [DEBUG] Motion level: 1.376, Smooth motion: 1.352
# [DEBUG] Motion level: 1.298, Smooth motion: 1.347
# [DEBUG] Motion level: 1.328, Smooth motion: 1.341
# [DEBUG] Motion level: 1.459, Smooth motion: 1.361
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: B (conf: 0.49)
# [DEBUG] Motion level: 1.365, Smooth motion: 1.365
# [DEBUG] Motion level: 1.491, Smooth motion: 1.388
# [DEBUG] Motion level: 1.366, Smooth motion: 1.402
# [DEBUG] Motion level: 1.377, Smooth motion: 1.411
# [DEBUG] Motion level: 1.800, Smooth motion: 1.480
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: B (conf: 0.49)
# [DEBUG] Motion level: 1.491, Smooth motion: 1.505
# [DEBUG] Motion level: 1.341, Smooth motion: 1.475
# [DEBUG] Motion level: 1.366, Smooth motion: 1.475
# [DEBUG] Motion level: 1.338, Smooth motion: 1.467
# [DEBUG] Motion level: 2.155, Smooth motion: 1.538
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [STATIC] Predicted: B (conf: 0.49)
# [DEBUG] Motion level: 1.594, Smooth motion: 1.559
# [DEBUG] Motion level: 2.267, Smooth motion: 1.744
# [DEBUG] Motion level: 2.417, Smooth motion: 1.954
# [DEBUG] Motion level: 1.926, Smooth motion: 2.072
# [DEBUG] Motion level: 4.705, Smooth motion: 2.582
# [DEBUG] Motion level: 3.594, Smooth motion: 2.982
# [DEBUG] Motion level: 3.062, Smooth motion: 3.141
# [DEBUG] Motion level: 1.806, Smooth motion: 3.019
# [DEBUG] Motion level: 1.671, Smooth motion: 2.967
# [DEBUG] Motion level: 1.458, Smooth motion: 2.318
# [DEBUG] Motion level: 1.896, Smooth motion: 1.979
# [DEBUG] Motion level: 1.449, Smooth motion: 1.656
# [DEBUG] Motion level: 1.637, Smooth motion: 1.622
# [DEBUG] Motion level: 2.196, Smooth motion: 1.727
# [DEBUG] Motion level: 1.494, Smooth motion: 1.734
# [DEBUG] Motion level: 1.303, Smooth motion: 1.616
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [STATIC] Predicted: B (conf: 0.53)
# [INFO] Recognized static gesture: B with confidence 0.53
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.332, Smooth motion: 1.592
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.358, Smooth motion: 1.537
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.276, Smooth motion: 1.352
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.353, Smooth motion: 1.324
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.763, Smooth motion: 1.416
# [DEBUG] Static prediction skipped due to cooldown: 5
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.286, Smooth motion: 1.407
# [DEBUG] Static prediction skipped due to cooldown: 4
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.309, Smooth motion: 1.397
# [DEBUG] Static prediction skipped due to cooldown: 3
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.240, Smooth motion: 1.390
# [DEBUG] Static prediction skipped due to cooldown: 2
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.305, Smooth motion: 1.381
# [DEBUG] Static prediction skipped due to cooldown: 1
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.422, Smooth motion: 1.312
# [DEBUG] Normalized buffer shape: (10, 63)
# [WARNING] Normalized static buffer shape unexpected: (10, 63)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.331, Smooth motion: 1.321
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.461, Smooth motion: 1.352
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.281, Smooth motion: 1.360
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.332, Smooth motion: 1.365
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.325, Smooth motion: 1.346
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [STATIC] Predicted: B (conf: 0.55)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.236, Smooth motion: 1.327
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.313, Smooth motion: 1.298
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.297, Smooth motion: 1.301
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.229, Smooth motion: 1.280
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.540, Smooth motion: 1.323
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# [STATIC] Predicted: B (conf: 0.55)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.328, Smooth motion: 1.342
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.338, Smooth motion: 1.346
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.234, Smooth motion: 1.334
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.302, Smooth motion: 1.348
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.432, Smooth motion: 1.327
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: B (conf: 0.54)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.270, Smooth motion: 1.315
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.244, Smooth motion: 1.296
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.625, Smooth motion: 1.375
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.530, Smooth motion: 2.020
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 5.364, Smooth motion: 2.807
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.941, Smooth motion: 2.941
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.900, Smooth motion: 3.272
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.504, Smooth motion: 3.248
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.136, Smooth motion: 2.769
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.866, Smooth motion: 2.069
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.311, Smooth motion: 2.343
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.549, Smooth motion: 2.073
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.999, Smooth motion: 2.172
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.302, Smooth motion: 2.005
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.522, Smooth motion: 2.137
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.358, Smooth motion: 1.746
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.319, Smooth motion: 1.700
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.459, Smooth motion: 1.592
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.981, Smooth motion: 1.728
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.019, Smooth motion: 1.627
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: P (conf: 0.45)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.514, Smooth motion: 1.658
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.868, Smooth motion: 1.768
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.853, Smooth motion: 1.847
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.485, Smooth motion: 1.748
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.130, Smooth motion: 1.770
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.346, Smooth motion: 1.736
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.176, Smooth motion: 1.798
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.134, Smooth motion: 1.854
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.471, Smooth motion: 1.851
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.517, Smooth motion: 1.729
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.250, Smooth motion: 1.710
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.421, Smooth motion: 1.559
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.228, Smooth motion: 1.378
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.213, Smooth motion: 1.526
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: R (conf: 0.49)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.308, Smooth motion: 1.484
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.527, Smooth motion: 1.540
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.496, Smooth motion: 1.554
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.697, Smooth motion: 1.848
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.825, Smooth motion: 2.171
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.014, Smooth motion: 2.312
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.220, Smooth motion: 2.450
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.555, Smooth motion: 2.462
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.386, Smooth motion: 2.200
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.274, Smooth motion: 1.690
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.314, Smooth motion: 1.550
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.317, Smooth motion: 1.369
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.462, Smooth motion: 1.351
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.344, Smooth motion: 1.342
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [STATIC] Predicted: P (conf: 0.44)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.472, Smooth motion: 1.382
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.396, Smooth motion: 1.398
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.559, Smooth motion: 1.447
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.392, Smooth motion: 1.433
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.128, Smooth motion: 1.589
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: C (conf: 0.43)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.671, Smooth motion: 1.629
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.444, Smooth motion: 1.639
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.543, Smooth motion: 1.636
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.419, Smooth motion: 1.841
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.427, Smooth motion: 2.101
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.526, Smooth motion: 2.072
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.689, Smooth motion: 2.121
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.408, Smooth motion: 2.094
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.478, Smooth motion: 1.906
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.439, Smooth motion: 1.508
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.243, Smooth motion: 1.651
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.915, Smooth motion: 1.697
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.690, Smooth motion: 1.753
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.862, Smooth motion: 1.830
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.614, Smooth motion: 1.865
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.809, Smooth motion: 1.778
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.369, Smooth motion: 1.869
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.402, Smooth motion: 1.811
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.458, Smooth motion: 1.730
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.373, Smooth motion: 1.682
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.544, Smooth motion: 1.629
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.648, Smooth motion: 1.485
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.451, Smooth motion: 1.495
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [STATIC] Predicted: R (conf: 0.40)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.336, Smooth motion: 1.670
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.097, Smooth motion: 1.615
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.032, Smooth motion: 1.513
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.095, Smooth motion: 1.402
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.180, Smooth motion: 1.348
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [STATIC] Predicted: R (conf: 0.40)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 0.988, Smooth motion: 1.078
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.037, Smooth motion: 1.066
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.033, Smooth motion: 1.067
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.090, Smooth motion: 1.066
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.741, Smooth motion: 1.178
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: R (conf: 0.44)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.309, Smooth motion: 1.242
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.346, Smooth motion: 1.304
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.424, Smooth motion: 1.582
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.121, Smooth motion: 1.788
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 8.248, Smooth motion: 3.090
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.239, Smooth motion: 3.276
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.122, Smooth motion: 3.631
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.812, Smooth motion: 3.508
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.252, Smooth motion: 3.534
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.757, Smooth motion: 2.236
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.991, Smooth motion: 2.387
# [DEBUG] Motion level: 1.799, Smooth motion: 2.122
# [DEBUG] Motion level: 5.822, Smooth motion: 2.924
# [DEBUG] Motion level: 2.386, Smooth motion: 2.951
# [DEBUG] Motion level: 3.825, Smooth motion: 3.365
# [DEBUG] Motion level: 4.218, Smooth motion: 3.610
# [DEBUG] Motion level: 2.506, Smooth motion: 3.751
# [DEBUG] Motion level: 1.431, Smooth motion: 2.873
# [DEBUG] Motion level: 2.470, Smooth motion: 2.890
# [DEBUG] Motion level: 1.553, Smooth motion: 2.436
# [DEBUG] Motion level: 1.304, Smooth motion: 1.853
# [DEBUG] Motion level: 1.481, Smooth motion: 1.648
# [DEBUG] Motion level: 2.787, Smooth motion: 1.919
# [DEBUG] Motion level: 1.196, Smooth motion: 1.664
# [DEBUG] Motion level: 1.392, Smooth motion: 1.632
# [DEBUG] Motion level: 1.451, Smooth motion: 1.661
# [DEBUG] Motion level: 1.303, Smooth motion: 1.626
# [DEBUG] Motion level: 1.750, Smooth motion: 1.419
# [DEBUG] Motion level: 1.520, Smooth motion: 1.483
# [DEBUG] Motion level: 2.093, Smooth motion: 1.624
# [DEBUG] Motion level: 1.485, Smooth motion: 1.630
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [STATIC] Predicted: R (conf: 0.65)
# [INFO] Recognized static gesture: R with confidence 0.65
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.588, Smooth motion: 1.687
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.256, Smooth motion: 1.588
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.531, Smooth motion: 1.591
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.318, Smooth motion: 1.436
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.773, Smooth motion: 1.493
# [DEBUG] Static prediction skipped due to cooldown: 5
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.325, Smooth motion: 1.441
# [DEBUG] Static prediction skipped due to cooldown: 4
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.327, Smooth motion: 1.455
# [DEBUG] Static prediction skipped due to cooldown: 3
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.128, Smooth motion: 1.374
# [DEBUG] Static prediction skipped due to cooldown: 2
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.224, Smooth motion: 1.355
# [DEBUG] Static prediction skipped due to cooldown: 1
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.124, Smooth motion: 1.226
# [DEBUG] Normalized buffer shape: (10, 63)
# [WARNING] Normalized static buffer shape unexpected: (10, 63)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.172, Smooth motion: 1.195
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.107, Smooth motion: 1.151
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.168, Smooth motion: 1.159
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.108, Smooth motion: 1.136
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.190, Smooth motion: 1.149
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: P (conf: 0.77)
# [INFO] Recognized static gesture: P with confidence 0.77
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.119, Smooth motion: 1.138
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.187, Smooth motion: 1.155
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.122, Smooth motion: 1.145
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.175, Smooth motion: 1.159
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.265, Smooth motion: 1.374
# [DEBUG] Static prediction skipped due to cooldown: 5
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.102, Smooth motion: 1.370
# [DEBUG] Static prediction skipped due to cooldown: 4
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.472, Smooth motion: 1.627
# [DEBUG] Static prediction skipped due to cooldown: 3
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.197, Smooth motion: 1.642
# [DEBUG] Static prediction skipped due to cooldown: 2
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.288, Smooth motion: 1.665
# [DEBUG] Static prediction skipped due to cooldown: 1
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.190, Smooth motion: 1.450
# [DEBUG] Normalized buffer shape: (10, 63)
# [WARNING] Normalized static buffer shape unexpected: (10, 63)
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.339, Smooth motion: 1.497
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.336, Smooth motion: 1.270
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.877, Smooth motion: 1.606
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.487, Smooth motion: 1.646
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.646, Smooth motion: 1.737
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: P (conf: 0.74)
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.627, Smooth motion: 1.795
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.488, Smooth motion: 1.825
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.842, Smooth motion: 1.618
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.451, Smooth motion: 1.611
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.121, Smooth motion: 1.706
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.649, Smooth motion: 1.710
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.495, Smooth motion: 1.712
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [STATIC] Predicted: R (conf: 0.69)
# [INFO] Recognized static gesture: R with confidence 0.69
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.457, Smooth motion: 1.635
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.172, Smooth motion: 1.579
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.213, Smooth motion: 1.397
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.223, Smooth motion: 1.312
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.774, Smooth motion: 1.368
# [DEBUG] Static prediction skipped due to cooldown: 5
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.135, Smooth motion: 1.503
# [DEBUG] Static prediction skipped due to cooldown: 4
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.099, Smooth motion: 1.689
# [DEBUG] Static prediction skipped due to cooldown: 3
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.770, Smooth motion: 2.000
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.115, Smooth motion: 2.178
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.287, Smooth motion: 2.281
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.548, Smooth motion: 2.164
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.339, Smooth motion: 2.012
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.225, Smooth motion: 1.703
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.450, Smooth motion: 1.570
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.281, Smooth motion: 1.369
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.416, Smooth motion: 1.342
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.205, Smooth motion: 1.316
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: P (conf: 0.42)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.232, Smooth motion: 1.317
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.172, Smooth motion: 1.261
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.218, Smooth motion: 1.249
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.706, Smooth motion: 1.306
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.931, Smooth motion: 1.652
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [STATIC] Predicted: P (conf: 0.49)
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 5.270, Smooth motion: 2.459
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.945, Smooth motion: 2.814
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.750, Smooth motion: 3.320
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.460, Smooth motion: 3.471
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 6.008, Smooth motion: 4.087
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.076, Smooth motion: 3.648
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.900, Smooth motion: 3.839
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.156, Smooth motion: 3.520
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.518, Smooth motion: 3.532
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.532, Smooth motion: 2.636
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.376, Smooth motion: 2.496
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.514, Smooth motion: 2.019
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.785, Smooth motion: 2.345
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.490, Smooth motion: 2.139
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.796, Smooth motion: 2.392
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.603, Smooth motion: 2.238
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.548, Smooth motion: 2.445
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.773, Smooth motion: 2.042
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.080, Smooth motion: 2.360
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.538, Smooth motion: 2.508
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.989, Smooth motion: 2.786
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 6.572, Smooth motion: 3.590
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.068, Smooth motion: 4.049
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 7.804, Smooth motion: 4.994
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.165, Smooth motion: 4.920
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.062, Smooth motion: 5.134
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.957, Smooth motion: 4.211
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.595, Smooth motion: 4.117
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.382, Smooth motion: 3.032
# [DEBUG] Drawing label: R (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.418, Smooth motion: 3.083
# [DEBUG] Normalized buffer shape: (30, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# [DYNAMIC] Predicted: CZ (conf: 0.63)
# [INFO] Recognized dynamic gesture: CZ with confidence 0.63
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.947, Smooth motion: 2.660
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 4.916, Smooth motion: 3.252
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.184, Smooth motion: 2.970
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.276, Smooth motion: 3.148
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 7.712, Smooth motion: 4.007
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.476, Smooth motion: 3.913
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.773, Smooth motion: 3.284
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.391, Smooth motion: 3.126
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.373, Smooth motion: 2.745
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.653, Smooth motion: 1.533
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.324, Smooth motion: 1.503
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.700, Smooth motion: 1.488
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.498, Smooth motion: 1.510
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.933, Smooth motion: 1.822
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.125, Smooth motion: 1.916
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.591, Smooth motion: 2.369
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.693, Smooth motion: 2.368
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.712, Smooth motion: 2.411
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.439, Smooth motion: 2.112
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.187, Smooth motion: 1.925
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.560, Smooth motion: 1.518
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.256, Smooth motion: 1.431
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.277, Smooth motion: 1.344
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.499, Smooth motion: 1.356
# [DEBUG] Drawing label: CZ (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.486, Smooth motion: 1.616
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [STATIC] Predicted: P (conf: 0.56)
# [INFO] Recognized static gesture: P with confidence 0.56
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.590, Smooth motion: 1.622
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.307, Smooth motion: 1.632
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.677, Smooth motion: 1.712
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.371, Smooth motion: 1.686
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.237, Smooth motion: 2.036
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.684, Smooth motion: 2.455
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.089, Smooth motion: 2.812
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.672, Smooth motion: 3.410
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.774, Smooth motion: 3.891
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.027, Smooth motion: 3.449
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.224, Smooth motion: 3.157
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.064, Smooth motion: 3.352
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.111, Smooth motion: 2.840
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.971, Smooth motion: 2.880
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 5.658, Smooth motion: 3.606
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.293, Smooth motion: 3.820
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.185, Smooth motion: 3.844
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.495, Smooth motion: 4.320
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 6.797, Smooth motion: 4.885
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.704, Smooth motion: 4.295
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.382, Smooth motion: 4.512
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.846, Smooth motion: 4.645
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 5.367, Smooth motion: 4.819
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 5.924, Smooth motion: 4.645
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.605, Smooth motion: 4.825
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 6.611, Smooth motion: 5.271
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 6.066, Smooth motion: 5.515
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 7.130, Smooth motion: 5.867
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 6.366, Smooth motion: 5.956
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.537, Smooth motion: 5.942
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.875, Smooth motion: 4.995
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 3.255, Smooth motion: 4.432
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.670, Smooth motion: 3.340
# [DEBUG] Drawing label: P (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.415, Smooth motion: 2.550
# [DEBUG] Normalized buffer shape: (30, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [DYNAMIC] Predicted: J (conf: 0.51)
# [INFO] Recognized dynamic gesture: J with confidence 0.51
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.791, Smooth motion: 2.201
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.573, Smooth motion: 2.341
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.083, Smooth motion: 2.106
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.285, Smooth motion: 2.429
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 7.846, Smooth motion: 3.516
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.274, Smooth motion: 3.812
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.973, Smooth motion: 3.892
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.407, Smooth motion: 4.157
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.259, Smooth motion: 3.952
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 5.313, Smooth motion: 3.445
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.222, Smooth motion: 3.235
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.342, Smooth motion: 3.109
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.758, Smooth motion: 2.779
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.657, Smooth motion: 2.858
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.578, Smooth motion: 2.111
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.744, Smooth motion: 2.016
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.416, Smooth motion: 1.831
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.191, Smooth motion: 1.917
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.321, Smooth motion: 1.650
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.554, Smooth motion: 1.645
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.469, Smooth motion: 1.590
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.264, Smooth motion: 1.560
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.277, Smooth motion: 1.377
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [STATIC] Predicted: P (conf: 0.37)
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.678, Smooth motion: 1.648
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.510, Smooth motion: 1.640
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.256, Smooth motion: 1.597
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.257, Smooth motion: 1.995
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.619, Smooth motion: 2.264
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 1.885, Smooth motion: 2.105
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.072, Smooth motion: 2.418
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 3.902, Smooth motion: 2.947
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.371, Smooth motion: 2.770
# [DEBUG] Drawing label: J (Dynamiczny) at (320, 30)
# [DEBUG] Motion level: 2.025, Smooth motion: 2.651
# [DEBUG] Motion level: 3.003, Smooth motion: 2.875
# [DEBUG] Motion level: 3.518, Smooth motion: 2.964
# [DEBUG] Motion level: 2.250, Smooth motion: 2.633
# [DEBUG] Motion level: 4.021, Smooth motion: 2.963
# [DEBUG] Motion level: 2.296, Smooth motion: 3.017
# [DEBUG] Motion level: 2.784, Smooth motion: 2.974
# [DEBUG] Motion level: 3.415, Smooth motion: 2.953
# [DEBUG] Motion level: 2.571, Smooth motion: 3.017
# [DEBUG] Motion level: 2.965, Smooth motion: 2.806
# [DEBUG] Motion level: 2.858, Smooth motion: 2.918
# [DEBUG] Motion level: 1.886, Smooth motion: 2.739
# [DEBUG] Motion level: 1.890, Smooth motion: 2.434
# [DEBUG] Motion level: 2.989, Smooth motion: 2.518
# [DEBUG] Motion level: 2.185, Smooth motion: 2.362
# [DEBUG] Motion level: 5.116, Smooth motion: 2.813
# [DEBUG] Motion level: 1.509, Smooth motion: 2.738
# [DEBUG] Motion level: 2.513, Smooth motion: 2.862
# [DEBUG] Motion level: 1.797, Smooth motion: 2.624
# [DEBUG] Motion level: 2.365, Smooth motion: 2.660
# [DEBUG] Motion level: 2.299, Smooth motion: 2.097
# [DEBUG] Motion level: 4.252, Smooth motion: 2.645
# [DEBUG] Motion level: 2.265, Smooth motion: 2.596
# [DEBUG] Motion level: 3.973, Smooth motion: 3.031
# [DEBUG] Motion level: 2.312, Smooth motion: 3.020
# [DEBUG] Motion level: 3.118, Smooth motion: 3.184
# [DEBUG] Motion level: 2.478, Smooth motion: 2.829
# [DEBUG] Motion level: 2.555, Smooth motion: 2.887
# [DEBUG] Motion level: 2.321, Smooth motion: 2.557
# [DEBUG] Motion level: 2.505, Smooth motion: 2.596
# [DEBUG] Motion level: 2.345, Smooth motion: 2.441
# [DEBUG] Motion level: 2.531, Smooth motion: 2.452
# [DEBUG] Motion level: 2.290, Smooth motion: 2.399
# [DEBUG] Motion level: 2.426, Smooth motion: 2.420
# [DEBUG] Motion level: 2.112, Smooth motion: 2.341
# [DEBUG] Motion level: 3.190, Smooth motion: 2.510
# [DEBUG] Motion level: 2.105, Smooth motion: 2.425
# [DEBUG] Motion level: 3.833, Smooth motion: 2.734
# [DEBUG] Motion level: 2.102, Smooth motion: 2.669
# [DEBUG] Motion level: 2.520, Smooth motion: 2.750
# [DEBUG] Motion level: 1.945, Smooth motion: 2.501
# [DEBUG] Motion level: 2.497, Smooth motion: 2.580
# [DEBUG] Motion level: 3.173, Smooth motion: 2.448
# [DEBUG] Motion level: 2.097, Smooth motion: 2.446
# ...
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.935, Smooth motion: 2.069
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.325, Smooth motion: 2.052
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.613, Smooth motion: 1.997
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.823, Smooth motion: 1.887
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.898, Smooth motion: 1.919
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.456, Smooth motion: 1.823
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.348, Smooth motion: 1.828
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.389, Smooth motion: 1.583
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.702, Smooth motion: 1.559
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.420, Smooth motion: 1.463
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.705, Smooth motion: 1.513
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.333, Smooth motion: 1.510
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: B (conf: 0.24)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.675, Smooth motion: 1.567
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.262, Smooth motion: 1.479
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.498, Smooth motion: 1.494
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.218, Smooth motion: 1.397
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.625, Smooth motion: 1.456
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: B (conf: 0.23)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.221, Smooth motion: 1.365
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.488, Smooth motion: 1.410
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.296, Smooth motion: 1.370
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.515, Smooth motion: 1.429
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.968, Smooth motion: 1.698
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: B (conf: 0.23)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.958, Smooth motion: 1.845
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.383, Smooth motion: 1.824
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.289, Smooth motion: 1.823
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.379, Smooth motion: 1.796
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.671, Smooth motion: 1.536
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.210, Smooth motion: 1.386
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.448, Smooth motion: 1.399
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.215, Smooth motion: 1.385
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: B (conf: 0.26)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.308, Smooth motion: 1.370
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.401, Smooth motion: 1.316
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.188, Smooth motion: 1.312
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.337, Smooth motion: 1.290
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.238, Smooth motion: 1.494
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [STATIC] Predicted: B (conf: 0.25)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.380, Smooth motion: 1.509
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.543, Smooth motion: 1.537
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.410, Smooth motion: 1.581
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.853, Smooth motion: 1.685
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.684, Smooth motion: 1.774
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: B (conf: 0.24)
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.774, Smooth motion: 1.853
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.451, Smooth motion: 1.834
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.616, Smooth motion: 1.875
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.310, Smooth motion: 1.767
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.744, Smooth motion: 1.579
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.856, Smooth motion: 1.595
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 1.577, Smooth motion: 1.621
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.849, Smooth motion: 1.867
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.356, Smooth motion: 2.076
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 2.982, Smooth motion: 2.324
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 5.400, Smooth motion: 3.033
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 4.186, Smooth motion: 3.554
# [DEBUG] Drawing label: B (Statyczny) at (320, 30)
# [DEBUG] Motion level: 7.002, Smooth motion: 4.385
# [DEBUG] Motion level: 4.692, Smooth motion: 4.852
# [DEBUG] Motion level: 4.217, Smooth motion: 5.100
# [DEBUG] Motion level: 1.340, Smooth motion: 4.288
# [DEBUG] Motion level: 1.567, Smooth motion: 3.764
# [DEBUG] Motion level: 1.285, Smooth motion: 2.620
# [DEBUG] Motion level: 1.516, Smooth motion: 1.985
# [DEBUG] Motion level: 1.525, Smooth motion: 1.447
# [DEBUG] Motion level: 1.994, Smooth motion: 1.578
# [DEBUG] Motion level: 1.486, Smooth motion: 1.561
# [DEBUG] Motion level: 1.524, Smooth motion: 1.609
# [DEBUG] Motion level: 1.404, Smooth motion: 1.587
# [DEBUG] Motion level: 1.753, Smooth motion: 1.632
# [DEBUG] Motion level: 3.029, Smooth motion: 1.839
# [DEBUG] Motion level: 5.577, Smooth motion: 2.657
# [DEBUG] Motion level: 4.008, Smooth motion: 3.154
# [DEBUG] Motion level: 4.790, Smooth motion: 3.831
# [DEBUG] Motion level: 3.462, Smooth motion: 4.173
# [DEBUG] Motion level: 2.868, Smooth motion: 4.141
# [DEBUG] Motion level: 3.886, Smooth motion: 3.803
# [DEBUG] Motion level: 4.329, Smooth motion: 3.867
# [DEBUG] Motion level: 2.176, Smooth motion: 3.344
# [DEBUG] Motion level: 2.783, Smooth motion: 3.208
# [DEBUG] Motion level: 1.857, Smooth motion: 3.006
# [DEBUG] Motion level: 2.392, Smooth motion: 2.708
# [DEBUG] Motion level: 2.357, Smooth motion: 2.313
# [DEBUG] Motion level: 1.497, Smooth motion: 2.177
# [DEBUG] Motion level: 1.471, Smooth motion: 1.915
# [DEBUG] Motion level: 1.991, Smooth motion: 1.942
# [DEBUG] Motion level: 1.580, Smooth motion: 1.779
# [DEBUG] Motion level: 1.282, Smooth motion: 1.564
# [DEBUG] Motion level: 1.243, Smooth motion: 1.514
# [DEBUG] Motion level: 1.785, Smooth motion: 1.576
# [DEBUG] Motion level: 1.572, Smooth motion: 1.492
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: B (conf: 0.24)
# [DEBUG] Motion level: 2.223, Smooth motion: 1.621
# [DEBUG] Motion level: 1.660, Smooth motion: 1.697
# [DEBUG] Motion level: 2.136, Smooth motion: 1.875
# [DEBUG] Motion level: 1.602, Smooth motion: 1.839
# [DEBUG] Motion level: 2.957, Smooth motion: 2.116
# [DEBUG] Motion level: 1.860, Smooth motion: 2.043
# [DEBUG] Motion level: 1.387, Smooth motion: 1.988
# [DEBUG] Motion level: 1.335, Smooth motion: 1.828
# [DEBUG] Motion level: 1.580, Smooth motion: 1.824
# [DEBUG] Motion level: 1.406, Smooth motion: 1.513
# [DEBUG] Motion level: 1.175, Smooth motion: 1.377
# [DEBUG] Motion level: 1.311, Smooth motion: 1.361
# [DEBUG] Motion level: 1.144, Smooth motion: 1.323
# [DEBUG] Motion level: 1.267, Smooth motion: 1.261
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [STATIC] Predicted: B (conf: 0.22)
# [DEBUG] Motion level: 1.140, Smooth motion: 1.207
# [DEBUG] Motion level: 1.374, Smooth motion: 1.247
# [DEBUG] Motion level: 1.204, Smooth motion: 1.226
# [DEBUG] Motion level: 1.545, Smooth motion: 1.306
# [DEBUG] Motion level: 2.200, Smooth motion: 1.493
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: B (conf: 0.22)
# [DEBUG] Motion level: 1.251, Smooth motion: 1.515
# [DEBUG] Motion level: 1.635, Smooth motion: 1.567
# [DEBUG] Motion level: 1.457, Smooth motion: 1.618
# [DEBUG] Motion level: 1.543, Smooth motion: 1.617
# [DEBUG] Motion level: 3.421, Smooth motion: 1.861
# [DEBUG] Motion level: 1.135, Smooth motion: 1.838
# [DEBUG] Motion level: 1.319, Smooth motion: 1.775
# [DEBUG] Motion level: 1.215, Smooth motion: 1.726
# [DEBUG] Motion level: 2.849, Smooth motion: 1.988
# [DEBUG] Motion level: 1.173, Smooth motion: 1.538
# [DEBUG] Motion level: 1.370, Smooth motion: 1.585
# [DEBUG] Motion level: 1.157, Smooth motion: 1.553
# [DEBUG] Motion level: 1.232, Smooth motion: 1.556
# [DEBUG] Motion level: 1.154, Smooth motion: 1.217
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: B (conf: 0.21)
# [DEBUG] Motion level: 1.282, Smooth motion: 1.239
# [DEBUG] Motion level: 1.207, Smooth motion: 1.206
# [DEBUG] Motion level: 1.264, Smooth motion: 1.228
# [DEBUG] Motion level: 1.180, Smooth motion: 1.217
# [DEBUG] Motion level: 2.341, Smooth motion: 1.455
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: B (conf: 0.21)
# [DEBUG] Motion level: 1.371, Smooth motion: 1.473
# [DEBUG] Motion level: 1.226, Smooth motion: 1.476
# [DEBUG] Motion level: 1.417, Smooth motion: 1.507
# [DEBUG] Motion level: 1.303, Smooth motion: 1.532
# [DEBUG] Motion level: 1.755, Smooth motion: 1.415
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: B (conf: 0.22)
# [DEBUG] Motion level: 1.651, Smooth motion: 1.471
# [DEBUG] Motion level: 2.755, Smooth motion: 1.776
# [DEBUG] Motion level: 1.553, Smooth motion: 1.804
# [DEBUG] Motion level: 1.308, Smooth motion: 1.805
# [DEBUG] Motion level: 2.172, Smooth motion: 1.888
# [DEBUG] Motion level: 1.303, Smooth motion: 1.818
# [DEBUG] Motion level: 1.338, Smooth motion: 1.535
# [DEBUG] Motion level: 1.617, Smooth motion: 1.548
# [DEBUG] Motion level: 1.253, Smooth motion: 1.537
# [DEBUG] Motion level: 1.340, Smooth motion: 1.370
# [DEBUG] Motion level: 1.218, Smooth motion: 1.353
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: B (conf: 0.22)
# [DEBUG] Motion level: 1.341, Smooth motion: 1.354
# [DEBUG] Motion level: 1.175, Smooth motion: 1.265
# [DEBUG] Motion level: 1.214, Smooth motion: 1.258
# [DEBUG] Motion level: 1.185, Smooth motion: 1.227
# [DEBUG] Motion level: 1.409, Smooth motion: 1.265
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [STATIC] Predicted: B (conf: 0.22)
# [DEBUG] Motion level: 1.245, Smooth motion: 1.246
# [DEBUG] Motion level: 1.137, Smooth motion: 1.238
# [DEBUG] Motion level: 1.184, Smooth motion: 1.232
# [DEBUG] Motion level: 1.131, Smooth motion: 1.221
# [DEBUG] Motion level: 1.336, Smooth motion: 1.207
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [STATIC] Predicted: B (conf: 0.22)
# [DEBUG] Motion level: 1.189, Smooth motion: 1.195
# [DEBUG] Motion level: 1.232, Smooth motion: 1.215
# [DEBUG] Motion level: 1.152, Smooth motion: 1.208
# [DEBUG] Motion level: 1.230, Smooth motion: 1.228
# [DEBUG] Motion level: 1.347, Smooth motion: 1.230
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [STATIC] Predicted: B (conf: 0.22)
# [DEBUG] Motion level: 1.157, Smooth motion: 1.224
# [DEBUG] Motion level: 1.126, Smooth motion: 1.202
# [DEBUG] Motion level: 1.276, Smooth motion: 1.227
# [DEBUG] Motion level: 1.200, Smooth motion: 1.221
# [DEBUG] Motion level: 2.971, Smooth motion: 1.546
# [DEBUG] Normalized buffer shape: (5, 63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [STATIC] Predicted: B (conf: 0.21)
# [DEBUG] Motion level: 3.862, Smooth motion: 2.087
# [DEBUG] Motion level: 4.055, Smooth motion: 2.673
# [DEBUG] Motion level: 4.898, Smooth motion: 3.397
# [DEBUG] Motion level: 3.448, Smooth motion: 3.847
# [DEBUG] Motion level: 7.689, Smooth motion: 4.790
# [DEBUG] Motion level: 5.628, Smooth motion: 5.144
# [DEBUG] Motion level: 3.710, Smooth motion: 5.075
# [DEBUG] Motion level: 3.837, Smooth motion: 4.862
# [DEBUG] Motion level: 6.382, Smooth motion: 5.449
# [DEBUG] Motion level: 4.197, Smooth motion: 4.751
# [DEBUG] Motion level: 8.169, Smooth motion: 5.259
# [DEBUG] Motion level: 4.852, Smooth motion: 5.487
# [DEBUG] Motion level: 8.373, Smooth motion: 6.394
# [DEBUG] Motion level: 5.333, Smooth motion: 6.185
# [DEBUG] Motion level: 7.675, Smooth motion: 6.880
# [DEBUG] Motion level: 4.472, Smooth motion: 6.141
# [DEBUG] Motion level: 4.181, Smooth motion: 6.007
# [DEBUG] Motion level: 5.900, Smooth motion: 5.512
# [DEBUG] Motion level: 3.573, Smooth motion: 5.160
# [DEBUG] Motion level: 5.253, Smooth motion: 4.676
# [DEBUG] Motion level: 3.355, Smooth motion: 4.452
# [DEBUG] Motion level: 5.132, Smooth motion: 4.642
# [DEBUG] Motion level: 3.207, Smooth motion: 4.104
# [DEBUG] Motion level: 4.588, Smooth motion: 4.307
# [DEBUG] Motion level: 2.602, Smooth motion: 3.777
# [DEBUG] Motion level: 3.425, Smooth motion: 3.791
# [DEBUG] Motion level: 2.279, Smooth motion: 3.220
# [DEBUG] Motion level: 4.466, Smooth motion: 3.472
# [DEBUG] Motion level: 3.998, Smooth motion: 3.354
# [DEBUG] Motion level: 4.724, Smooth motion: 3.779
# [DEBUG] Motion level: 2.910, Smooth motion: 3.676
# [DEBUG] Motion level: 5.044, Smooth motion: 4.228
# [DEBUG] Motion level: 3.997, Smooth motion: 4.135
# [DEBUG] Motion level: 7.993, Smooth motion: 4.934
# [DEBUG] Motion level: 9.406, Smooth motion: 5.870
# [DEBUG] Motion level: 7.000, Smooth motion: 6.688
# [DEBUG] Motion level: 7.906, Smooth motion: 7.260
# [DEBUG] Motion level: 3.248, Smooth motion: 7.110
# [DEBUG] Motion level: 2.524, Smooth motion: 6.017
# [DEBUG] Motion level: 2.106, Smooth motion: 4.557
# [DEBUG] Motion level: 4.146, Smooth motion: 3.986
# [DEBUG] Motion level: 2.349, Smooth motion: 2.875
# [DEBUG] Motion level: 2.171, Smooth motion: 2.659
# [DEBUG] Motion level: 3.412, Smooth motion: 2.837
# [DEBUG] Motion level: 4.115, Smooth motion: 3.239
# [DEBUG] Motion level: 3.002, Smooth motion: 3.010
# [DEBUG] Motion level: 3.904, Smooth motion: 3.321
# [DEBUG] Motion level: 3.393, Smooth motion: 3.565
# [DEBUG] Motion level: 2.462, Smooth motion: 3.375
# [DEBUG] Motion level: 4.004, Smooth motion: 3.353
# [DEBUG] Motion level: 2.614, Smooth motion: 3.275
# [DEBUG] Motion level: 4.512, Smooth motion: 3.397
# [DEBUG] Motion level: 2.400, Smooth motion: 3.198
# [DEBUG] Motion level: 3.593, Smooth motion: 3.424
# [DEBUG] Motion level: 2.481, Smooth motion: 3.120
# [DEBUG] Motion level: 3.270, Smooth motion: 3.251
# [DEBUG] Motion level: 2.116, Smooth motion: 2.772
# [DEBUG] Motion level: 3.166, Smooth motion: 2.925
# [DEBUG] Motion level: 2.132, Smooth motion: 2.633
# [DEBUG] Motion level: 3.939, Smooth motion: 2.925
# [DEBUG] Motion level: 3.130, Smooth motion: 2.897
# [DEBUG] Motion level: 2.118, Smooth motion: 2.897
# [DEBUG] Motion level: 3.404, Smooth motion: 2.945
# [DEBUG] Motion level: 2.443, Smooth motion: 3.007
# [DEBUG] Motion level: 3.672, Smooth motion: 2.953
# [DEBUG] Motion level: 2.454, Smooth motion: 2.818
# [DEBUG] Motion level: 5.054, Smooth motion: 3.405
# [DEBUG] Motion level: 2.996, Smooth motion: 3.324

# %%
import cv2
import mediapipe as mp
import numpy as np
from tensorflow.keras.models import load_model
import joblib

# Załaduj modele
model_static = load_model('StaticBiLSTM/static_gestures_model.keras')
label_encoder_static = joblib.load('StaticBiLSTM/static_gestures_labels.pkl')

model_dynamic = load_model('DynamicBiLSTM/dynamic_gestures_model.keras')
label_encoder_dynamic = joblib.load('DynamicBiLSTM/dynamic_gestures_labels.pkl')

# Parametry
motion_threshold = 1.8
motion_history = []
motion_history_len = 5
cooldown_frames = 0
cooldown_threshold = 10
recognized_sign = ''
recognized_type = ''
last_prediction = None
static_buffer = []
dynamic_buffer = []

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

def normalize_landmarks_buffer(buffer):
    buffer = np.array(buffer)
    if buffer.shape[0] == 0:
        return np.zeros((1, 63))
    wrist_ref = buffer[0, 3:6]  # landmark_1 x,y,z
    norm_buffer = buffer.copy()
    for i in range(1, 21):
        norm_buffer[:, i*3:(i+1)*3] -= wrist_ref
    return norm_buffer

def extract_right_hand_landmarks(results):
    if results.right_hand_landmarks:
        return [coord for lm in results.right_hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]
    return None

def get_hand_bbox(landmarks, image_width, image_height):
    xs = [lm.x * image_width for lm in landmarks.landmark]
    ys = [lm.y * image_height for lm in landmarks.landmark]
    x_min, x_max = max(int(min(xs)), 0), min(int(max(xs)), image_width)
    y_min, y_max = max(int(min(ys)), 0), min(int(max(ys)), image_height)
    return (x_min, y_min, x_max, y_max)

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

ret, prev_frame = cap.read()
prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        curr_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame_diff = cv2.absdiff(prev_gray, curr_gray)
        motion_level = np.sum(frame_diff) / (frame.shape[0] * frame.shape[1])
        prev_gray = curr_gray.copy()

        motion_history.append(motion_level)
        if len(motion_history) > motion_history_len:
            motion_history.pop(0)
        smooth_motion = np.mean(motion_history)

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image_rgb)
        image_height, image_width, _ = frame.shape

        landmarks = extract_right_hand_landmarks(results)

        if landmarks:
            mp_drawing.draw_landmarks(frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
            bbox = get_hand_bbox(results.right_hand_landmarks, image_width, image_height)
            x1, y1, x2, y2 = bbox
            box_color = (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)

            if smooth_motion < motion_threshold:
                dynamic_buffer.clear()
                static_buffer.append(landmarks)
                if len(static_buffer) >= 5 and cooldown_frames == 0:
                    norm_static = normalize_landmarks_buffer(static_buffer)
                    if norm_static.shape[0] == 5:
                        norm_static = np.expand_dims(norm_static, axis=0)
                        prediction = model_static.predict(norm_static, verbose=0)[0]
                        label = label_encoder_static.inverse_transform([np.argmax(prediction)])[0]
                        conf = np.max(prediction)
                        if conf > 0.8 and label != last_prediction:
                            recognized_sign = label
                            recognized_type = "Statyczny"
                            last_prediction = label
                            cooldown_frames = cooldown_threshold
                            static_buffer.clear()
                            dynamic_buffer.clear()
            else:
                static_buffer.clear()
                dynamic_buffer.append(landmarks)
                if len(dynamic_buffer) >= 30 and cooldown_frames == 0:
                    norm_dynamic = normalize_landmarks_buffer(dynamic_buffer)
                    if norm_dynamic.shape[0] == 30:
                        norm_dynamic = np.expand_dims(norm_dynamic, axis=0)
                        prediction = model_dynamic.predict(norm_dynamic, verbose=0)[0]
                        label = label_encoder_dynamic.inverse_transform([np.argmax(prediction)])[0]
                        conf = np.max(prediction)
                        if conf > 0.8 and label != last_prediction:
                            recognized_sign = label
                            recognized_type = "Dynamiczny"
                            last_prediction = label
                            cooldown_frames = cooldown_threshold
                            static_buffer.clear()
                            dynamic_buffer.clear()

            if recognized_sign and recognized_type:
                label_text = f'{recognized_sign} ({recognized_type})'
                label_pos_x = image_width // 2
                label_pos_y = 30
                (text_width, _), _ = cv2.getTextSize(label_text, cv2.FONT_HERSHEY_SIMPLEX, 1.0, 3)
                text_x = label_pos_x - text_width // 2
                cv2.putText(frame, label_text, (text_x, label_pos_y), cv2.FONT_HERSHEY_SIMPLEX,
                            1.0, (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0), 3, cv2.LINE_AA)
        else:
            static_buffer.clear()
            dynamic_buffer.clear()
            recognized_sign = ''
            recognized_type = ''
            last_prediction = None

        cooldown_frames = max(0, cooldown_frames - 1)

        cv2.imshow('Sign Language Recognition', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1748950510.030400   35366 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1748950510.031475   38505 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1-1ubuntu3.1~22.04.3), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1748950510.100607   38497 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950510.136915   38496 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950510.139891   38498 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950510.139949   38499 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950510.142065   38496 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950510.147875   38498 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950510.151018   38502 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748950510.151800   38499 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 76
#      73 smooth_motion = np.mean(motion_history)
#      75 image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# ---> 76 results = holistic.process(image_rgb)
#      77 image_height, image_width, _ = frame.shape
#      79 landmarks = extract_right_hand_landmarks(results)
#
# File ~/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages/mediapipe/python/solutions/holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)    157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~/Documents/Github/project-pjm/.venv/lib/python3.12/site-packages/mediapipe/python/solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Śledzenie odległości punktów

# %%
import cv2
import mediapipe as mp
import numpy as np
from tensorflow.keras.models import load_model
import joblib

# Załaduj modele
model_static = load_model('StaticBiLSTM/static_gestures_model.keras')
model_dynamic = load_model('DynamicBiLSTM/dynamic_gestures_model.keras')
label_encoder_static = joblib.load('StaticBiLSTM/static_gestures_labels.pkl')
label_encoder_dynamic = joblib.load('DynamicBiLSTM/dynamic_gestures_labels.pkl')

# Parametry

cooldown_frames = 0
cooldown_threshold = 10
recognized_sign = ''
recognized_type = ''
last_prediction = None
static_buffer = []
dynamic_buffer = []

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

def normalize_landmarks_buffer(buffer):
    buffer = np.array(buffer)
    if buffer.shape[0] == 0 or buffer.shape[1] != 63:
        return np.zeros((1, 63))  # awaryjnie
    wrist_ref = buffer[0, 3:6]  # landmark_1_x, _y, _z
    norm_buffer = buffer.copy()
    for i in range(1, 21):  # zakres 1 do 20 (czyli i*3 < 63)
        norm_buffer[:, i*3:(i+1)*3] -= wrist_ref
    return norm_buffer

def extract_right_hand_landmarks(results):
    if results.right_hand_landmarks:
        return [coord for lm in results.right_hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]
    return None

def get_hand_centroid(landmarks):
    # landmarks: lista 63 floatów (21 punktów x 3)
    points = np.array(landmarks).reshape(21, 3)
    centroid = points[:, :2].mean(axis=0)  # średnia x,y (ignorujemy z)
    return centroid

def get_hand_bbox(landmarks, image_width, image_height):
    xs = [lm.x * image_width for lm in landmarks.landmark]
    ys = [lm.y * image_height for lm in landmarks.landmark]
    x_min, x_max = max(int(min(xs)), 0), min(int(max(xs)), image_width)
    y_min, y_max = max(int(min(ys)), 0), min(int(max(ys)), image_height)
    return (x_min, y_min, x_max, y_max)

def landmarks_movement(prev, curr):
    """
    Oblicza średnią odległość L2 między odpowiadającymi landmarkami
    prev, curr: listy 63 floatów (21 punktów x 3)
    """
    prev_pts = np.array(prev).reshape(21, 3)
    curr_pts = np.array(curr).reshape(21, 3)
    distances = np.linalg.norm(curr_pts - prev_pts, axis=1)  # odległość L2 dla każdego punktu
    return np.mean(distances)

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

prev_landmarks = None

with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image_rgb)
        image_height, image_width, _ = frame.shape

        landmarks = extract_right_hand_landmarks(results)

        if landmarks:
            mp_drawing.draw_landmarks(frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

            if prev_landmarks is None:
                movement = 0.0
            else:
                movement = landmarks_movement(prev_landmarks, landmarks)
            prev_landmarks = landmarks

            # Próg zmiany pozycji landmarków (dostosuj eksperymentalnie)
            movement_threshold = 0.005

            bbox = get_hand_bbox(results.right_hand_landmarks, image_width, image_height)
            x1, y1, x2, y2 = bbox

            if movement < movement_threshold:
                # Gest statyczny
                dynamic_buffer.clear()
                static_buffer.append(landmarks)
                if len(static_buffer) >= 5 and cooldown_frames == 0:
                    norm_static = normalize_landmarks_buffer(static_buffer)
                    if norm_static.shape[0] == 5:
                        norm_static = np.expand_dims(norm_static, axis=0)
                        prediction = model_static.predict(norm_static, verbose=0)[0]
                        label = label_encoder_static.inverse_transform([np.argmax(prediction)])[0]
                        conf = np.max(prediction)
                        if conf > 0.3:
                            recognized_sign = label
                            recognized_type = "Statyczny"
                            last_prediction = label
                            cooldown_frames = cooldown_threshold
                            static_buffer.clear()
                            dynamic_buffer.clear()
            else:
                # Gest dynamiczny
                static_buffer.clear()
                dynamic_buffer.append(landmarks)
                if len(dynamic_buffer) >= 30 and cooldown_frames == 0:
                    norm_dynamic = normalize_landmarks_buffer(dynamic_buffer)
                    if norm_dynamic.shape[0] == 30:
                        norm_dynamic = np.expand_dims(norm_dynamic, axis=0)
                        prediction = model_dynamic.predict(norm_dynamic, verbose=0)[0]
                        label = label_encoder_dynamic.inverse_transform([np.argmax(prediction)])[0]
                        conf = np.max(prediction)
                        if conf > 0.3:
                            recognized_sign = label
                            recognized_type = "Dynamiczny"
                            last_prediction = label
                            cooldown_frames = cooldown_threshold
                            static_buffer.clear()
                            dynamic_buffer.clear()

            box_color = (0, 255, 0) if recognized_type == "Statyczny" else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)

            if recognized_sign and recognized_type:
                label_text = f'{recognized_sign} ({recognized_type})'
                label_pos_x = image_width // 2
                label_pos_y = 30
                (text_width, _), _ = cv2.getTextSize(label_text, cv2.FONT_HERSHEY_SIMPLEX, 1.0, 3)
                text_x = label_pos_x - text_width // 2
                cv2.putText(frame, label_text, (text_x, label_pos_y), cv2.FONT_HERSHEY_SIMPLEX,
                            1.0, box_color, 3, cv2.LINE_AA)
        else:
            static_buffer.clear()
            dynamic_buffer.clear()
            recognized_sign = ''
            recognized_type = ''
            last_prediction = None
            prev_landmarks = None

        cooldown_frames = max(0, cooldown_frames - 1)

        cv2.imshow('Sign Language Recognition', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-06-03 14:17:12.343758: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748953032.362274   46199 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748953032.367852   46199 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748953032.382164   46199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748953032.382186   46199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748953032.382188   46199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748953032.382190   46199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-03 14:17:12.387143: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1748953034.699519   46199 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1740 MB memory:  -> device: 0, name: NVIDIA GeForce MX150, pci bus id: 0000:01:00.0, compute capability: 6.1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748953035.994159   46199 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1748953035.999325   46323 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1-1ubuntu3.1~22.04.3), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1748953036.086054   46308 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748953036.121843   46312 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748953036.124466   46306 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748953036.125261   46310 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748953036.127098   46308 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748953036.132877   46307 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748953036.152357   46312 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748953036.153851   46308 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1748953036.311850   46312 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# I0000 00:00:1748953039.426401   46271 cuda_dnn.cc:529] Loaded cuDNN version 90300
